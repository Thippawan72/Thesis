# %% [markdown]
# <a href="https://colab.research.google.com/github/Thippawan72/Thesis/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ###Data Preprocessing

# %%
#pip install moviepy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from moviepy.editor import VideoFileClip

varbs_input_directory = '/content/drive/MyDrive/วิดีโอภาษามือ/TSL/กริยา'
varbs_output_directory = '/content/drive/MyDrive/วิดีโอภาษามือ/TSL/varbs_video'
words_input_directory = '/content/drive/MyDrive/วิดีโอภาษามือ/TSL/คำ'
words_output_directory = '/content/drive/MyDrive/วิดีโอภาษามือ/TSL/words_video'
added_input_directory = '/content/drive/MyDrive/Thesis/วิดีโอภาษามือ (โหลดใหม่)'
added_output_directory = '/content/drive/MyDrive/Thesis/Added Video'
added3_input_directory = '/content/drive/MyDrive/Thesis/โหลดใหม่ ครั้งที่ 3'
added3_output_directory = '/content/drive/MyDrive/Thesis/New added Video3'

# Function to convert GIF to MP4
def convert_gif_to_mp4(input_gif, output_mp4):
    try:
        clip = VideoFileClip(input_gif)

        clip.write_videofile(output_mp4, codec='libx264')
        print(f"Successfully converted {input_gif} to {output_mp4}")

    except Exception as e:
        print(f"Failed to convert {input_gif}: {e}")

def preprocess_videos(input_dir, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for filename in os.listdir(input_dir):
        if filename.endswith(".gif"):
            input_path = os.path.join(input_dir, filename)
            output_filename = filename.replace(".gif", ".mp4")
            output_path = os.path.join(output_dir, output_filename)

            # Convert GIF to MP4
            convert_gif_to_mp4(input_path, output_path)

#preprocess_videos(varbs_input_directory, varbs_output_directory)
#preprocess_videos(words_input_directory, words_output_directory)
#preprocess_videos(added_input_directory, added_output_directory)
#preprocess_videos(added3_input_directory, added3_output_directory)
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if event.key is 'enter':

# %%
#Prints the filenames in the format you specified (filename.mp4 - filename).
import os

# Set the directory where your files are located
folder_path = "/content/drive/MyDrive/Thesis/Added Video"  # Replace with your actual path

# List all files in the directory
file_list = os.listdir(folder_path)

# Filter and list only the .mp4 files
mp4_files = [f for f in file_list if f.endswith('.mp4')]

# Print the file names in the desired format
for file in mp4_files:
    filename = file.replace(".mp4", "")
    print(f"{file} - {filename}")
# Out:
# พริษฐ์ ชิวารักษ์.mp4 - พริษฐ์ ชิวารักษ์
# อุซเบกิสถาน (ประเทศ).mp4 - อุซเบกิสถาน (ประเทศ)
# เฮติ (ประเทศ).mp4 - เฮติ (ประเทศ)
# ณัฏฐา มหัทธนา (พรรคก้าวไกล).mp4 - ณัฏฐา มหัทธนา (พรรคก้าวไกล)
# น้ำตกเต่าดำ.mp4 - น้ำตกเต่าดำ
# ริมน้ำปิง.mp4 - ริมน้ำปิง
# บ่อน้ำพุร้อนพระร่วง.mp4 - บ่อน้ำพุร้อนพระร่วง
# บ่อน้ำสีฟ้า.mp4 - บ่อน้ำสีฟ้า
# โรงนาคาแฟกำแพงเพชร.mp4 - โรงนาคาแฟกำแพงเพชร
# บ้านริมธารปูกะแหยม.mp4 - บ้านริมธารปูกะแหยม
# ประเพณีสารทไทยกล้วยไข่.mp4 - ประเพณีสารทไทยกล้วยไข่
# บ้านนาตันจั่น ศรีสัชนาลัย (ข้าวเปิ๊บ ยายเครื่อง).mp4 - บ้านนาตันจั่น ศรีสัชนาลัย (ข้าวเปิ๊บ ยายเครื่อง)
# สวนสัตด์สนามบินสุโขทัย.mp4 - สวนสัตด์สนามบินสุโขทัย
# น้ำตกสายรุ้ง.mp4 - น้ำตกสายรุ้ง
# วัดช้างล้อม.mp4 - วัดช้างล้อม
# วัดพิพัฒน์มาดล.mp4 - วัดพิพัฒน์มาดล
# ดอยเขามุ้ง.mp4 - ดอยเขามุ้ง
# ถ้ำเจ้ารามถ้ำพระราม.mp4 - ถ้ำเจ้ารามถ้ำพระราม
# ตลาดริมยม.mp4 - ตลาดริมยม
# อุทยานแห่งชาติรามคำแหง.mp4 - อุทยานแห่งชาติรามคำแหง
# พระแม่ย่า.mp4 - พระแม่ย่า
# เทหลวงสุโขทัย.mp4 - เทหลวงสุโขทัย
# เกรงใจ.mp4 - เกรงใจ
# คลองถม.mp4 - คลองถม
# พาหุรัด.mp4 - พาหุรัด
# ยินดีด้วย.mp4 - ยินดีด้วย
# ดี.mp4 - ดี
# ซ้ำ (ท่าที่2).mp4 - ซ้ำ (ท่าที่2)
# ซ้ำ.mp4 - ซ้ำ
# ศพ.mp4 - ศพ
# วัดโบสถ์ (อำเภอ).mp4 - วัดโบสถ์ (อำเภอ)
# วังทอง (อำเภอ).mp4 - วังทอง (อำเภอ)
# พรหมพิราม (อำเภอ).mp4 - พรหมพิราม (อำเภอ)
# บางระกำ (อำเภอ).mp4 - บางระกำ (อำเภอ)
# บางกระทุ่ม (อำเภอ).mp4 - บางกระทุ่ม (อำเภอ)
# เนินมะปราง (อำเภอ).mp4 - เนินมะปราง (อำเภอ)
# นครไทย (อำเภอ).mp4 - นครไทย (อำเภอ)
# ชาติตระการ (อำเภอ).mp4 - ชาติตระการ (อำเภอ)
# เมืองพิษณุโลก (อำเภอ).mp4 - เมืองพิษณุโลก (อำเภอ)
# เดิน.mp4 - เดิน
# ตัดสิน (ท่าที่2).mp4 - ตัดสิน (ท่าที่2)
# เปลี่ยน.mp4 - เปลี่ยน
# สังคม.mp4 - สังคม
# ประกัน.mp4 - ประกัน
# เขิน.mp4 - เขิน
# ยุ่ง.mp4 - ยุ่ง
# ประชด.mp4 - ประชด
# ตายแล้ว (ท่าที่2).mp4 - ตายแล้ว (ท่าที่2)
# ตายแล้ว.mp4 - ตายแล้ว
# เสียหาย.mp4 - เสียหาย
# ห้างฉัตร (อำเภอ).mp4 - ห้างฉัตร (อำเภอ)
# เสริมงาม (อำเภอ).mp4 - เสริมงาม (อำเภอ)
# สบปราบ (อำเภอ).mp4 - สบปราบ (อำเภอ)
# วังเหนือ (อำเภอ).mp4 - วังเหนือ (อำเภอ)
# เมืองปาน (อำเภอ).mp4 - เมืองปาน (อำเภอ)
# แม่เมาะ (อำเภอ).mp4 - แม่เมาะ (อำเภอ)
# แม่พริก (อำเภอ).mp4 - แม่พริก (อำเภอ)
# แม่ทะ (อำเภอ).mp4 - แม่ทะ (อำเภอ)
# เถิน (อำเภอ).mp4 - เถิน (อำเภอ)
# แจ้ห่ม (อำเภอ).mp4 - แจ้ห่ม (อำเภอ)
# งาว (อำเภอ).mp4 - งาว (อำเภอ)
# เกาะคา (อำเภอ).mp4 - เกาะคา (อำเภอ)
# เมืองลำปาง (อำเภอ).mp4 - เมืองลำปาง (อำเภอ)
# กังวล.mp4 - กังวล
# ศูนย์ราชการแจ้งวัฒนะ.mp4 - ศูนย์ราชการแจ้งวัฒนะ
# ข่าว.mp4 - ข่าว
# ผอม.mp4 - ผอม
# อ้วน.mp4 - อ้วน
# เพิ่มพูน ชิดชอบ.mp4 - เพิ่มพูน ชิดชอบ
# งก.mp4 - งก
# อวดดี.mp4 - อวดดี
# อวด.mp4 - อวด
# ไข่ดาว (ท่าที่2).mp4 - ไข่ดาว (ท่าที่2)
# ไข่ดาว.mp4 - ไข่ดาว
# ไข่เจียว (ท่าที่2).mp4 - ไข่เจียว (ท่าที่2)
# ไข่เจียว.mp4 - ไข่เจียว
# ไข่ (ท่าที่2).mp4 - ไข่ (ท่าที่2)
# กาตาร์-(ประเทศ).mp4 - กาตาร์-(ประเทศ)
# กรีซ-(ประเทศ).mp4 - กรีซ-(ประเทศ)
# โรงพยาบาลส่งเสริมสุขภาพตำบล.mp4 - โรงพยาบาลส่งเสริมสุขภาพตำบล
# สถานีอนามัย.mp4 - สถานีอนามัย
# เยเมน-(ประเทศ).mp4 - เยเมน-(ประเทศ)
# กรมอนามัย.mp4 - กรมอนามัย
# ผ้าป่า.mp4 - ผ้าป่า
# นักศึกษา.mp4 - นักศึกษา
# นักเรียน.mp4 - นักเรียน
# คู่.mp4 - คู่
# กทปส..mp4 - กทปส.
# กล้วยทอด.mp4 - กล้วยทอด
# ช้า.mp4 - ช้า
# นาน(ท่าที่2).mp4 - นาน(ท่าที่2)
# ช้า(ท่าที่2).mp4 - ช้า(ท่าที่2)
# ฮามาส.mp4 - ฮามาส
# สีส้ม.mp4 - สีส้ม
# ปาเลสไตน์ (ประเทศ).mp4 - ปาเลสไตน์ (ประเทศ)
# พิเชษฐ์ เชื้อเมืองพาน.mp4 - พิเชษฐ์ เชื้อเมืองพาน
# ปดิพัทธ์ สันติภาดา (หมออ๋อง).mp4 - ปดิพัทธ์ สันติภาดา (หมออ๋อง)
# สยามพารากอน.mp4 - สยามพารากอน
# นกขมิ้นน้อยปีกสีเรียบ (Great Iora).mp4 - นกขมิ้นน้อยปีกสีเรียบ (Great Iora)
# นกขมิ้นน้อยธรรมดา (Common Iora).mp4 - นกขมิ้นน้อยธรรมดา (Common Iora)
# นกขมิ้นน้อยสีเขียว (Green Iora).mp4 - นกขมิ้นน้อยสีเขียว (Green Iora)
# กลุ่มนกขมิ้นน้อย (Iora).mp4 - กลุ่มนกขมิ้นน้อย (Iora)
# นกกางเขนบ้าน (Oriental Magpie Robin).mp4 - นกกางเขนบ้าน (Oriental Magpie Robin)
# นกยางกรอก (pond herons).mp4 - นกยางกรอก (pond herons)
# นกแซงแซวหางบ่วงใหญ่ (Greater Racquet-tailed Drongo).mp4 - นกแซงแซวหางบ่วงใหญ่ (Greater Racquet-tailed Drongo)
# นกแซงหางปลา (Black Drongo).mp4 - นกแซงหางปลา (Black Drongo)
# นกแซงแซวสีเทา (Ashy Drongo).mp4 - นกแซงแซวสีเทา (Ashy Drongo)
# กลุ่มนกแซงแซว (drongos).mp4 - กลุ่มนกแซงแซว (drongos)
# นกตีทอง (Coppersmit Barbet).mp4 - นกตีทอง (Coppersmit Barbet)
# กลุ่มนกโพระดก (barbets).mp4 - กลุ่มนกโพระดก (barbets)
# นกตะขาบทุ่ง (Indochinese Roller).mp4 - นกตะขาบทุ่ง (Indochinese Roller)
# นกจาบคาเล็ก (Asian Green Bee-eater).mp4 - นกจาบคาเล็ก (Asian Green Bee-eater)
# นกจาบคาหัวเขียว (Blue-tailed Bee-eater).mp4 - นกจาบคาหัวเขียว (Blue-tailed Bee-eater)
# กลุ่มนกจาบคา (bee-eaters).mp4 - กลุ่มนกจาบคา (bee-eaters)
# นกตีนเทียน (Black-winged Stilt).mp4 - นกตีนเทียน (Black-winged Stilt)
# นกกาน้ำเล็ก (Little Cormorant).mp4 - นกกาน้ำเล็ก (Little Cormorant)
# กลุ่มนกกาน้ำ (cormorants).mp4 - กลุ่มนกกาน้ำ (cormorants)
# นกปากห่าง (Asian Openbill).mp4 - นกปากห่าง (Asian Openbill)
# นกกระแตแต้แว้ด (Red-wattled Lapwing).mp4 - นกกระแตแต้แว้ด (Red-wattled Lapwing)
# นกกวัก (White-breasted Waterhen).mp4 - นกกวัก (White-breasted Waterhen)
# นกยางเปีย (Little Egret).mp4 - นกยางเปีย (Little Egret)
# นกยางควาย (Cattle Egret).mp4 - นกยางควาย (Cattle Egret)
# นกยางโทนน้อย (Medium Egret).mp4 - นกยางโทนน้อย (Medium Egret)
# นกยางโทนใหญ่ (Great Egret).mp4 - นกยางโทนใหญ่ (Great Egret)
# กลุ่มนกยาง (herons and egrets).mp4 - กลุ่มนกยาง (herons and egrets)
# กลุ่มนกกระเต็น (kingfishers).mp4 - กลุ่มนกกระเต็น (kingfishers)
# นกกาเหว่า (Asian Koel).mp4 - นกกาเหว่า (Asian Koel)
# นกกระปูดใหญ่ (Greater Coucal).mp4 - นกกระปูดใหญ่ (Greater Coucal)
# เหยี่ยวแดง (Brahminy Kite).mp4 - เหยี่ยวแดง (Brahminy Kite)
# กลุ่มเหยี่ยวและนกอินทรี (hawks and eagles).mp4 - กลุ่มเหยี่ยวและนกอินทรี (hawks and eagles)
# นกเค้าจุด (Spotted Owlet).mp4 - นกเค้าจุด (Spotted Owlet)
# นกเค้ากู่, นกฮูก (Collared Scops Owl).mp4 - นกเค้ากู่, นกฮูก (Collared Scops Owl)
# กลุ่มนกเค้า (owls).mp4 - กลุ่มนกเค้า (owls)
# อนันต์ชัย ไชยเดช (ทนายกระดูกเหล็ก).mp4 - อนันต์ชัย ไชยเดช (ทนายกระดูกเหล็ก)
# ต่อศักดิ์ สุขวิมล (บิ๊กต่อ).mp4 - ต่อศักดิ์ สุขวิมล (บิ๊กต่อ)
# ษิทรา เบี้ยบังเกิด (ทนายตั้ม).mp4 - ษิทรา เบี้ยบังเกิด (ทนายตั้ม)
# สุรเชษฐ์ หักพาล (บิ๊กโจ๊ก).mp4 - สุรเชษฐ์ หักพาล (บิ๊กโจ๊ก)
# ปิยบุตร แสงกนกกุล.mp4 - ปิยบุตร แสงกนกกุล
# พรรณิการ์ วานิช.mp4 - พรรณิการ์ วานิช
# สันติสุข-(อำเภอ).mp4 - สันติสุข-(อำเภอ)
# สองแคว-(อำเภอ).mp4 - สองแคว-(อำเภอ)
# เวียงสา-(อำเภอ).mp4 - เวียงสา-(อำเภอ)
# แม่จริม-(อำเภอ).mp4 - แม่จริม-(อำเภอ)
# ภูเพียง-(อำเภอ).mp4 - ภูเพียง-(อำเภอ)
# ปัว (อำเภอ).mp4 - ปัว (อำเภอ)
# บ่อเกลือ (อำเภอ).mp4 - บ่อเกลือ (อำเภอ)
# บ้านหลวง (อำเภอ).mp4 - บ้านหลวง (อำเภอ)
# นาหมื่น (อำเภอ).mp4 - นาหมื่น (อำเภอ)
# นาน้อย (อำเภอ).mp4 - นาน้อย (อำเภอ)
# ทุ่งช้าง (อำเภอ).mp4 - ทุ่งช้าง (อำเภอ)
# ท่าวังผา-(อำเภอ).mp4 - ท่าวังผา-(อำเภอ)
# เชียงกลาง-(อำเภอ).mp4 - เชียงกลาง-(อำเภอ)
# เฉลิมพระเกียรติ-(อำเภอ).mp4 - เฉลิมพระเกียรติ-(อำเภอ)
# เมืองน่าน-(อำเภอ).mp4 - เมืองน่าน-(อำเภอ)
# อุ้มผาง (อำเภอ).mp4 - อุ้มผาง (อำเภอ)
# สามเงา (อำเภอ).mp4 - สามเงา (อำเภอ)
# วังเจ้า (อำเภอ).mp4 - วังเจ้า (อำเภอ)
# แม่สอด (อำเภอ).mp4 - แม่สอด (อำเภอ)
# แม่ระมาด (อำเภอ).mp4 - แม่ระมาด (อำเภอ)
# พบพระ (อำเภอ).mp4 - พบพระ (อำเภอ)
# ท่าสองยาง (อำเภอ).mp4 - ท่าสองยาง (อำเภอ)
# เมืองตาก (อำเภอ).mp4 - เมืองตาก (อำเภอ)
# สามง่าม-(อำเภอ).mp4 - สามง่าม-(อำเภอ)
# สากเหล็ก-(อำเภอ).mp4 - สากเหล็ก-(อำเภอ)
# วังทรายพูน-(อำเภอ).mp4 - วังทรายพูน-(อำเภอ)
# วชิรบารมี-(อำเภอ).mp4 - วชิรบารมี-(อำเภอ)
# โพธิ์ประทับช้าง-(อำเภอ).mp4 - โพธิ์ประทับช้าง-(อำเภอ)
# โพทะเล-(อำเภอ).mp4 - โพทะเล-(อำเภอ)
# บึงนาราง (อำเภอ).mp4 - บึงนาราง (อำเภอ)
# บางมูลนาก (อำเภอ).mp4 - บางมูลนาก (อำเภอ)
# ทับคล้อ-(อำเภอ).mp4 - ทับคล้อ-(อำเภอ)
# ตะพานหิน-(อำเภอ).mp4 - ตะพานหิน-(อำเภอ)
# ดงเจริญ-(อำเภอ).mp4 - ดงเจริญ-(อำเภอ)
# เมืองพิจิตร-(อำเภอ).mp4 - เมืองพิจิตร-(อำเภอ)
# เวียงหนองล่อง-(อำเภอ).mp4 - เวียงหนองล่อง-(อำเภอ)
# ลี้-(อำเภอ).mp4 - ลี้-(อำเภอ)
# แม่ทา-(อำเภอ).mp4 - แม่ทา-(อำเภอ)
# ป่าซาง (อำเภอ).mp4 - ป่าซาง (อำเภอ)
# บ้านโฮ่ง (อำเภอ).mp4 - บ้านโฮ่ง (อำเภอ)
# บ้านธิ (อำเภอ).mp4 - บ้านธิ (อำเภอ)
# ทุ่งหัวช้าง (อำเภอ).mp4 - ทุ่งหัวช้าง (อำเภอ)
# เมืองลำพูน-(อำเภอ).mp4 - เมืองลำพูน-(อำเภอ)
# ลานกระบือ-(อำเภอ).mp4 - ลานกระบือ-(อำเภอ)
# พรานกระต่าย-(อำเภอ).mp4 - พรานกระต่าย-(อำเภอ)
# ปางศิลาทอง (อำเภอ).mp4 - ปางศิลาทอง (อำเภอ)
# บึงสามัคคี (อำเภอ).mp4 - บึงสามัคคี (อำเภอ)
# ไทรงาม (อำเภอ).mp4 - ไทรงาม (อำเภอ)
# ทรายทองวัฒนา-(อำเภอ).mp4 - ทรายทองวัฒนา-(อำเภอ)
# คลองลาน-(อำเภอ).mp4 - คลองลาน-(อำเภอ)
# คลองขลุง-(อำเภอ).mp4 - คลองขลุง-(อำเภอ)
# ขาญุวรลักษบุรี-(อำเภอ).mp4 - ขาญุวรลักษบุรี-(อำเภอ)
# โกสัมพีนคร-(อำเภอ).mp4 - โกสัมพีนคร-(อำเภอ)
# เมืองกำแพงเพชร-(อำเภอ).mp4 - เมืองกำแพงเพชร-(อำเภอ)
# แม่ใจ (อำเภอ).mp4 - แม่ใจ (อำเภอ)
# ภูซาง (อำเภอ).mp4 - ภูซาง (อำเภอ)
# ภูกามยาว (อำเภอ).mp4 - ภูกามยาว (อำเภอ)
# ปง (อำเภอ).mp4 - ปง (อำเภอ)
# ดอกคำใต้ (อำเภอ).mp4 - ดอกคำใต้ (อำเภอ)
# เชียงม่วน (อำเภอ).mp4 - เชียงม่วน (อำเภอ)
# เชียงคำ (อำเภอ).mp4 - เชียงคำ (อำเภอ)
# จุน (อำเภอ).mp4 - จุน (อำเภอ)
# เมืองพะเยา (อำเภอ).mp4 - เมืองพะเยา (อำเภอ)
# กฤดิทัช แสงธนโยธิน.mp4 - กฤดิทัช แสงธนโยธิน
# รอมฎอน ปันจอร์.mp4 - รอมฎอน ปันจอร์
# อภิสิทธิ์ ไล่ศัตรูไกล.mp4 - อภิสิทธิ์ ไล่ศัตรูไกล
# จิรัฏฐ์ ทองสุวรรณ์.mp4 - จิรัฏฐ์ ทองสุวรรณ์
# มณเฑียร บุญตัน.mp4 - มณเฑียร บุญตัน
# วัลลภ ตังคณานุรักษ์.mp4 - วัลลภ ตังคณานุรักษ์
# สุรทิน พิจารณ์.mp4 - สุรทิน พิจารณ์
# ทวี สอดส่อง.mp4 - ทวี สอดส่อง
# นครชัยศรี-(อำเภอ) ท่าที่1.mp4 - นครชัยศรี-(อำเภอ) ท่าที่1
# เมืองนครปฐม-(อำเภอ).mp4 - เมืองนครปฐม-(อำเภอ)
# หนองม่วงไข่ (อำเภอ).mp4 - หนองม่วงไข่ (อำเภอ)
# ลอง (อำเภอ).mp4 - ลอง (อำเภอ)
# บรรพตพิสัย (อำเภอ).mp4 - บรรพตพิสัย (อำเภอ)
# สูงเม่น (อำเภอ).mp4 - สูงเม่น (อำเภอ)
# สอง (อำเภอ).mp4 - สอง (อำเภอ)
# วังชิ้น (อำเภอ).mp4 - วังชิ้น (อำเภอ)
# ร้องกวาง (อำเภอ).mp4 - ร้องกวาง (อำเภอ)
# เด่นชัย (อำเภอ).mp4 - เด่นชัย (อำเภอ)
# เมืองแพร่ (อำเภอ).mp4 - เมืองแพร่ (อำเภอ)
# อบรม.mp4 - อบรม
# แพรรี่ ไพรวัลย์.mp4 - แพรรี่ ไพรวัลย์
# พิมรี่พาย.mp4 - พิมรี่พาย
# ลีนา จังจรรจา.mp4 - ลีนา จังจรรจา
# โหน่ง ชะชะช่า.mp4 - โหน่ง ชะชะช่า
# เท่ง เถิดเทิง.mp4 - เท่ง เถิดเทิง
# หม่ำ จ๊กมก.mp4 - หม่ำ จ๊กมก
# ติ๊กต๊อก (Tik Tok).mp4 - ติ๊กต๊อก (Tik Tok)
# อินสตาแกรม (Instagram).mp4 - อินสตาแกรม (Instagram)
# ไลน์-(Line) (ท่าที่2).mp4 - ไลน์-(Line) (ท่าที่2)
# ไลน์-(Line).mp4 - ไลน์-(Line)
# เฟซบุ๊ก-(Facebook) (ท่าที่2).mp4 - เฟซบุ๊ก-(Facebook) (ท่าที่2)
# เฟซบุ๊ก-(Facebook).mp4 - เฟซบุ๊ก-(Facebook)
# โรบินสัน (ท่ามือที่ 2) (ห้างสรรพสินค้า).mp4 - โรบินสัน (ท่ามือที่ 2) (ห้างสรรพสินค้า)
# นครสวรรค์ (ท่าที่3).mp4 - นครสวรรค์ (ท่าที่3)
# ลิซ่า.mp4 - ลิซ่า
# นครสวรรค์ (ท่าที่2).mp4 - นครสวรรค์ (ท่าที่2)
# พิษ.mp4 - พิษ
# นครสวรรค์.mp4 - นครสวรรค์
# ชุมตาบง (อำเภอ).mp4 - ชุมตาบง (อำเภอ)
# แม่เปิน (อำเภอ).mp4 - แม่เปิน (อำเภอ)
# แม่วงก์ (อำเภอ).mp4 - แม่วงก์ (อำเภอ)
# ตากฟ้า (อำเภอ).mp4 - ตากฟ้า (อำเภอ)
# ลาดยาว (อำเภอ).mp4 - ลาดยาว (อำเภอ)
# พยุหะคีรี (อำเภอ).mp4 - พยุหะคีรี (อำเภอ)
# ไพศาลี (อำเภอ).mp4 - ไพศาลี (อำเภอ)
# ท่าตะโก (อำเภอ).mp4 - ท่าตะโก (อำเภอ)
# ตาคลี (อำเภอ).mp4 - ตาคลี (อำเภอ)
# เก้าเลี้ยว (อำเภอ).mp4 - เก้าเลี้ยว (อำเภอ)
# ขอนแก่น - มหาวิทยาลัยขอนแก่น.mp4 - ขอนแก่น - มหาวิทยาลัยขอนแก่น
# ศิลปากร - มหาวิทยาลัยศิลปากร.mp4 - ศิลปากร - มหาวิทยาลัยศิลปากร
# ศรีนครินทรวิโรฒ - มหาวิทยาลัยศรีนครินทรวิโรฒ.mp4 - ศรีนครินทรวิโรฒ - มหาวิทยาลัยศรีนครินทรวิโรฒ
# สุโขทัยธรรมธิราช - มหาวิทยาลัยสุโขทัยธรรมธิราช.mp4 - สุโขทัยธรรมธิราช - มหาวิทยาลัยสุโขทัยธรรมธิราช
# รังสิต - มหาวิทยาลัยรังสิต.mp4 - รังสิต - มหาวิทยาลัยรังสิต
# กันตพงศ์ รังษีสว่าง.mp4 - กันตพงศ์ รังษีสว่าง
# กรุงเทพ - มหาวิทยาลัยกรุงเทพ.mp4 - กรุงเทพ - มหาวิทยาลัยกรุงเทพ
# สวนดุสิต - มหาวิทยาลัยสวนดุสิต.mp4 - สวนดุสิต - มหาวิทยาลัยสวนดุสิต
# บูรพา - มหาวิทยาลัยบูรพา.mp4 - บูรพา - มหาวิทยาลัยบูรพา
# ธรรมศาสตร์ - มหาวิทยาลัยธรรมศาสตร์.mp4 - ธรรมศาสตร์ - มหาวิทยาลัยธรรมศาสตร์
# เชียงใหม่-มหาวิทยาลัยเชียงใหม่.mp4 - เชียงใหม่-มหาวิทยาลัยเชียงใหม่
# รามคำแหง-มหาวิทยาลัยรามคำแหง.mp4 - รามคำแหง-มหาวิทยาลัยรามคำแหง

# %%
import os
from IPython.display import Video, display

video_directory = '/content/drive/MyDrive/Thesis/วิดีโอภาษามือ/2.ภาษาระดับกึ่งทางการ/วิดีโอทั้งหมดกึ่งทางการ'

# Path to the file containing the keyword-video pairs (assume one pair per line)
keyword_file_path = '/content/drive/MyDrive/Thesis/keyword_video.txt'

# Load the keywords and video filenames into a dictionary
def load_keyword_video_mapping(file_path):
    keyword_video_map = {}
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            video_file, keyword = line.strip().split(' - ')
            keyword_video_map[keyword] = video_file
    return keyword_video_map

# Display the video corresponding to the keyword
def display_video_for_keyword(keyword, keyword_video_map, width=640, height=480):
    if keyword in keyword_video_map:
        video_file = keyword_video_map[keyword]
        video_path = os.path.join(video_directory, video_file)

        if os.path.exists(video_path):
            print(f"Displaying video for '{keyword}': {video_file}")
            # Standardized size for video display
            display(Video(video_path, embed=True, width=width, height=height))
        else:
            print(f"Video file '{video_file}' not found.")
    else:
        print(f"No video found for the keyword '{keyword}'.")

# Load the keyword-video mapping
keyword_video_map = load_keyword_video_mapping(keyword_file_path)

# Example: Display videos for multiple keywords
keywords_to_search = ["สวัสดี", "อาจารย์", "ปรึกษา"]  # List of keywords to search for

# Loop through each keyword and display its corresponding video
for keyword in keywords_to_search:
    display_video_for_keyword(keyword, keyword_video_map, width=640, height=480)  # Adjust video size here
# Out:
# Video file 'สวัสดี.mp4' not found.
# Video file 'อาจารย์.mp4' not found.
# Video file 'ปรึกษา.mp4' not found.

# %%
from IPython.display import Video, display

# ตัวอย่างแสดงวิดีโอหนึ่งตัว
video_path = '/content/drive/MyDrive/Thesis/วิดีโอภาษามือ/2.ภาษาระดับกึ่งทางการ/วิดีโอทั้งหมดกึ่งทางการ/สวัสดี.mp4'
display(Video(video_path, embed=True, width=640, height=480))
# Out:
# <video controls  width="640"  height="480">
#  <source src="...วิดีโอภาษามือ/2.ภาษาระดับกึ่งทางการ/วิดีโอทั้งหมดกึ่งทางการ/สวัสดี.mp4" type="None">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ### PyThaiNLP Get Started
#
# Code examples for basic functions in PyThaiNLP https://github.com/PyThaiNLP/pythainlp

# %%
# # pip install required modules
# # uncomment if running from colab
# # see list of modules in `requirements` and `extras`
# # in https://github.com/PyThaiNLP/pythainlp/blob/dev/setup.py

#!pip install pythainlp
#!pip install epitran

# %%
#pip install required modules

# %%
# !pip install pythainlp
# !pip install epitran
# Out:
# Collecting pythainlp
#   Downloading pythainlp-5.1.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from pythainlp) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->pythainlp) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->pythainlp) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->pythainlp) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->pythainlp) (2025.1.31)
# Downloading pythainlp-5.1.0-py3-none-any.whl (19.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 21.2 MB/s eta 0:00:00
# Installing collected packages: pythainlp
# Successfully installed pythainlp-5.1.0
# Collecting epitran
#   Downloading epitran-1.26.0-py2.py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from epitran) (75.1.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from epitran) (2024.11.6)
# Collecting panphon>=0.20 (from epitran)
#   Downloading panphon-0.21.2-py2.py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: marisa-trie in /usr/local/lib/python3.11/dist-packages (from epitran) (1.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from epitran) (2.32.3)
# Collecting jamo (from epitran)
#   Downloading jamo-0.4.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting unicodecsv (from panphon>=0.20->epitran)
#   Downloading unicodecsv-0.14.1.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from panphon>=0.20->epitran) (6.0.2)
# Requirement already satisfied: numpy>=1.20.2 in /usr/local/lib/python3.11/dist-packages (from panphon>=0.20->epitran) (2.0.2)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.11/dist-packages (from panphon>=0.20->epitran) (0.8.1)
# Collecting munkres (from panphon>=0.20->epitran)
#   Downloading munkres-1.1.4-py2.py3-none-any.whl.metadata (980 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->epitran) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->epitran) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->epitran) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->epitran) (2025.1.31)
# Downloading epitran-1.26.0-py2.py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 7.7 MB/s eta 0:00:00
# Downloading panphon-0.21.2-py2.py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 4.8 MB/s eta 0:00:00
# Downloading jamo-0.4.1-py3-none-any.whl (9.5 kB)
# Downloading munkres-1.1.4-py2.py3-none-any.whl (7.0 kB)
# Building wheels for collected packages: unicodecsv
#   Building wheel for unicodecsv (setup.py) ... done
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10744 sha256=766d7341cf3d148f431ef68f0452b520ae39b72a06619aefffe6265b4b3d4018
#   Stored in directory: /root/.cache/pip/wheels/ec/03/6f/d2e0162d94c0d451556fa43dd4d5531457245c34a36b41ef4a
# Successfully built unicodecsv
# Installing collected packages: unicodecsv, munkres, jamo, panphon, epitran
# Successfully installed epitran-1.26.0 jamo-0.4.1 munkres-1.1.4 panphon-0.21.2 unicodecsv-0.14.1

# %% [markdown]
# ### Import PyThaiNLP

# %%
import pythainlp

# %%
import pythainlp

pythainlp.__version__
# Out:
# '5.1.0'

# %% [markdown]
# ### Thai Characters
#
# PyThaiNLP provides some ready-to-use Thai character set (e.g. Thai consonants, vowels, tonemarks, symbols) as a string for convenience. There are also few utility functions to test if a string is in Thai or not.

# %%
pythainlp.thai_characters
# Out:
# 'กขฃคฅฆงจฉชซฌญฎฏฐฑฒณดตถทธนบปผฝพฟภมยรลวศษสหฬอฮฤฦะัาำิีึืุูเแโใไๅํ็่้๊๋ฯฺๆ์ํ๎๏๚๛๐๑๒๓๔๕๖๗๘๙฿'

# %%
len(pythainlp.thai_characters)
# Out:
# 88

# %%
pythainlp.thai_consonants
# Out:
# 'กขฃคฅฆงจฉชซฌญฎฏฐฑฒณดตถทธนบปผฝพฟภมยรลวศษสหฬอฮ'

# %%
len(pythainlp.thai_consonants)
# Out:
# 44

# %%
"๔" in pythainlp.thai_digits  # check if Thai digit "4" is in the character set
# Out:
# True

# %% [markdown]
# ### Checking if a string contains Thai character or not, or how many

# %%
import pythainlp.util

pythainlp.util.isthai("ก")
# Out:
# True

# %%
pythainlp.util.isthai("(ก.พ.)")
# Out:
# False

# %%
pythainlp.util.isthai("(ก.พ.)", ignore_chars=".()")
# Out:
# True

# %%
from pythainlp import sent_tokenize
from pythainlp.corpus.common import thai_words
from pythainlp import Tokenizer
from pythainlp.tokenize import subword_tokenize
from pythainlp.tokenize import word_tokenize
from pythainlp.tag import pos_tag
from pythainlp.corpus import thai_stopwords

# %%
from pythainlp.tokenize import word_detokenize
print(word_detokenize(['โน็', 'ตบุ๊ค']))
# Out:
# โน็ตบุ๊ค

# %% [markdown]
# ###NLP for TSL แบบทดลอง

# %%
from pythainlp.tokenize import word_tokenize, Tokenizer
from pythainlp.corpus import thai_stopwords, thai_words
from pythainlp.tag import pos_tag

# ฟังก์ชันสำหรับการปรับรูปเป็นคำพื้นฐาน
def get_lemma(word):
    lemmas = {
        "สวัสดีค่ะ": "สวัสดี",
        "ที่ปรึกษา": "ปรึกษา",
        "สอบถาม": "ถาม",
    }
    return lemmas.get(word, word)

# ฟังก์ชันสำหรับการเรียงคำตามไวยากรณ์ของ TSL
def reorder_to_tsl(words):
    # กรองคำบางคำออกไปตามลักษณะของไวยากรณ์ TSL
    simplified_sentence = [word for word in words if word not in ['คือ', 'เป็น', 'อยู่', 'มี', 'จะ', 'ได้', 'แล้ว', 'ก็', 'ที่', 'นั้น', 'นี้']]

    # จัดลำดับคำตามเวลา (ถ้ามี)
    time_words = ['วันนี้', 'พรุ่งนี้', 'เมื่อวาน', 'ตอนเช้า', 'ตอนเย็น', 'หนึ่งสัปดาห์หน้า']
    time_elements = [word for word in simplified_sentence if word in time_words]
    non_time_elements = [word for word in simplified_sentence if word not in time_words]

    # รวมส่วนที่เป็นเวลาขึ้นก่อน และส่วนอื่นๆ ต่อท้าย
    reordered_sentence = time_elements + non_time_elements

    return ' '.join(reordered_sentence)

# ข้อความตัวอย่าง
text1 = "นี่หนังสือใช่ไหม"

# สร้าง custom dictionary สำหรับการตัดคำ
words = set(thai_words())
words.discard("การเรียน")  # ลบคำที่ไม่ต้องการออกจาก dictionary
custom_tokenizer = Tokenizer(words)

# ตัดคำ
tokenized_words = custom_tokenizer.word_tokenize(text1)
print("custom dictionary:", tokenized_words)

# ดึง stop words ภาษาไทยและลบคำที่ไม่จำเป็นออก
stopwords = set(thai_stopwords())
stopwords.discard("นี่")  # เก็บคำว่า "นี่"

# ลบคำที่อยู่ใน stop words
filtered_words = [word for word in tokenized_words if word not in stopwords]
print("Original words:", tokenized_words)
print("Filtered words:", filtered_words)

# ปรับคำให้เป็นรูปพื้นฐาน (lemmatization)
lemmatized_words = [get_lemma(word) for word in filtered_words]
print("Lemmatized words:", lemmatized_words)

# เพิ่ม POS tagging สำหรับคำที่ผ่านการ lemmatization แล้ว
pos_tags = pos_tag(lemmatized_words)
print("POS Tags:", pos_tags)

# เรียงคำตามไวยากรณ์ของ TSL
tsl_sentence = reorder_to_tsl(lemmatized_words)
print("Reordered sentence (TSL):", tsl_sentence)
# Out:
# custom dictionary: ['นี่', 'หนังสือ', 'ใช่ไหม']
# Original words: ['นี่', 'หนังสือ', 'ใช่ไหม']
# Filtered words: ['นี่', 'หนังสือ']
# Lemmatized words: ['นี่', 'หนังสือ']
# POS Tags: [('นี่', 'PDMN'), ('หนังสือ', 'NCMN')]
# Reordered sentence (TSL): นี่ หนังสือ

# %% [markdown]
# ### NLP ที่ใช้บน colap ประโยคชีวิตประจำวัน

# %%
from pythainlp.tokenize import Tokenizer, word_tokenize
from pythainlp.corpus.common import thai_stopwords, thai_words

# Example sentences list
sentences = [
     "นี่หนังสือใช่ไหม", "นั่นสมุดใช่ไหม", "นี่อะไร", "นี่นาฬิกาหรือปากกา", "คุณเข้าใจไหม",
     "ฉันขอโทษ", "ขอบคุณนะพี่ชาย", "โทรศัพท์อยู่ที่ไหน", "คุณเป็นคนที่ไหน", "ขายราคาเท่าไร",
     "โทรศัพท์อยู่บนโต๊ะใช่ไหม", "เขาเป็นคนญี่ปุ่นหรือคนเกาหลีใต้", "ภาษาไทยยากไหม", "ภาษาไทยง่าย",
     "ราคาแพง", "หนังสืออยู่บนเก้าอี้", "คุณชอบอาหารอะไร", "คุณชอบอาหารจีนไหม", "คุณชอบอาหารไทยหรืออาหารจีน",
    "คุณอ่านภาษาไทยได้ไหม", "คุณเขียนภาษาไทยได้ไหม", "คุณจะไปที่ไหน", "เขาชอบดื่มอะไร", "เขาทำงานที่ไหน",
    "ขอโทษ พูดช้าลงหน่อยได้ไหม", "พูดอีกทีได้ไหม", "เขามีเวลาว่างทุกวันเสาร์", "เมื่อวานนี้ไปทำงาน",
    "หนึ่งสัปดาห์หน้าจะเรียนภาษาไทย", "หนึ่งสัปดาห์ที่แล้วกลับบ้านช้าทุกวัน", "อีกสามปีจะกลับประเทศไทย",
    "ตอนเที่ยงกินข้าวมันไก่แล้ว", "ผมพบกับแฟนที่สวนสัตว์", "ตอนนี้เวลากี่โมง", "คุณกินข้าวเช้ากี่โมง",
    "เขามาช้า", "ผมเรียนภาษาไทยเริ่มจากเวลาบ่ายโมง", "ผมอ่านหนังสืออยู่ตอนนี้", "เขาจะไปสนามบินเวลาเที่ยงตรง",
    "ผมจะทำอาหารไทยตอนเที่ยง", "สามารถไปเข้าห้องน้ำได้ห้านาที", "ผมทำงานห้าชั่วโมง", "อีกสิบนาทีจะกลับบ้าน",
    "พรุ่งนี้ดิฉันทำงานเวลาเช้า", "คุณจะไปธนาคารกี่โมง", "วันนี้วันหยุด ทำอะไรดี", "พรุ่งนี้วันอาทิตย์",
    "สิ้นเดือนแล้วเงินเดือนออก", "วันปีใหม่ไปเที่ยวที่ไหน", "คุณจะไปประเทศไทยเดือนอะไร", "วันหยุดนี้คุณจะทำอะไร",
    "เมื่อวานนี้คุณทำอะไร", "ผมอยู่ประเทศไทยนานหกปีแล้ว", "หนึ่งสัปดาห์หน้าจะทำอะไร",
    "เมื่อวานซืนคุยโทรศัพท์กับแฟนสองชั่วโมง", "เขาไปทำงานแต่เช้า", "วันเสาร์ฉันชอบไปเดินเล่น",
    "ผมกลับประเทศอังกฤษเดือนธันวาคม", "คุณไปออกกำลังกายกี่โมง", "คุณกินข้าวหรือยัง", "คุณอยากทำอะไร",
    "ฉันเคยไปประเทศเม็กซิโก", "อากาศร้อน เมื่อไรจะเข้าฤดูหนาว", "คุณพ่อไปกินข้าวที่ร้านอาหาร", "ปกติคุณไปทำงานยังไง",
    "ไปที่ไหนมา", "ผมอยากไปหาคุณ", "ฝนตกหนักมาก", "ผมขับรถยนต์ไปทำงาน", "ผมชอบคุยกับคนไทย",
    "ประเทศไทยไม่มีหิมะตก", "ภูเขาเดี๋ยวนี้ไม่มีต้นไม้", "ที่บ้านไม่มีคนอยู่", "วันนี้มีไปทำธุระ", "ผมทานข้าวแล้ว",
    "ผมยังไม่ทานข้าว", "ฉันนั่งร้องเพลงคาราโอเกะ", "เขายืนคุยกับคุณ", "ผมชอบนั่งอ่านหนังสือที่บ้าน",
    "พรุ่งนี้อยากไปเที่ยวกับแฟน", "เขายังไม่อยากเรียนภาษาไทยตอนนี้", "วันนี้ไม่อยากทำอะไร", "นี่ใคร",
    "ฉันไปว่ายน้ำออกกำลังกาย", "จำผมได้ไหม", "ได้ยินฉันไหม", "มองเห็นเขาไหม", "รู้จักเขาไหม", "ทำงานเสร็จแล้ว",
    "เมื่อวานนี้นอนหลับไม่ดี", "ง่วงนอนต้องการดื่มกาแฟ", "เขาฟังภาษาไทยไม่ได้", "ผมอ่านหนังสือภาษาไทยยังไม่ได้",
    "กินเผ็ดไม่ได้", "ไปประเทศไทยไม่ได้", "ผมคิดถึงคุณมาก", "เขามองดูทะเล", "ผมพูดภาษาไทยได้นิดหน่อย",
    "เขาอ่านภาษาอังกฤษไม่ผิดเลย", "อาหารไทยอร่อยมาก", "คุณจะไปประเทศไทยเดือนอะไร", "เขาชื่อเล่นอะไร",
    "พรุ่งนี้จะไปตัดผม", "ผมโกนหนวดทุกวันเวลาเช้า", "คนไทยชอบอาบน้ำ", "จะไปซื้อสบู่กับยาสีฟัน",
    "เขาชอบซื้อเสื้อแขนยาว", "ครอบครัวคุณมีกี่คน", "คุณทำงานอะไร", "คุณแต่งงานหรือยัง", "คุณมีลูกหรือยัง",
    "คุณอายุกี่ปี", "บ้านคุณมีแมวไหม", "ใครเป็นครูภาษาไทย", "ทำไมคุณเรียนภาษาไทย", "ทำไมคุณไม่มาวัดหนึ่งสัปดาห์ที่แล้ว",
    "ถ้าคุณรวย คุณอยากจะทำอะไร", "ถ้าฝนตกควรทำอะไรดี", "วันนี้อยากไปหาหมอฟัน", "ผมมีลุงที่อยู่อังกฤษ",
    "เขามีครอบครัวอยู่ที่ไทย", "ผมอยากแต่งงานกับคุณ", "ผมรักคุณมาก", "เขาสูงมาก", "คุณเรียนภาษาไทยกี่ชั่วโมง",
    "ผมชอบสีขาวมากกว่าสีดำ", "เครื่องบินลำนี้ใหญ่มาก", "เขารักเธอมาก", "เขาเกลียดคุณเพราะคุณชอบโกหก",
    "เสื้อยืดตัวนี้ไม่แพง", "ใครเขียนหนังสือสวย", "คุณชอบไปเที่ยวที่ไหน", "วันนี้กินกล้วยหอม",
    "เมื่อวานนี้คุณอ่านหนังสืออะไร", "ผมมีทีวีสามเครื่อง คอมพิวเตอร์หนึ่งเครื่อง",
    "นั่งเครื่องบินมาลงกรุงเทพฯ", "ผมซื้อบ้านใหม่", "เนื้อชิ้นนี้อร่อยมาก", "ดอกไม้ดอกนี้สวยมาก",
    "มีอาหารหกจานอยู่บนโต๊ะ"
]
# sentences = ["วันนี้เธอกินข้าวหรือยัง"]
# Set of words that should not be filtered out (คำศัพท์ที่ไม่ควรตัดออก)
important_words = {
  "นี่", "หนังสือ", "นั่น", "สมุด", "อะไร", "นาฬิกา", "หรือ", "ปากกา", "คุณ", "เข้าใจ",
    "ฉัน", "ขอโทษ", "ขอบคุณ", "โทรศัพท์", "อยู่", "ที่ไหน", "คน", "ขาย", "ราคา", "บน",
    "โต๊ะ", "ญี่ปุ่น", "เกาหลีใต้", "ภาษาไทย", "ยาก", "ง่าย", "แพง", "เก้าอี้", "ชอบ",
    "อาหาร", "จีน", "ไทย", "อ่าน", "เขียน", "ไป", "ที่ไหน", "เขา", "ดื่ม", "ทำงาน",
    "ขอโทษ", "พูด", "ช้า", "ลง", "อีก", "มี", "เวลา", "ว่าง", "ทุกวัน", "เสาร์",
    "เมื่อวานนี้", "หนึ่งสัปดาห์หน้า", "เรียน", "หนึ่งสัปดาห์ที่แล้ว", "กลับบ้าน", "สาม",
    "ปี", "กลับ", "ประเทศไทย", "ตอนเที่ยง", "กิน", "ข้าวมันไก่", "แล้ว", "ผม", "พบ",
    "แฟน", "เริ่ม", "ตอนนี้", "กี่โมง", "ข้าว", "เช้า", "สี่", "สนามบิน", "พี่ชาย",
    "สวนสัตว์", "อ่าน", "ตอนนี้", "เที่ยง", "ทำ", "ได้", "สามารถ", "ห้องน้ำ", "นาที",
    "เข้า", "ห้า", "ชั่วโมง", "สิบ", "กลับบ้าน", "ดิฉัน", "พรุ่งนี้", "ธนาคาร", "วันนี้",
    "วันหยุด", "ดี", "วันอาทิตย์", "สิ้นเดือน", "เงินเดือน", "ออก", "วันปีใหม่", "ไปเที่ยว",
    "ที่ไหน", "เดือน", "เมื่อวานนี้", "นาน", "หนึ่งสัปดาห์หน้า", "เมื่อวานซืน", "คุย",
    "วันเสาร์", "ชอบ", "เดิน", "เล่น", "อังกฤษ", "ธันวาคม", "ออกกำลังกาย", "กิน",
    "ยัง", "เมื่อไร", "อยาก", "เคย", "เม็กซิโก", "อากาศ", "ร้อน", "ฤดู", "หนาว",
    "พ่อ", "ที่ไหน", "หา", "มาก", "ขับรถ", "รถยนต์", "คุย", "ไทย", "ไม่มี", "หิมะ",
    "ตก", "ภูเขา", "เดี๋ยวนี้", "ต้นไม้", "บ้าน", "คน", "ธุระ", "หา", "ไม่", "ไม่กิน",
    "นั่ง", "ฟัง", "ร้องเพลงคาราโอเกะ", "ยืน", "ใคร", "ว่ายน้ำ", "ออกกำลังกาย", "จำ",
    "ได้", "ได้ยิน", "มอง", "เห็น", "รู้จัก", "เสร็จแล้ว", "นอนหลับ", "ไม่ดี", "ง่วงนอน",
    "ดื่ม", "กาแฟ", "ต้องการ", "เผ็ด", "คิดถึง", "มองดู", "ทะเล", "นิดหน่อย",
    "ภาษาอังกฤษ", "ผิด", "อร่อย", "ชื่อเล่น", "ตัด", "ผม (เส้นผม)", "โกนหนวด", "เช้า",
    "อาบน้ำ", "ซื้อ", "สบู่", "ยาสีฟัน", "เสื้อแขนยาว", "ครอบครัว", "แต่งงาน", "ลูก",
    "อายุ", "แมว", "ครู", "ทำไม", "ถ้า", "รวย", "ฝนตก", "หมอ", "ฟัน", "ดิฉัน",
    "ลุง", "รัก", "สูง", "เกลียด", "โกหก", "สวย", "กล้วยหอม", "สอง", "สาม", "คอมพิวเตอร์",
    "หนึ่ง", "กรุงเทพฯ", "นั่ง", "ลง", "ใหม่", "ดอกไม้","เท่าไร"
}

# Custom function for lemmatization
def get_lemma(word):
    lemmas = {
        "มาช้า": "มาสาย",
        "ขับ": "ขับรถ",
         "ทาน": "กิน",
        "ไม่ทาน": "ไม่กิน",
        "ผม ": "ผม (เส้นผม)",
        "ไม่ทาน": "ไม่กิน",
        # Add more lemmas as needed
    }
    return lemmas.get(word, word)

# Reordering for TSL (focus on time elements first)
def reorder_to_tsl(words):
    simplified_sentence = [word for word in words if word not in ['คือ', 'เป็น', 'จะ', 'ก็', 'ที่', 'นั้น', 'นี้','ได้']]

    # Define common time-related words
    time_words = ['วันนี้', 'พรุ่งนี้', 'เมื่อวาน', 'ตอนเช้า', 'ตอนเย็น', 'หนึ่งสัปดาห์หน้า']
    time_elements = [word for word in simplified_sentence if word in time_words]
    non_time_elements = [word for word in simplified_sentence if word not in time_words]

    # Reorder by placing time elements first
    reordered_sentence = time_elements + non_time_elements
    return reordered_sentence  # Return as a list

# Create a custom tokenizer by defining words to be used
custom_words = set(thai_words())
custom_words.discard("คนญี่ปุ่น")
custom_words.discard("ราคาแพง")
custom_words.discard("อาหารจีน")
custom_words.discard("เวลาว่าง")
custom_words.discard("กินข้าว")
custom_words.discard("อ่านหนังสือ")
custom_words.discard("เที่ยงตรง")
custom_words.discard("ทำอาหาร")
custom_words.discard("แต่เช้า")
custom_words.discard("เดินเล่น")
custom_words.discard("ฤดูหนาว")
custom_words.discard("คุณพ่อ")
custom_words.discard("ทานข้าว")
custom_words.discard("มองเห็น")
custom_words.discard("ตัดผม")
custom_words.discard("คนไทย")
custom_words.discard("ที่อยู่")
custom_words.discard("หรือยัง")
custom_words.discard("มีครอบครัว")
custom_words.discard("เขียนหนังสือ")
custom_words.discard("ยืดตัว")
custom_words.discard("ไม้ดอก")
custom_words.discard("")

custom_words.add("เมื่อวานนี้")
custom_words.add("หนึ่งสัปดาห์หน้า")
custom_words.add("หนึ่งสัปดาห์ที่แล้ว")
custom_words.add("ประเทศไทย")
custom_words.add("กี่โมง")
custom_words.add("มาช้า")
custom_words.add("วันปีใหม่")
custom_words.add("วันเสาร์")
custom_words.add("ฝนตกหนัก")
custom_words.add("ไม่มี")
custom_words.add("ร้องเพลงคาราโอเกะ")
custom_words.add("ไม่ทาน")
custom_words.add("เสร็จแล้ว")
custom_words.add("ไม่ดี")
custom_words.add("โกนหนวด")
custom_words.add("สีขาว")
custom_words.add("สีดำ")
custom_words.add("เสื้อยืด")
custom_words.add("")
custom_words.add("")

# Remove words that should not be in the dictionary
custom_tokenizer = Tokenizer(custom_words)

# Stopwords
stopwords = set(thai_stopwords())
stopwords.add("ไหม")
stopwords.add("กี่")
stopwords.add("")
stopwords.add("")
stopwords.add("")

stopwords.add(" ")
stopwords.discard("อยู่")
stopwords.discard("ตรง")
stopwords.discard("มา")
stopwords.discard("หรือยัง")
stopwords.discard("ยัง")
stopwords.discard("ได้")
stopwords.discard("ใหญ่")
stopwords.discard("ตัว")
stopwords.discard("")
stopwords.discard("")


# Process each sentence through tokenization, stopword removal, lemmatization, and reordering
def process_sentence(sentence):
    # Tokenization using custom tokenizer
    tokens = custom_tokenizer.word_tokenize(sentence)

    # Stopword filtering, but keeping important words
    filtered_tokens = [token for token in tokens if token not in stopwords or token in important_words]

    # Lemmatization
    lemmatized_tokens = [get_lemma(token) for token in filtered_tokens]

    # Sentence reordering for TSL
    reordered_sentence = reorder_to_tsl(lemmatized_tokens)

    return reordered_sentence

# Process all sentences in the list
processed_sentences_train = [process_sentence(sentence) for sentence in sentences]

 # Output the results
for i, sentence in enumerate(processed_sentences_train):
    print(f"Original: {sentences[i]}")
    print(f"Processed: {sentence}\n")
# Out:
# Original: นี่หนังสือใช่ไหม
# Processed: ['นี่', 'หนังสือ']
#
# Original: นั่นสมุดใช่ไหม
# Processed: ['นั่น', 'สมุด']
#
# Original: นี่อะไร
# Processed: ['นี่', 'อะไร']
#
# Original: นี่นาฬิกาหรือปากกา
# Processed: ['นี่', 'นาฬิกา', 'หรือ', 'ปากกา']
#
# Original: คุณเข้าใจไหม
# Processed: ['คุณ', 'เข้าใจ']
#
# Original: ฉันขอโทษ
# Processed: ['ฉัน', 'ขอโทษ']
#
# Original: ขอบคุณนะพี่ชาย
# Processed: ['ขอบคุณ', 'พี่ชาย']
#
# Original: โทรศัพท์อยู่ที่ไหน
# Processed: ['โทรศัพท์', 'อยู่', 'ที่ไหน']
#
# Original: คุณเป็นคนที่ไหน
# Processed: ['คุณ', 'คน', 'ที่ไหน']
#
# Original: ขายราคาเท่าไร
# Processed: ['ขาย', 'ราคา', 'เท่าไร']
#
# Original: โทรศัพท์อยู่บนโต๊ะใช่ไหม
# Processed: ['โทรศัพท์', 'อยู่', 'บน', 'โต๊ะ']
#
# Original: เขาเป็นคนญี่ปุ่นหรือคนเกาหลีใต้
# Processed: ['เขา', 'คน', 'ญี่ปุ่น', 'หรือ', 'คน', 'เกาหลีใต้']
#
# Original: ภาษาไทยยากไหม
# Processed: ['ภาษาไทย', 'ยาก']
#
# Original: ภาษาไทยง่าย
# Processed: ['ภาษาไทย', 'ง่าย']
#
# Original: ราคาแพง
# Processed: ['ราคา', 'แพง']
#
# Original: หนังสืออยู่บนเก้าอี้
# Processed: ['หนังสือ', 'อยู่', 'บน', 'เก้าอี้']
#
# Original: คุณชอบอาหารอะไร
# Processed: ['คุณ', 'ชอบ', 'อาหาร', 'อะไร']
#
# Original: คุณชอบอาหารจีนไหม
# Processed: ['คุณ', 'ชอบ', 'อาหาร', 'จีน']
#
# Original: คุณชอบอาหารไทยหรืออาหารจีน
# Processed: ['คุณ', 'ชอบ', 'อาหาร', 'ไทย', 'หรือ', 'อาหาร', 'จีน']
#
# Original: คุณอ่านภาษาไทยได้ไหม
# Processed: ['คุณ', 'อ่าน', 'ภาษาไทย']
#
# Original: คุณเขียนภาษาไทยได้ไหม
# Processed: ['คุณ', 'เขียน', 'ภาษาไทย']
#
# Original: คุณจะไปที่ไหน
# Processed: ['คุณ', 'ไป', 'ที่ไหน']
#
# Original: เขาชอบดื่มอะไร
# Processed: ['เขา', 'ชอบ', 'ดื่ม', 'อะไร']
#
# Original: เขาทำงานที่ไหน
# Processed: ['เขา', 'ทำงาน', 'ที่ไหน']
#
# Original: ขอโทษ พูดช้าลงหน่อยได้ไหม
# Processed: ['ขอโทษ', 'พูด', 'ช้า', 'ลง']
#
# Original: พูดอีกทีได้ไหม
# Processed: ['พูด', 'อีกที']
#
# Original: เขามีเวลาว่างทุกวันเสาร์
# Processed: ['เขา', 'มี', 'เวลา', 'ว่าง', 'วันเสาร์']
#
# Original: เมื่อวานนี้ไปทำงาน
# Processed: ['เมื่อวานนี้', 'ไป', 'ทำงาน']
#
# Original: หนึ่งสัปดาห์หน้าจะเรียนภาษาไทย
# Processed: ['หนึ่งสัปดาห์หน้า', 'เรียน', 'ภาษาไทย']
#
# Original: หนึ่งสัปดาห์ที่แล้วกลับบ้านช้าทุกวัน
# Processed: ['หนึ่งสัปดาห์ที่แล้ว', 'กลับบ้าน', 'ช้า', 'ทุกวัน']
#
# Original: อีกสามปีจะกลับประเทศไทย
# Processed: ['อีก', 'สาม', 'ปี', 'กลับ', 'ประเทศไทย']
#
# Original: ตอนเที่ยงกินข้าวมันไก่แล้ว
# Processed: ['ตอนเที่ยง', 'กิน', 'ข้าวมันไก่', 'แล้ว']
#
# Original: ผมพบกับแฟนที่สวนสัตว์
# Processed: ['ผม', 'พบ', 'แฟน', 'สวนสัตว์']
#
# Original: ตอนนี้เวลากี่โมง
# Processed: ['ตอนนี้', 'เวลา', 'กี่โมง']
#
# Original: คุณกินข้าวเช้ากี่โมง
# Processed: ['คุณ', 'กิน', 'ข้าว', 'เช้า', 'กี่โมง']
#
# Original: เขามาช้า
# Processed: ['เขา', 'มาสาย']
#
# Original: ผมเรียนภาษาไทยเริ่มจากเวลาบ่ายโมง
# Processed: ['ผม', 'เรียน', 'ภาษาไทย', 'เริ่ม', 'เวลา', 'บ่ายโมง']
#
# Original: ผมอ่านหนังสืออยู่ตอนนี้
# Processed: ['ผม', 'อ่าน', 'หนังสือ', 'อยู่', 'ตอนนี้']
#
# Original: เขาจะไปสนามบินเวลาเที่ยงตรง
# Processed: ['เขา', 'ไป', 'สนามบิน', 'เวลา', 'เที่ยง', 'ตรง']
#
# Original: ผมจะทำอาหารไทยตอนเที่ยง
# Processed: ['ผม', 'ทำ', 'อาหาร', 'ไทย', 'ตอนเที่ยง']
#
# Original: สามารถไปเข้าห้องน้ำได้ห้านาที
# Processed: ['สามารถ', 'ไป', 'เข้า', 'ห้องน้ำ', 'ห้า', 'นาที']
#
# Original: ผมทำงานห้าชั่วโมง
# Processed: ['ผม', 'ทำงาน', 'ห้า', 'ชั่วโมง']
#
# Original: อีกสิบนาทีจะกลับบ้าน
# Processed: ['อีก', 'สิบ', 'นาที', 'กลับบ้าน']
#
# Original: พรุ่งนี้ดิฉันทำงานเวลาเช้า
# Processed: ['พรุ่งนี้', 'ดิฉัน', 'ทำงาน', 'เวลา', 'เช้า']
#
# Original: คุณจะไปธนาคารกี่โมง
# Processed: ['คุณ', 'ไป', 'ธนาคาร', 'กี่โมง']
#
# Original: วันนี้วันหยุด ทำอะไรดี
# Processed: ['วันนี้', 'วันหยุด', 'ทำ', 'อะไร', 'ดี']
#
# Original: พรุ่งนี้วันอาทิตย์
# Processed: ['พรุ่งนี้', 'วันอาทิตย์']
#
# Original: สิ้นเดือนแล้วเงินเดือนออก
# Processed: ['สิ้นเดือน', 'แล้ว', 'เงินเดือน', 'ออก']
#
# Original: วันปีใหม่ไปเที่ยวที่ไหน
# Processed: ['วันปีใหม่', 'ไปเที่ยว', 'ที่ไหน']
#
# Original: คุณจะไปประเทศไทยเดือนอะไร
# Processed: ['คุณ', 'ไป', 'ประเทศไทย', 'เดือน', 'อะไร']
#
# Original: วันหยุดนี้คุณจะทำอะไร
# Processed: ['วันหยุด', 'คุณ', 'ทำ', 'อะไร']
#
# Original: เมื่อวานนี้คุณทำอะไร
# Processed: ['เมื่อวานนี้', 'คุณ', 'ทำ', 'อะไร']
#
# Original: ผมอยู่ประเทศไทยนานหกปีแล้ว
# Processed: ['ผม', 'อยู่', 'ประเทศไทย', 'นาน', 'หก', 'ปี', 'แล้ว']
#
# Original: หนึ่งสัปดาห์หน้าจะทำอะไร
# Processed: ['หนึ่งสัปดาห์หน้า', 'ทำ', 'อะไร']
#
# Original: เมื่อวานซืนคุยโทรศัพท์กับแฟนสองชั่วโมง
# Processed: ['เมื่อวานซืน', 'คุย', 'โทรศัพท์', 'แฟน', 'สอง', 'ชั่วโมง']
#
# Original: เขาไปทำงานแต่เช้า
# Processed: ['เขา', 'ไป', 'ทำงาน', 'เช้า']
#
# Original: วันเสาร์ฉันชอบไปเดินเล่น
# Processed: ['วันเสาร์', 'ฉัน', 'ชอบ', 'ไป', 'เดิน', 'เล่น']
#
# Original: ผมกลับประเทศอังกฤษเดือนธันวาคม
# Processed: ['ผม', 'กลับ', 'ประเทศ', 'อังกฤษ', 'เดือน', 'ธันวาคม']
#
# Original: คุณไปออกกำลังกายกี่โมง
# Processed: ['คุณ', 'ไป', 'ออกกำลังกาย', 'กี่โมง']
#
# Original: คุณกินข้าวหรือยัง
# Processed: ['คุณ', 'กิน', 'ข้าว', 'หรือ', 'ยัง']
#
# Original: คุณอยากทำอะไร
# Processed: ['คุณ', 'อยาก', 'ทำ', 'อะไร']
#
# Original: ฉันเคยไปประเทศเม็กซิโก
# Processed: ['ฉัน', 'เคย', 'ไป', 'ประเทศ', 'เม็กซิโก']
#
# Original: อากาศร้อน เมื่อไรจะเข้าฤดูหนาว
# Processed: ['อากาศ', 'ร้อน', 'เมื่อไร', 'เข้า', 'ฤดู', 'หนาว']
#
# Original: คุณพ่อไปกินข้าวที่ร้านอาหาร
# Processed: ['คุณ', 'พ่อ', 'ไป', 'กิน', 'ข้าว', 'ร้านอาหาร']
#
# Original: ปกติคุณไปทำงานยังไง
# Processed: ['ปกติ', 'คุณ', 'ไป', 'ทำงาน']
#
# Original: ไปที่ไหนมา
# Processed: ['ไป', 'ที่ไหน', 'มา']
#
# Original: ผมอยากไปหาคุณ
# Processed: ['ผม', 'อยาก', 'ไปหา', 'คุณ']
#
# Original: ฝนตกหนักมาก
# Processed: ['ฝนตกหนัก', 'มาก']
#
# Original: ผมขับรถยนต์ไปทำงาน
# Processed: ['ผม', 'ขับรถ', 'รถยนต์', 'ไป', 'ทำงาน']
#
# Original: ผมชอบคุยกับคนไทย
# Processed: ['ผม', 'ชอบ', 'คุย', 'คน', 'ไทย']
#
# Original: ประเทศไทยไม่มีหิมะตก
# Processed: ['ประเทศไทย', 'ไม่มี', 'หิมะ', 'ตก']
#
# Original: ภูเขาเดี๋ยวนี้ไม่มีต้นไม้
# Processed: ['ภูเขา', 'เดี๋ยวนี้', 'ไม่มี', 'ต้นไม้']
#
# Original: ที่บ้านไม่มีคนอยู่
# Processed: ['บ้าน', 'ไม่มี', 'คน', 'อยู่']
#
# Original: วันนี้มีไปทำธุระ
# Processed: ['วันนี้', 'มี', 'ไป', 'ทำ', 'ธุระ']
#
# Original: ผมทานข้าวแล้ว
# Processed: ['ผม', 'กิน', 'ข้าว', 'แล้ว']
#
# Original: ผมยังไม่ทานข้าว
# Processed: ['ผม', 'ยัง', 'ไม่กิน', 'ข้าว']
#
# Original: ฉันนั่งร้องเพลงคาราโอเกะ
# Processed: ['ฉัน', 'นั่ง', 'ร้องเพลงคาราโอเกะ']
#
# Original: เขายืนคุยกับคุณ
# Processed: ['เขา', 'ยืน', 'คุย', 'คุณ']
#
# Original: ผมชอบนั่งอ่านหนังสือที่บ้าน
# Processed: ['ผม', 'ชอบ', 'นั่ง', 'อ่าน', 'หนังสือ', 'บ้าน']
#
# Original: พรุ่งนี้อยากไปเที่ยวกับแฟน
# Processed: ['พรุ่งนี้', 'อยาก', 'ไปเที่ยว', 'แฟน']
#
# Original: เขายังไม่อยากเรียนภาษาไทยตอนนี้
# Processed: ['เขา', 'ยัง', 'ไม่', 'อยาก', 'เรียน', 'ภาษาไทย', 'ตอนนี้']
#
# Original: วันนี้ไม่อยากทำอะไร
# Processed: ['วันนี้', 'ไม่', 'อยาก', 'ทำ', 'อะไร']
#
# Original: นี่ใคร
# Processed: ['นี่', 'ใคร']
#
# Original: ฉันไปว่ายน้ำออกกำลังกาย
# Processed: ['ฉัน', 'ไป', 'ว่ายน้ำ', 'ออกกำลังกาย']
#
# Original: จำผมได้ไหม
# Processed: ['จำ', 'ผม']
#
# Original: ได้ยินฉันไหม
# Processed: ['ได้ยิน', 'ฉัน']
#
# Original: มองเห็นเขาไหม
# Processed: ['มอง', 'เห็น', 'เขา']
#
# Original: รู้จักเขาไหม
# Processed: ['รู้จัก', 'เขา']
#
# Original: ทำงานเสร็จแล้ว
# Processed: ['ทำงาน', 'เสร็จแล้ว']
#
# Original: เมื่อวานนี้นอนหลับไม่ดี
# Processed: ['เมื่อวานนี้', 'นอนหลับ', 'ไม่ดี']
#
# Original: ง่วงนอนต้องการดื่มกาแฟ
# Processed: ['ง่วงนอน', 'ต้องการ', 'ดื่ม', 'กาแฟ']
#
# Original: เขาฟังภาษาไทยไม่ได้
# Processed: ['เขา', 'ฟัง', 'ภาษาไทย', 'ไม่']
#
# Original: ผมอ่านหนังสือภาษาไทยยังไม่ได้
# Processed: ['ผม', 'อ่าน', 'หนังสือ', 'ภาษาไทย', 'ยัง', 'ไม่']
#
# Original: กินเผ็ดไม่ได้
# Processed: ['กิน', 'เผ็ด', 'ไม่']
#
# Original: ไปประเทศไทยไม่ได้
# Processed: ['ไป', 'ประเทศไทย', 'ไม่']
#
# Original: ผมคิดถึงคุณมาก
# Processed: ['ผม', 'คิดถึง', 'คุณ', 'มาก']
#
# Original: เขามองดูทะเล
# Processed: ['เขา', 'มองดู', 'ทะเล']
#
# Original: ผมพูดภาษาไทยได้นิดหน่อย
# Processed: ['ผม', 'พูด', 'ภาษาไทย', 'นิดหน่อย']
#
# Original: เขาอ่านภาษาอังกฤษไม่ผิดเลย
# Processed: ['เขา', 'อ่าน', 'ภาษาอังกฤษ', 'ไม่', 'ผิด']
#
# Original: อาหารไทยอร่อยมาก
# Processed: ['อาหาร', 'ไทย', 'อร่อย', 'มาก']
#
# Original: คุณจะไปประเทศไทยเดือนอะไร
# Processed: ['คุณ', 'ไป', 'ประเทศไทย', 'เดือน', 'อะไร']
#
# Original: เขาชื่อเล่นอะไร
# Processed: ['เขา', 'ชื่อเล่น', 'อะไร']
#
# Original: พรุ่งนี้จะไปตัดผม
# Processed: ['พรุ่งนี้', 'ไป', 'ตัด', 'ผม']
#
# Original: ผมโกนหนวดทุกวันเวลาเช้า
# Processed: ['ผม', 'โกนหนวด', 'ทุกวัน', 'เวลา', 'เช้า']
#
# Original: คนไทยชอบอาบน้ำ
# Processed: ['คน', 'ไทย', 'ชอบ', 'อาบน้ำ']
#
# Original: จะไปซื้อสบู่กับยาสีฟัน
# Processed: ['ไป', 'ซื้อ', 'สบู่', 'ยาสีฟัน']
#
# Original: เขาชอบซื้อเสื้อแขนยาว
# Processed: ['เขา', 'ชอบ', 'ซื้อ', 'เสื้อแขนยาว']
#
# Original: ครอบครัวคุณมีกี่คน
# Processed: ['ครอบครัว', 'คุณ', 'มี', 'คน']
#
# Original: คุณทำงานอะไร
# Processed: ['คุณ', 'ทำงาน', 'อะไร']
#
# Original: คุณแต่งงานหรือยัง
# Processed: ['คุณ', 'แต่งงาน', 'หรือ', 'ยัง']
#
# Original: คุณมีลูกหรือยัง
# Processed: ['คุณ', 'มีลูก', 'หรือ', 'ยัง']
#
# Original: คุณอายุกี่ปี
# Processed: ['คุณ', 'อายุ', 'ปี']
#
# Original: บ้านคุณมีแมวไหม
# Processed: ['บ้าน', 'คุณ', 'มี', 'แมว']
#
# Original: ใครเป็นครูภาษาไทย
# Processed: ['ใคร', 'ครู', 'ภาษาไทย']
#
# Original: ทำไมคุณเรียนภาษาไทย
# Processed: ['ทำไม', 'คุณ', 'เรียน', 'ภาษาไทย']
#
# Original: ทำไมคุณไม่มาวัดหนึ่งสัปดาห์ที่แล้ว
# Processed: ['ทำไม', 'คุณ', 'ไม่', 'มา', 'วัด', 'หนึ่งสัปดาห์ที่แล้ว']
#
# Original: ถ้าคุณรวย คุณอยากจะทำอะไร
# Processed: ['ถ้า', 'คุณ', 'รวย', 'คุณ', 'อยาก', 'ทำ', 'อะไร']
#
# Original: ถ้าฝนตกควรทำอะไรดี
# Processed: ['ถ้า', 'ฝนตก', 'ทำ', 'อะไร', 'ดี']
#
# Original: วันนี้อยากไปหาหมอฟัน
# Processed: ['วันนี้', 'อยาก', 'ไปหา', 'หมอฟัน']
#
# Original: ผมมีลุงที่อยู่อังกฤษ
# Processed: ['ผม', 'มี', 'ลุง', 'อยู่', 'อังกฤษ']
#
# Original: เขามีครอบครัวอยู่ที่ไทย
# Processed: ['เขา', 'มี', 'ครอบครัว', 'อยู่', 'ไทย']
#
# Original: ผมอยากแต่งงานกับคุณ
# Processed: ['ผม', 'อยาก', 'แต่งงาน', 'คุณ']
#
# Original: ผมรักคุณมาก
# Processed: ['ผม', 'รัก', 'คุณ', 'มาก']
#
# Original: เขาสูงมาก
# Processed: ['เขา', 'สูง', 'มาก']
#
# Original: คุณเรียนภาษาไทยกี่ชั่วโมง
# Processed: ['คุณ', 'เรียน', 'ภาษาไทย', 'ชั่วโมง']
#
# Original: ผมชอบสีขาวมากกว่าสีดำ
# Processed: ['ผม', 'ชอบ', 'สีขาว', 'สีดำ']
#
# Original: เครื่องบินลำนี้ใหญ่มาก
# Processed: ['เครื่องบิน', 'ลำ', 'ใหญ่', 'มาก']
#
# Original: เขารักเธอมาก
# Processed: ['เขา', 'รัก', 'มาก']
#
# Original: เขาเกลียดคุณเพราะคุณชอบโกหก
# Processed: ['เขา', 'เกลียด', 'คุณ', 'คุณ', 'ชอบ', 'โกหก']
#
# Original: เสื้อยืดตัวนี้ไม่แพง
# Processed: ['เสื้อยืด', 'ตัว', 'ไม่', 'แพง']
#
# Original: ใครเขียนหนังสือสวย
# Processed: ['ใคร', 'เขียน', 'หนังสือ', 'สวย']
#
# Original: คุณชอบไปเที่ยวที่ไหน
# Processed: ['คุณ', 'ชอบ', 'ไปเที่ยว', 'ที่ไหน']
#
# Original: วันนี้กินกล้วยหอม
# Processed: ['วันนี้', 'กิน', 'กล้วยหอม']
#
# Original: เมื่อวานนี้คุณอ่านหนังสืออะไร
# Processed: ['เมื่อวานนี้', 'คุณ', 'อ่าน', 'หนังสือ', 'อะไร']
#
# Original: ผมมีทีวีสามเครื่อง คอมพิวเตอร์หนึ่งเครื่อง
# Processed: ['ผม', 'มี', 'ทีวี', 'สาม', 'เครื่อง', 'คอมพิวเตอร์', 'หนึ่ง', 'เครื่อง']
#
# Original: นั่งเครื่องบินมาลงกรุงเทพฯ
# Processed: ['นั่ง', 'เครื่องบิน', 'มา', 'ลง', 'กรุงเทพฯ']
#
# Original: ผมซื้อบ้านใหม่
# Processed: ['ผม', 'ซื้อ', 'บ้าน', 'ใหม่']
#
# Original: เนื้อชิ้นนี้อร่อยมาก
# Processed: ['เนื้อ', 'ชิ้น', 'อร่อย', 'มาก']
#
# Original: ดอกไม้ดอกนี้สวยมาก
# Processed: ['ดอกไม้', 'ดอก', 'สวย', 'มาก']
#
# Original: มีอาหารหกจานอยู่บนโต๊ะ
# Processed: ['มี', 'อาหาร', 'หก', 'จาน', 'อยู่', 'บน', 'โต๊ะ']

# %% [markdown]
# ### NLP ที่ใช้บนเว็บ ท่องเที่ยว

# %%
from pythainlp.tokenize import Tokenizer, word_tokenize
from pythainlp.corpus.common import thai_stopwords, thai_words

#ประโยคท่องเที่ยว 80 ประโยค
sentences = [
    "ฉันต้องการจองสองที่นั่งถึงกรุงเทพ",
    "คุณต้องการตั๋วเที่ยวเดียวหรือไปกลับ",
    "ตั๋วไปกลับราคาเท่าไร",
    "คุณต้องการจ่ายเงินสดหรือบัตรเครดิต",
    "ฉันขอดูตั๋วและหนังสือเดินทางของคุณได้ไหม",
    "วันนี้มีใครไปกับคุณไหม",
    "ฉันเอาสัมภาระมาสองชิ้น",
    "คุณอยากจะนั่งใกล้หน้าต่างหรือไม่",
    "เครื่องบินไปที่เกาะสมุยตั๋วหมดแล้ว",
    "คุณต้องการตั๋วเวลาบ่ายสองหรือสี่โมง",
    "หมายเลขที่นั่งของคุณคืออะไร",
    "โปรดเอาใส่ใจกับการสาธิตความปลอดภัยบนเครื่องบินสั้นๆ นี้",
    "ช่วยปิดโทรศัพท์มือถือและอุปกรณ์อิเล็กทรอนิกส์อื่นๆ",
    "กรุณารัดเข็มขัดนิรภัย",
    "เที่ยวบินใช้เวลานานเท่าไร",
    "คุณต้องการอาหารหรือเครื่องดื่มอะไรไหม",
    "คุณต้องการดื่มชาหรือกาแฟ",
    "ฉันอยากดื่มโค้กโดยไม่ใส่น้ำแข็ง",
    "เครื่องบินจะลงจอดในอีกประมาณสิบห้านาที",
    "เวลาที่ท่าอากาศยานสนามบินดอนเมืองตอนนี้คือสิบนาฬิกาห้านาที",
    "คุณมีสัญชาติอะไร",
    "ฉันเป็นคนไทย",
    "ฉันขอดูหนังสือเดินทางของคุณได้ไหม",
    "นี่คือหนังสือเดินทางของฉัน",
    "คุณมาทำงานหรือเที่ยว",
    "ทำไมคุณอยากไปประเทศสหรัฐอเมริกา",
    "มีเที่ยวบินไปเกาหลีใต้ เพราะฉันอยากไปเที่ยวกับครอบครัว",
    "ฉันเดินทางไปทำงาน",
    "ฉันไปเยี่ยมครอบครัว",
    "ฉันจะไปอยู่บ้านเพื่อนที่ชลบุรีเวลาหนึ่งเดือน",
    "ฉันสามารถจองโรงแรมได้หรือไม่",
    "สวัสดี ขอถามหน่อยว่าโรงแรมของคุณราคาเท่าไหร่",
    "ฉันต้องการเพียงหนึ่งห้องเท่านั้น",
    "ฉันจะอยู่เป็นเวลาหนึ่งสัปดาห์",
    "ฉันต้องการห้องตั้งแต่วันอังคารถึงวันศุกร์",
    "มีห้องว่างที่เป็นเตียงคู่เหลือเท่าไร",
    "ฉันจะอยู่ที่กรุงเทพอีกนาน",
    "ฉันต้องการอยู่พักแค่สองคน",
    "โรงแรมเหลือห้องสุดท้าย ต้องการจองไว้มั้ย",
    "ฉันต้องเดินไปที่ไหนเพื่อเข้าห้องน้ำ",
    "ฉันได้ทำการจองไว้แล้วตอนนี้ต้องการเช็คอิน",
    "ฉันขอดูบัตรประชาชนของคุณได้ไหม",
    "นี่คือกุญแจห้องของคุณ",
    "ฉันลืมบัตรเครดิต ขอเป็นจ่ายเงินสดแทน",
    "ฉันขอดูแผนที่ได้ไหม",
    "ฉันสามารถชำระเงินด้วยบัตรเครดิตได้หรือไม่",
    "คุณมีพนักงานดูแลกระเป๋าหรือไม่",
    "ช่วยเรียกรถแท็กซี่ให้ฉันหน่อยได้ไหม",
    "เสื้อนี่ราคาเท่าไร",
    "คุณมีเสื้อราคาถูกลงอีกไหม",
    "คุณมีสินค้านี้หรือไม่",
    "คุณรู้หรือไม่ว่ามีที่อื่นขายหรือไม่?",
    "คุณพูดภาษาอังกฤษได้ไหม",
    "ฉันชื่อเล่นว่าลิซ่า",
    "ฉันดีใจที่ได้พบคุณ",
    "คุณมาจากที่ไหน",
    "คุณจะอยู่ภูเก็ตนานเท่าไร",
    "ช่วยบอกทางไปน้ำตกหน่อยได้ไหม",
    "ห้องน้ำอยู่ที่ไหน",
    "คุณช่วยพาฉันไปสวนลุมพินีได้ไหม",
    "ฉันจะหารถเมล์ไปเซ็นทรัลได้ที่ไหน",
    "ฉันต้องการความช่วยเหลือจากคุณ",
    "ขนมนี่ราคาเท่าไร",
    "ขอโทษ คุณช่วยพูดซ้ำอีกทีได้ไหม",
    "ฉันจะเอาสิ่งของเหล่านี้กลับบ้าน",
    "ฉันจะหาอาหารอร่อยได้ที่ไหน",
    "เคยไปที่ถนนเยาวราชหรือยัง",
    "คุณช่วยเขียนลงกระดาษให้ฉันได้ไหม",
    "คุณพูดช้าลงหน่อยได้ไหม",
    "คุณช่วยบอกทางไปสถานีรถไฟให้ฉันหน่อยได้ไหม",
    "คุณรับบัตรเครดิตหรือไม่",
    "คุณช่วยบอกทางไปเซเว่นบนแผนที่ให้ฉันหน่อยได้ไหม",
    "ฉันหลงทาง",
    "ฉันไม่เข้าใจ",
    "ภาษาอังกฤษของฉันไม่ดีมาก",
    "โรงแรมอยู่ไกลมาก ขึ้นรถไฟความเร็วสูงไปดีกว่านะ",
    "คุณจะไปที่สนามบินกี่โมง",
    "เสร็จแล้วจะไปเที่ยวที่ไหนกันอีกดี",
    "เครื่องบินจะออกเมื่อไร",
    "ตรงไปข้างหน้าแล้วเลี้ยวซ้าย"
]
# Set of words that should not be filtered out (คำศัพท์ที่ไม่ควรตัดออก)
important_words = {
    "นี่", "หนังสือ", "นั่น", "สมุด", "อะไร", "นาฬิกา", "หรือ", "ปากกา", "คุณ", "เข้าใจ",
    "ฉัน", "ขอโทษ", "ขอบคุณ", "โทรศัพท์", "อยู่", "ที่ไหน", "คน", "ขาย", "ราคา", "บน",
    "โต๊ะ", "ญี่ปุ่น", "เกาหลีใต้", "ภาษาไทย", "ยาก", "ง่าย", "แพง", "เก้าอี้", "ชอบ",
    "อาหาร", "จีน", "ไทย", "อ่าน", "เขียน", "ไป", "ที่ไหน", "เขา", "ดื่ม", "ทำงาน",
    "พูด", "ช้า", "ลง", "อีก", "มี", "เวลา", "ว่าง", "ทุกวัน", "เสาร์",
    "เมื่อวานนี้", "หนึ่งสัปดาห์หน้า", "เรียน", "หนึ่งสัปดาห์ที่แล้ว", "กลับบ้าน", "สาม",
    "ปี", "กลับ", "ประเทศไทย", "ตอนเที่ยง", "กิน", "ข้าวมันไก่", "แล้ว", "ผม", "พบ",
    "แฟน", "เริ่ม", "ตอนนี้", "กี่โมง", "ข้าว", "เช้า", "สี่", "สนามบิน", "พี่ชาย",
    "สวนสัตว์", "เที่ยง", "ทำ", "ได้", "สามารถ", "ห้องน้ำ", "นาที",
    "เข้า", "ห้า", "ชั่วโมง", "สิบ", "กลับบ้าน", "ดิฉัน", "พรุ่งนี้", "ธนาคาร", "วันนี้",
    "วันหยุด", "ดี", "วันอาทิตย์", "สิ้นเดือน", "เงินเดือน", "ออก", "วันปีใหม่", "ไปเที่ยว",
    "เดือน", "นาน", "เมื่อวานซืน", "คุย", "วันเสาร์", "เดิน", "เล่น", "อังกฤษ", "ธันวาคม",
    "ออกกำลังกาย", "ยัง", "เมื่อไร", "อยาก", "เคย", "เม็กซิโก", "อากาศ", "ร้อน",
    "ฤดู", "หนาว", "พ่อ", "หา", "มาก", "ขับรถ", "รถยนต์", "ไทย", "ไม่มี", "หิมะ",
    "ตก", "ภูเขา", "เดี๋ยวนี้", "ต้นไม้", "บ้าน", "ธุระ", "ไม่", "ไม่กิน", "นั่ง",
    "ฟัง", "ร้องเพลงคาราโอเกะ", "ยืน", "ใคร", "ว่ายน้ำ", "ออกกำลังกาย", "จำ",
    "ได้", "ได้ยิน", "มอง", "เห็น", "รู้จัก", "เสร็จแล้ว", "นอนหลับ", "ไม่ดี",
    "ง่วงนอน", "ดื่ม", "กาแฟ", "ต้องการ", "เผ็ด", "คิดถึง", "มองดู", "ทะเล",
    "นิดหน่อย", "ภาษาอังกฤษ", "ผิด", "อร่อย", "ชื่อเล่น", "ตัด", "ผม (เส้นผม)",
    "โกนหนวด", "เช้า", "อาบน้ำ", "ซื้อ", "สบู่", "ยาสีฟัน", "เสื้อแขนยาว",
    "ครอบครัว", "แต่งงาน", "ลูก", "อายุ", "แมว", "ครู", "ทำไม", "ถ้า", "รวย",
    "ฝนตก", "หมอ", "ฟัน", "ลุง", "รัก", "สูง", "เกลียด", "โกหก", "สวย",
    "กล้วยหอม", "สอง", "สาม", "คอมพิวเตอร์", "หนึ่ง", "กรุงเทพฯ", "นั่ง",
    "ลง", "ใหม่", "ดอกไม้", "เท่าไร","ฉัน", "คุณ", "เขา", "ใคร", "สวย", "หนัก", "เบา", "หมด", "บัญชี", "ถอนเงิน",
    "เงินสด", "ฝาก", "บัตรเครดิต", "ดอกเบี้ย", "ประกันชีวิต", "งบประมาณ", "รถยนต์",
    "กำไร", "ขาดทุน", "รถไฟ", "รถแท็กซี่", "เครื่องบิน", "รถเมล์", "เรือ", "จักรยาน",
    "มอเตอร์ไซค์", "สนามบิน", "สถานีรถไฟ", "ตั๋ว", "แผนที่", "โต๊ะ", "ขอโทษ",
    "เก้าอี้", "เตียง", "ตู้เสื้อผ้า", "ตู้เย็น", "โทรทัศน์", "กระจก", "พัดลม",
    "เครื่องซักผ้า", "ไมโครเวฟ", "ทุกวัน", "วันนี้", "วันพุธ", "วันอังคาร", "วันอาทิตย์",
    "วันเสาร์", "วันศุกร์", "วันพฤหัสบดี", "วันหยุด", "มกราคม", "กุมภาพันธ์",
    "มีนาคม", "เมษายน", "พฤษภาคม", "มิถุนายน", "กรกฎาคม", "สิงหาคม", "กันยายน",
    "พฤศจิกายน", "ตุลาคม", "ธันวาคม", "ปี", "เช้า", "เที่ยง", "บ่าย", "เย็น", "กลางคืน",
    "นาที", "วินาที", "ชั่วโมง", "สัปดาห์", "หนึ่ง", "หนึ่งล้าน", "หนึ่งร้อย", "หนึ่งพัน",
    "หนึ่งหมื่น", "สอง", "สิงสอง", "สาม", "สามสิบ", "สามร้อย", "สามี", "สี่", "สี่สิบ",
    "สิบสี่", "สี่ร้อย", "ห้า", "สิบห้า", "ห้าสิบ", "ห้าร้อย", "หก", "สิบหก", "หกสิบ",
    "เจ็ด", "สิบเจ็ด", "เจ็ดสิบ", "เจ็ดร้อย", "แปด", "สิบแปด", "แปดร้อย", "แปดสิบ",
    "เก้า", "สิบเก้า", "เก้าสิบ", "เก้าร้อย", "สิบ", "สิบเอ็ด", "สิบสอง", "สิบสาม", "พ่อ",
    "แม่", "ผู้ชาย", "ผู้หญิง", "เด็ก", "ผู้ใหญ่", "ภรรยา", "ยาย", "ปู่", "พี่ชาย", "พี่สาว",
    "พี่น้อง", "ลุง", "ป้า", "น้า", "อายุ", "เพื่อน", "แฟน", "แต่งงาน", "โสด", "หย่า",
    "ลูก", "ญาติ", "บ้าน", "กลับบ้าน", "โรงเรียน", "วิทยาลัย", "มหาวิทยาลัย", "ตลาด",
    "สวนสัตว์", "สถานีตำรวจ", "โรงพยาบาล", "สนามกีฬา", "โรงแรม", "พิพิธภัณฑ์", "โบสถ์",
    "ข้าว", "ข้าวต้ม", "ข้าวเหนียว", "ข้าวผัด", "ข้าวมันไก่", "ไก่ผัดกะเพรา", "ส้มตำ",
    "ต้มยำ", "ผัดไทย", "ไข่ตุ๋น", "ไข่ดาว", "ไข่", "น้ำชา", "น้ำอัดลม", "กาแฟ", "ดีใจ",
    "เศร้า", "ง่วง", "เบื่อ", "โกรธ", "กลัว", "หัวเราะ", "ร้องไห้", "นอนหลับ", "พูด",
    "ฟัง", "กิน", "ดื่ม", "นั่ง", "ยืน", "ร้องเพลง", "ตื่น", "แปรงฟัน", "เรียน", "อ่าน",
    "เขียน", "ทำงาน", "ออกกำลังกาย", "ทนาย", "ครู", "ช่างไฟฟ้า", "พนักงานขาย", "ตำรวจ",
    "พ่อครัว", "วิศวกร", "นิติบุคคล", "ทนายความ", "โจทก์", "จำเลย", "คณะบุคคล",
    "หมวดครอบครัว", "สิทธิมนุษยชน", "ภาษี", "เบี้ยประกัน", "กรรมสิทธิ์", "สิทธิบัตร",
    "สินสมรส", "การแยกกันอยู่", "ฟ้องหย่า", "การเลือกปฏิบัติ", "คดีแพ่ง", "ประมวลกฎหมาย",
    "ผู้พิพากษา", "ผู้ช่วยผู้พิพากษา", "นักโทษ", "คดีอาญา", "ผู้ต้องหา", "ผู้เสียหาย",
    "การประกันภัย", "การกู้ยืมเงิน", "การประกันชีวิต", "สิทธิบัตร", "คำพิพากษา",
    "สัญญา", "นโยบาย", "สมาชิกผู้แทนราษฎร", "รัฐบาล", "รัฐประหาร", "ฝ่ายค้าน", "เลือกตั้ง",
    "โนโหวต", "ดีเบต", "แลนด์สไลด์", "รัฐสภา", "นายกรัฐมนตรี", "นักการเมือง", "การเมือง",  "สัญญาค้ำประกัน", "สัญญาฝากขาย", "สัญญา", "สังหาริมทรัพย์", "วินาศภัย", "ลูกหนี้",
    "โมฆีกรรม", "โมฆกรรม", "อินเตอร์เน็ต", "วันแรงงาน", "ประเทศลัตเวีย", "ผู้รับประกันภัย",
    "ผู้รับจำนำ", "ผู้รับจำนอง", "ผู้รับจ้าง", "ผู้เช่าซื้อ", "ผู้เช่า", "ผู้จำนำ", "ผู้จำนอง",
    "ผู้กู้", "การประกันสุขภาพ", "การประกันภัยรถยนต์", "การประกันภัยทรัพย์สิน",
    "การประกันภัย", "การประกันชีวิต", "เบี้ยประกันภัย", "ประเทศทาจิสถาน", "นินจา",
    "นิติกรรม", "นายจ้าง", "ทรัพย์สิน", "ยาหม่อง", "ยาล้างแผล", "ยาทาแผล", "ยาพ่นคอ",
    "ยาพ่นจมูก", "ยาดม", "ยาเม็ด", "ยาเม็ดเล็ก", "ยาน้ำ", "มัดจำ", "เงินผ่อน", "เงินกู้",
    "ดอกเบี้ย", "ภาษี", "กล้องวงจรปิด", "นิทาน", "ไถนา", "คนพิการ", "แอปพลิเคชัน",
    "กูเกิ้ลไดร์ฟ", "กูเกิ้ลโครม", "เล็ก", "กูเกิ้ล", "เมาส์", "แป้นพิมพ์", "เว็ปไซต์",
    "บลูทูธ", "ใหญ่", "โน๊ตบุ๊ค", "ตรงกัน", "ไอโอเอส", "แอนดรอยด์", "ยอมความ", "มาตรา",
    "ภาษีมูลค่าเพิ่ม", "ภาษีเงินได้บุคคลธรรมดา", "ภาษีเงินได้นิติบุคคล", "ภาษีเงินได้",
    "ภาษีหัก ณ ที่จ่าย", "พันวิสัย", "ประมวลกฎหมาย", "ประกาศ", "การนัดไกล่เกลี่ย",
    "ทรัพย์สินทางปัญญา", "เครื่องหมายการค้า", "คำสั่ง", "คำพิพากษา", "ความเสมอภาค",
    "คดีอาญา", "คดีหมายเลขดำ", "คดีมีมูล", "คดีแพ่ง", "ข้อบังคับ", "การไกล่เกลี่ย",
    "กฎกระทรวง", "การเลือกปฏิบัติ", "กฎหมายรัฐธรรมนูญ", "หมวดทั่วไป", "เศรษฐกิจพอเพียง",
    "บัตรสวัสดิการแห่งรัฐ", "ฝุ่น pm 2.5", "หน้ากากอนามัย", "อาหาร", "พิซซ่า", "แมคโดนัลด์",
    "เคเอฟซี", "เมเจอร์ ซีนีเพล็กซ์", "เงินประกัน", "บ้านม้าเฟอร์นิเจอร์", "เดอะซันนิวเซ็นเตอร์",
    "แจ่มฟ้าช้อปปิ้งมอลล์", "อนุสาวรีย์พระนางจามเทวี", "กู่ช้างกู่ม้า", "อ่างเก็บน้ำแม่ธิ",
    "วัดพระบาทผาหนาม", "วัดพุทธบาทตากผ้า", "วัดสันป่ายางหลวง", "สะพานทาชมภู", "แก่งก้อ",
    "น้ำตกก้อหลวง", "วัดมหาวัน", "วัดจามเทวี", "วัดพระธาตุหริภุญชัยวรมหาวิหาร", "กิจกรรม",
    "เรียก", "ทักทาย", "คำ", "โล่งใจ", "กด", "หมวดสถานที่", "หมวดบุคคล", "สดใส", "อิสรภาพ",
    "อายุความ", "หน้าที่", "เสรีภาพ", "เหตุสุดวิสัย", "สิทธิมนุษยชน", "สิทธิบัตร", "สิทธิ์",
    "ลหุโทษ", "การล้มละลาย", "ระเบียบ", "นายกรัฐมนตรี", "นักการเมือง", "การเมือง", "ดีเบต",
    "แคนดิเดต", "แลนด์สไลด์", "โนโหวต", "โหวตโน", "นิวโหวตเตอร์", "ขนมเบื้อง", "สีลม",
    "ซอยพัฒน์พงษ์", "กรรม", "อสังหาริมทรัพย์", "ค่าจ้าง", "สัญญาให้โดยเสน่หา", "สัญญาจำนอง",
    "สัญญาจ้างแรงงาน", "สัญญาจ้างทำของ", "รัฐประหาร", "นโยบาย", "ฝ่ายค้าน", "รัฐสภา",
    "สมาชิกผู้แทนราษฎร", "พรรค ส.ว.", "ฉัน", "คุณ", "เขา", "ใคร", "สวย", "หนัก", "เบา", "หมด", "บัญชี", "ถอนเงิน", "เงินสด",
    "ฝาก", "บัตรเครดิต", "ดอกเบี้ย", "ประกันชีวิต", "งบประมาณ", "รถยนต์", "กำไร", "ขาดทุน",
    "รถไฟ", "รถแท็กซี่", "เครื่องบิน", "รถเมล์", "เรือ", "จักรยาน", "มอเตอร์ไซค์", "สนามบิน",
    "สถานีรถไฟ", "ตั๋ว", "แผนที่", "โต๊ะ", "ขอโทษ", "เก้าอี้", "เตียง", "ตู้เสื้อผ้า", "ตู้เย็น",
    "โทรทัศน์", "กระจก", "พัดลม", "เครื่องซักผ้า", "ไมโครเวฟ", "ทุกวัน", "วันนี้", "วันพุธ",
    "วันอังคาร", "วันอาทิตย์", "วันเสาร์", "วันศุกร์", "วันพฤหัสบดี", "วันหยุด", "มกราคม",
    "กุมภาพันธ์", "มีนาคม", "เมษายน", "พฤษภาคม", "มิถุนายน", "กรกฎาคม", "สิงหาคม", "กันยายน",
    "ตุลาคม", "พฤศจิกายน", "ธันวาคม", "ปี", "เช้า", "เที่ยง", "บ่าย", "เย็น", "กลางคืน",
    "นาที", "วินาที", "ชั่วโมง", "สัปดาห์", "หนึ่ง", "หนึ่งล้าน", "หนึ่งร้อย", "หนึ่งพัน",
    "หนึ่งหมื่น", "สอง", "สาม", "สามสิบ", "สามร้อย", "สามี", "สี่", "สี่สิบ", "สิบสี่",
    "สี่ร้อย", "ห้า", "สิบห้า", "ห้าสิบ", "ห้าร้อย", "หก", "สิบหก", "หกสิบ", "เจ็ด",
    "สิบเจ็ด", "เจ็ดสิบ", "เจ็ดร้อย", "แปด", "สิบแปด", "แปดสิบ", "แปดร้อย", "เก้า",
    "สิบเก้า", "เก้าสิบ", "เก้าร้อย", "สิบ", "สิบเอ็ด", "สิบสอง", "สิบสาม", "พ่อ",
    "แม่", "ผู้ชาย", "ผู้หญิง", "เด็ก", "ผู้ใหญ่", "ภรรยา", "ยาย", "ปู่", "พี่ชาย",
    "พี่สาว", "พี่น้อง", "ลุง", "ป้า", "น้า", "อายุ", "เพื่อน", "แฟน", "แต่งงาน",
    "โสด", "หย่า", "ลูก", "ญาติ", "บ้าน", "กลับบ้าน", "โรงเรียน", "วิทยาลัย",
    "มหาวิทยาลัย", "ตลาด", "สวนสัตว์", "สถานีตำรวจ", "โรงพยาบาล", "สนามกีฬา",
    "โรงแรม", "พิพิธภัณฑ์", "โบสถ์", "ข้าว", "ข้าวต้ม", "ข้าวเหนียว", "ข้าวผัด",
    "ข้าวมันไก่", "ไก่ผัดกะเพรา", "ส้มตำ", "ต้มยำ", "ผัดไทย", "ไข่ตุ๋น", "ไข่ดาว",
    "ไข่", "น้ำชา", "น้ำอัดลม", "กาแฟ", "ดีใจ", "เศร้า", "ง่วง", "เบื่อ", "โกรธ",
    "กลัว", "หัวเราะ", "ร้องไห้", "นอนหลับ", "พูด", "ฟัง", "กิน", "ดื่ม", "นั่ง",
    "ยืน", "ร้องเพลง", "ตื่น", "แปรงฟัน", "เรียน", "อ่าน", "เขียน", "ทำงาน",
    "ออกกำลังกาย", "ทนาย", "ครู", "ช่างไฟฟ้า", "พนักงานขาย", "ตำรวจ", "พ่อครัว",
    "วิศวกร", "นิติบุคคล", "ทนายความ", "โจทก์", "จำเลย", "คณะบุคคล", "หมวดครอบครัว",
    "สิทธิมนุษยชน", "ภาษี", "เบี้ยประกัน", "กรรมสิทธิ์", "สิทธิบัตร", "สินสมรส",
    "การแยกกันอยู่", "ฟ้องหย่า", "การเลือกปฏิบัติ", "คดีแพ่ง", "ประมวลกฎหมาย",
    "ผู้พิพากษา", "ผู้ช่วยผู้พิพากษา", "นักโทษ", "คดีอาญา", "ผู้ต้องหา", "ผู้เสียหาย",
    "การประกันภัย", "การกู้ยืมเงิน", "การประกันชีวิต", "สิทธิบัตร", "คำพิพากษา",
    "สัญญา", "นโยบาย", "สมาชิกผู้แทนราษฎร", "รัฐบาล", "รัฐประหาร", "ฝ่ายค้าน",
    "เลือกตั้ง", "โนโหวต", "ดีเบต", "แลนด์สไลด์", "รัฐสภา", "นายกรัฐมนตรี",
    "นักการเมือง", "การเมือง", "อิสรภาพ", "หน้าที่", "เสรีภาพ", "เหตุสุดวิสัย",
    "สิทธิมนุษยชน", "ความเสมอภาค", "ยอมความ", "ทรัพย์สินทางปัญญา", "ภาษีมูลค่าเพิ่ม",
    "ภาษีเงินได้บุคคลธรรมดา", "ภาษีเงินได้นิติบุคคล", "ภาษีเงินได้", "ภาษีหัก ณ ที่จ่าย",
    "พันวิสัย", "ประมวลกฎหมาย", "เครื่องหมายการค้า", "การนัดไกล่เกลี่ย", "ประกาศ",
    "สัญญาค้ำประกัน", "สัญญาฝากขาย", "สัญญา", "สังหาริมทรัพย์", "วินาศภัย", "ลูกหนี้",
    "อินเตอร์เน็ต", "วันแรงงาน", "ผู้รับประกันภัย", "ผู้รับจำนำ", "ผู้รับจำนอง",
    "ผู้รับจ้าง", "ผู้เช่าซื้อ", "ผู้เช่า", "ผู้จำนำ", "ผู้จำนอง", "ผู้กู้", "การประกันสุขภาพ",
    "การประกันภัยรถยนต์", "การประกันภัยทรัพย์สิน", "การประกันภัย", "เบี้ยประกันภัย",
    "ประเทศทาจิสถาน", "นินจา", "นิติกรรม", "นายจ้าง", "ทรัพย์สิน", "สัญญาค้ำประกัน", "สัญญาฝากขาย", "สัญญา", "สังหาริมทรัพย์", "วินาศภัย", "ลูกหนี้",
    "โมฆีกรรม", "โมฆกรรม", "อินเตอร์เน็ต", "วันแรงงาน", "ประเทศลัตเวีย", "ผู้รับประกันภัย",
    "ผู้รับจำนำ", "ผู้รับจำนอง", "ผู้รับจ้าง", "ผู้เช่าซื้อ", "ผู้เช่า", "ผู้จำนำ", "ผู้จำนอง",
    "ผู้กู้", "การประกันสุขภาพ", "การประกันภัยรถยนต์", "การประกันภัยทรัพย์สิน",
    "การประกันภัย", "การประกันชีวิต", "เบี้ยประกันภัย", "ประเทศทาจิสถาน", "นินจา",
    "นิติกรรม", "นายจ้าง", "ทรัพย์สิน", "ยาหม่อง", "ยาล้างแผล", "ยาทาแผล", "ยาพ่นคอ",
    "ยาพ่นจมูก", "ยาดม", "ยาเม็ด", "ยาเม็ดเล็ก", "ยาน้ำ", "มัดจำ", "เงินผ่อน", "เงินกู้",
    "ดอกเบี้ย", "ภาษี", "กล้องวงจรปิด", "นิทาน", "ไถนา", "คนพิการ", "แอปพลิเคชัน",
    "กูเกิ้ลไดร์ฟ", "กูเกิ้ลโครม", "เล็ก", "กูเกิ้ล", "เมาส์", "แป้นพิมพ์", "เว็ปไซต์",
    "บลูทูธ", "ใหญ่", "โน๊ตบุ๊ค", "ตรงกัน", "ไอโอเอส", "แอนดรอยด์", "ยอมความ", "มาตรา",
    "ภาษีมูลค่าเพิ่ม", "ภาษีเงินได้บุคคลธรรมดา", "ภาษีเงินได้นิติบุคคล", "ภาษีเงินได้",
    "ภาษีหัก ณ ที่จ่าย", "พันวิสัย", "ประมวลกฎหมาย", "ประกาศ", "การนัดไกล่เกลี่ย",
    "ทรัพย์สินทางปัญญา", "เครื่องหมายการค้า", "คำสั่ง", "คำพิพากษา", "ความเสมอภาค",
    "คดีอาญา", "คดีหมายเลขดำ", "คดีมีมูล", "คดีแพ่ง", "ข้อบังคับ", "การไกล่เกลี่ย",
    "กฎกระทรวง", "การเลือกปฏิบัติ", "กฎหมายรัฐธรรมนูญ", "หมวดทั่วไป", "เศรษฐกิจพอเพียง",
    "บัตรสวัสดิการแห่งรัฐ", "ฝุ่น pm 2.5", "หน้ากากอนามัย", "อาหาร", "พิซซ่า", "แมคโดนัลด์",
    "เคเอฟซี", "เมเจอร์ ซีนีเพล็กซ์", "เงินประกัน", "บ้านม้าเฟอร์นิเจอร์", "เดอะซันนิวเซ็นเตอร์",
    "แจ่มฟ้าช้อปปิ้งมอลล์", "อนุสาวรีย์พระนางจามเทวี", "กู่ช้างกู่ม้า", "อ่างเก็บน้ำแม่ธิ",
    "วัดพระบาทผาหนาม", "วัดพุทธบาทตากผ้า", "วัดสันป่ายางหลวง", "สะพานทาชมภู", "แก่งก้อ",
    "น้ำตกก้อหลวง", "วัดมหาวัน", "วัดจามเทวี", "วัดพระธาตุหริภุญชัยวรมหาวิหาร", "กิจกรรม",
    "เรียก", "ทักทาย", "คำ", "โล่งใจ", "กด", "หมวดสถานที่", "หมวดบุคคล", "สดใส", "อิสรภาพ",
    "อายุความ", "หน้าที่", "เสรีภาพ", "เหตุสุดวิสัย", "สิทธิมนุษยชน", "สิทธิบัตร", "สิทธิ์",
    "ลหุโทษ", "การล้มละลาย", "ระเบียบ", "นายกรัฐมนตรี", "นักการเมือง", "การเมือง", "ดีเบต",
    "แคนดิเดต", "แลนด์สไลด์", "โนโหวต", "โหวตโน", "นิวโหวตเตอร์", "ขนมเบื้อง", "สีลม",
    "ซอยพัฒน์พงษ์", "กรรม", "อสังหาริมทรัพย์", "ค่าจ้าง", "สัญญาให้โดยเสน่หา", "สัญญาจำนอง",
    "สัญญาจ้างแรงงาน", "สัญญาจ้างทำของ", "รัฐประหาร", "นโยบาย", "ฝ่ายค้าน", "รัฐสภา",
    "สมาชิกผู้แทนราษฎร", "พรรค ส.ว.","เอา","ใกล้","หรือไม่","สาธิต","ปลอดภัย","เอาใส่ใจ","ปิด","ช่วย","ได้"
    ,"วันอังคาร","วันศุกร์","เหลือเท่าไร"  "เช่าทรัพย์", "เช่าซื้อ", "เครียด", "ดูถูก", "เคย", "สดใส", "เซ็ง", "หลุด",
    "เข้าใจ", "เข้าใจผิด", "จ่าย", "อยาก", "ยาก", "ไม่ยาก", "ง่าย", "เรียนหนังสือ",
    "แพ้อาหาร", "ไป", "สอน", "ไม่ดี", "ไปเที่ยว", "ชอบ", "รับผิดชอบ", "ดื่ม",
    "ทำงาน", "ที่ไหน", "ช้า", "ใจเย็น", "อีก", "บิน", "ไม่มี", "ฝาก", "ลง", "ลดลง",
    "ร้องเพลงคาราโอเกะ", "ว่าง", "สว่าง", "กิน", "กินเลี้ยง", "ไม่กิน", "กลับบ้าน",
    "กลับ", "คิด", "คิดลบ", "คิดถึง", "โกนหนวด", "ผีเสื้อ", "เสื้อเชิ้ต", "เสื้อกล้าม",
    "เสื้อกันหนาว", "เสื้อ", "เสื้อแขนยาว", "ตู้เสื้อผ้า", "ล่าง", "ตัด", "อาบน้ำ",
    "แต่งงาน", "แกะ"    "ศูนย์อนุรักษ์ช้างไทย", "กาดกองต้า", "วัดปงสนุก", "หล่มภูเขียว", "สะพานรัษฎาภิเศก",
    "วัดพระธาตุดอยพระฌาน", "โรงไฟฟ้าแม่เมาะ", "วัดเฉลิมพระเกียรติพระจอมเกล้าราชานุสรณ์",
    "พัด", "แขวน", "โรคฝีดาษลิง", "พรรคประชาชน", "พาณิภัค วงศ์พัฒนกิจ (น้องเทนนิส)",
    "รัชนก อินทนนท์ (เมย์)", "กุลวุฒิ วิทิศานต์ (วิว)", "เติร์กเมนิสถาน", "เกาหลีเหนือ",
    "บังกลาเทศ", "มัลดีฟส์", "สหรัฐอาหรับเมิเรตส์", "ติมอร์-เลสเต", "อัฟกานิสถาน",
    "บาห์เรน", "กวม", "ซีเรีย", "วงกลม", "สี่เหลี่ยมผืนผ้า", "สี่เหลี่ยมขนมเปียกปูน",
    "หกเหลี่ยม", "สี่เหลี่ยม", "สามเหลี่ยม", "ข้างหลัง", "คนทำงาน", "ประเทศมาลี",
    "ประเทศกานา", "ปานามา (ประเทศ)", "ประเทศโบลิเวีย", "ประเทศจาไมก้า", "ประเทศเม็กซิโก",
    "ประเทศเอกวาดอร์", "ประเทศชิลี", "ประเทศเปรู", "ทางรัฐ", "ประเทศแทนซาเนีย",
    "ประเทศแซมเบีย", "ประเทศ ดร.คองโก", "ประเทศโมร็อกโก", "ประเทศนามิเบีย",
    "ประเทศแอฟริกาใต้", "ประเทศตูนิเซีย", "ประเทศแองโกลา", "ประเทศมอริเตเนีย",
    "ประเทศบูร์กินาฟาโซ", "ประเทศแกมเบีย", "ประเทศกินี", "ประเทศแคเมอรูน",
    "ประเทศเซเนกัล", "ประเทศโมซักบิก", "ประเทศกาบูเวร์ดี", "กินี-บิสเซา",
    "อีเควทอเรียลกินี", "ไนจีเรีย", "ประเทศโกตดิวัวร์", "กระท่อม", "โชจู", "สุราขาว", "ยาอี", "ยาเลิฟ", "โคเคน", "ฝิ่น", "เฮโรอีน", "ยาบ้า",
    "อายุ", "ส่วนสูง", "น้ำหนัก", "เพลีย", "หัวหน้า", "น้ำใจ", "สาธารณรัฐเช็ก",
    "ประเทศโปรตุเกส", "จอร์เจีย", "ตุรกี", "ยูเครน", "โรมาเนีย", "สโลวาเกีย",
    "เบลเยี่ยม", "เนเธอร์แลนด์", "โปแลนด์", "อังกฤษ", "เซอร์เบีย", "สโลวีเนีย",
    "แอลเบเนีย", "โครเอเชีย", "ฮังการี", "สกอตแลนด์", "สด", "พิธีกร",
    "แมลงก้นกระดก", "นรก", "เทวดา", "พื้นฐาน", "หลักสูตร", "ความลับ", "ทั้งหมด",
    "กล้า", "ว้าว", "กิ๊ก", "ฝ่าย", "ตรงข้าม", "วิษณุ เครืองาม", "พระเยซู",
    "บาป", "กิจกรรม", "คำ", "ขยะ", "ประสบการณ์", "การปราศรัย", "หาเสียง",
    "ยุบสภา", "รัฐประหาร", "นโยบาย", "ฝ่ายค้าน", "สมาชิกผู้แทนราษฎร", "รัฐบาล",
    "รัฐสภา", "นายกรัฐมนตรี", "นักการเมือง", "การเมือง", "ดีเบต (Debate)",
    "แคนดิเดต (Candidate)", "แลนด์สไลด์ (Landslide)", "โนโหวต (No Vote)", "โหวตโน",
    "นิวโหวตเตอร์ (New Votor)", "คืนหมาหอน", "พรรค ส.ว. (ส.ว. 250)", "สลิ่ม",
    "สอบตก (การเมือง)", "ไวไฟ", "เดอะ สตรีท", "ขนมเบื้อง", "สีลม", "ซอยพัฒน์พงษ์",
    "กรรม", "อสังหาริมทรัพย์", "ค่าจ้าง", "สัญญาให้โดยเสน่หา", "สัญญาจำนอง",
    "สัญญาจ้างแรงงาน", "สัญญาจ้างทำของ", "สัญญาค้ำประกัน", "สัญญาฝากขาย",
    "สัญญา", "สังหาริมทรัพย์", "วินาศภัย", "ลูกหนี้", "โมฆีกรรม", "โมฆกรรม",
    "อินเตอร์เน็ต", "วันแรงงาน", "ประเทศลัตเวีย", "ผู้รับประกันภัย",
    "ผู้รับจำนำ", "ผู้รับจำนอง", "ผู้รับจ้าง", "ผู้เช่าซื้อ", "ผู้เช่า",
    "ผู้จำนำ", "ผู้จำนอง", "ผู้กู้", "การประกันสุขภาพ", "การประกันภัยรถยนต์",
    "การประกันภัยทรัพย์สิน", "การประกันภัย", "การประกันชีวิต", "เบี้ยประกันภัย",
    "ประเทศทาจิสถาน", "นินจา", "นิติกรรม", "นายจ้าง", "ทรัพย์สิน", "ทรัพย์",
    "เจ้าหนี้", "เงินทดแทน", "การกู้ยืมเงิน", "กรรมสิทธิ์", "สินสอด", "สินสมรส",
    "การแยกกันอยู่", "ฟ้องหย่า", "การหมั้น", "หมวดครอบครัว", "พนักงานอัยการ",
    "พนักงานสืบสวน", "พนักงานสอบสวน", "ผู้เสียหาย", "ผู้เยาว์", "ผู้พิพากษาอาวุโส",
    "ผู้พิพากษา", "ผู้พิพากษาสมทบ", "ผู้ปกครอง", "ผู้บรรลุนิติภาวะ", "ผู้ต้องหา",
    "ผู้ต้องสงสัย", "ผู้ช่วยผู้พิพากษา", "บุคคลธรรมดา", "นิติบุคคล", "นักโทษ",
    "ทนายความ", "โจทก์", "จำเลย", "คณะบุคคล", "หมวดบุคคล", "หมวดสถานที่",
    "ถ้า", "หรือ", "อิสรภาพ", "อายุความ", "หน้าที่", "เสรีภาพ", "เหตุสุดวิสัย",
    "สิทธิมนุษยชน", "สิทธิบัตร", "สิทธิ์", "ลหุโทษ", "การล้มละลาย", "ระเบียบ",
    "ยอมความ", "มาตรา", "ภาษีมูลค่าเพิ่ม", "ภาษีเงินได้บุคคลธรรมดา",
    "ภาษีเงินได้นิติบุคคล", "ภาษีเงินได้", "ภาษีหัก ณ ที่จ่าย", "พันวิสัย",
    "ประมวลกฎหมาย", "ประกาศ", "การนัดไกล่เกลี่ย", "ทรัพย์สินทางปัญญา",
    "เครื่องหมายการค้า", "คำสั่ง", "คำพิพากษา", "ความเสมอภาค", "คดีอาญา",
    "คดีหมายเลขดำ", "คดีมีมูล", "คดีแพ่ง", "คดี", "ข้อบังคับ", "การไกล่เกลี่ย",
    "กฎกระทรวง", "การเลือกปฏิบัติ", "กฎหมายรัฐธรรมนูญ", "หมวดทั่วไป", "ซูชิ",
    "เศรษฐกิจพอเพียง", "เวอร์ไป", "ประเทศแอลจีเรีย", "สาลี่", "บัตรสวัสดิการแห่งรัฐ",
    "ฝุ่น pm 2.5", "หน้ากากอนามัย", "ยาหม่อง", "ยาล้างแผล", "ยาทาแผล", "ยาพ่นคอ",
    "ยาพ่นจมูก", "ยาดม", "ยาเม็ด", "ยาเม็ดเล็ก", "ยาน้ำ", "มัดจำ", "เงินผ่อน",
    "เงินกู้", "ดอกเบี้ย", "ภาษี", "กล้องวงจรปิด", "นิทาน", "ไถนา", "คนพิการ",
    "แอปพลิเคชั่น", "กูเกิ้ลไดร์ฟ", "กูเกิ้ลโครม", "เล็ก", "กูเกิ้ล", "เมาส์",
    "แป้นพิมพ์", "เว็ปไซต์", "บลูทูธ", "ใหญ่", "โน๊ตบุ๊ค", "ตรงกัน", "ไอโอเอส (IOS)", "แอนดรอย์", "ตรง", "โปรแกรมคอมพิวเตอร์", "แอปพลิเคชัน ซูม",
    "รับจ้าง", "โปรแกรมออฟฟิศ Office", "ไมโครซอฟท์พาวเวอร์พอยท์ (Microsoft PowerPoint)",
    "แบตเตอร์รี่รถยนต์", "แบตเตอรี่โทรศัพท์", "ถุงผ้า", "ถุงพลาสติก", "ถุงกระดาษ", "รูปภาพ",
    "โฟมล้างหน้า", "โลเคชั่นทาผิว", "ครีมทาหน้า", "สบู่เหลว", "น้ำหอม", "แป้งตลับ",
    "ไม้กวาดหยากไย่", "ไม้แขวนเสื้อ", "ไม้ขนไก่", "ไม้กวาด", "สาก", "ครก", "ชักโครก",
    "อ่างล้างหน้า", "ปลั๊กไฟ", "ปริ้นเตอร์", "เรือดำน้ำ", "เรือด่วน", "ตะเกียบ", "หม้อ",
    "กระทะ", "เขียง", "ทัพพี", "ตะไบเล็บ", "กรรไกรตัดเล็บ", "ทิชชู่เปียก", "ผ้าอนามัย",
    "แคบ", "สมาร์ทโฟน", "โทรศัพท์บ้าน", "มือถือแบบกด", "แว่นตากันแดด", "แว่นตา", "กล่อง",
    "กล้องวิดีโอ", "กล้องถ่ายรูป", "ฟืน", "จอบ", "กระดาษคาร์บอน", "หุ่นยนต์", "การ์ตูน",
    "ตุ๊กตา", "ซาลาเปา", "ปาท่องโก๋", "ช้อปปี้ (Shopee)", "โคมไฟ", "ไมโครโฟนตั้งโต๊ะ",
    "ไมโครโฟน", "วิดีโอเทป", "เครื่องเล่นวิดีโอ", "เครื่องพิมพ์ดีด",
    "ธนาคารอาคารสงเคราะห์", "ธนาคารยูโอบี", "ธนาคารทีทีบี", "ธนาคารอิสลาม",
    "ภูเขา", "ลำคลอง", "แม่น้ำ", "เขื่อน", "ศูนย์ราชการเฉลิมพระเกียรติ 80 พรรษา แจ้งวัฒนะ",
    "ผมปลอม", "วัดพระเชตุพนวิมลมังคลารามราช (วัดโพธิ์)", "สะพานลอย", "สะพาน",
    "พิพิธภัณฑ์", "เอเซียทีค เดอะ ริเวอร์ ฟรอนต์", "สวนสยาม", "สวนสัตว์ซาฟารีเวิลด์",
    "รถยนต์ไฮบริด", "รถไฟฟ้าสายสีชมพู", "รถไฟฟ้าสายสีเหลือง",
    "ศูนย์การประชุมแห่งชาติสิริกิติ์", "อิมแพคอารีนาเมืองทองธานี",
    "ศูนย์บริการถ่ายทอดการสื่อสารแห่งประเทศไทย TTRS", "โรงพยาบาลพุทธมณฑล",
    "หนังสือ", "สมุด", "อะไร", "นาฬิกา", "ขอโทษ", "พี่ชาย", "ขอบคุณ", "คุณ",
    "สามี", "ภาษาไทย", "ปากกา", "ปากกาไวท์บอร์ด", "ที่ไหน", "คน", "ขาย", "ราคา", "บน",
    "โต๊ะ", "ญี่ปุ่น", "เกาหลีใต้", "วิทยากร", "สุกี้ ยากี้", "แพง", "เก้าอี้", "เตียง",
    "กระเพาะอาหาร", "จีน", "ขนมจีน", "ปราจีนบุรี", "วันตรุษจีน", "ไฟไหม้", "เครื่องดื่ม",
    "เครื่องดื่มเกลือแร่", "เครื่องดื่มชูกำลัง", "ช่างภาพ", "ช่างไม้", "เช้า",
    "น้ำส้มสายชู", "บ่าย", "เย็น", "นมเย็น", "เย็นตาโฟ", "ตู้เย็น", "มีด", "มาก", "สวัสดี",
    "มีนาคม", "เส้นหมี่", "บะหมี่", "มกราคม", "กุมภาพันธ์", "เมษายน", "พฤษภาคม",
    "มิถุนายน", "กรกฎาคม", "กัมพูชา", "สิงหาคม", "กันยายน", "ตุลาคม", "พฤศจิกายน",
    "ธันวาคม", "วันปีใหม่", "เทควันโด", "วันรัฐธรรมนูญ", "วันแม่แห่งชาติ", "วันครู",
    "วันเด็ก", "วันปิยมหาราช", "วันฉัตรมงคล", "วันมหิดล", "วันพืชมงคล", "วันคริสต์มาส",
    "วันลอยกระทง", "วันนี้", "วันอังคาร", "วันอาทิตย์", "เที่ยง", "วันเสาร์", "ไดโนเสาร์",
    "ทัวร์ลง", "แมลงวัน", "แมลงเม่า", "แมลงหวี่", "แมลงปอ", "หอยแมลงภู่", "แมลงสาบ",
    "ทุกวัน", "เมื่อวานนี้", "เมื่อวานซืน", "สิ้นเดือน", "สัปดาห์ที่สี่ของเดือน", "เดือน",
    "เงินเดือน", "สัปดาห์ที่สามของเดือน", "สัปดาห์ที่สองของเดือน",
    "สัปดาห์ที่หนึ่งของเดือน", "ประจำเดือน", "ไส้เดือน", "ปี", "การบินไทย", "ประเทศไทย",
    "แผนที่ประเทศไทย", "ภูเก็ต", "ผัดไทย", "ภาษามือไทย", "พริกไทย", "เส้นผม", "แชมพู",
    "ช่างทำผม", "แฟน", "สลากกินแบ่งรัฐบาล", "ข่าว", "ข้าวมันไก่", "ข้าวเกรียบ",
    "ข้าวต้มมัด", "ข้าวเกรียบปากหม้อ", "ข้าวเหนียวมะม่วง", "ข้าวหมูแดง", "ข้าวผัด",
    "ข้าวต้ม", "ข้าว", "ข้าวเหนียว", "ข้าวโพด", "หม้อหุงข้าวไฟฟ้า", "วินาที", "นาที",
    "แล้ว", "เมื่อไร", "ลง", "ช้า", "ไป", "อีก", "มี", "ตอบกลับ", "กลับ", "หนึ่งสัปดาห์",
    "หนึ่ง", "หนึ่งแสน", "หนึ่งล้าน", "หนึ่งหมื่น", "หนึ่งพัน", "หนึ่งร้อย", "สอง",
    "สิบสอง", "สิบสาม", "สามร้อย", "สามสิบ", "สาม", "มาสาย", "สนามบิน", "เวลา",
    "เวลาเท่าไร", "พรุ่งนี้", "ดิฉัน", "ผม", "วันหยุด", "ธนาคาร", "เสี่ยง", "สี่",
    "สิบสี่", "สี่สิบ", "สี่ร้อย", "ห้าม", "ห้าร้อย", "ห้าสิบ", "สิบห้า", "ห้า", "หกสิบ",
    "โกหก", "หก", "สิบหก", "เจ็ดร้อย", "เจ็ดสิบ", "สิบเจ็ด", "เจ็ด", "แปด", "สิบแปด",
    "แปดสิบ", "แปดร้อย", "เก่า", "เก้าร้อย", "เก้าสิบ", "สิบเก้า", "เก้า", "มาเก๊า",
    "ยี่สิบ", "สิบ", "สิบเอ็ด", "ดีเยี่ยม", "เรียบร้อย", "อร่อย", "ไม่อร่อย", "ร้อยละ",
    "เดิมพัน", "เยอรมนี", "พี่น้อง", "รัสเซีย", "หนี่งแสน", "บางแสน", "นาน", "วิเคราะห์",
    "มหาวิทยาลัยจุฬาลงกรณ์", "มหาวิทยาลัยมหิดล", "มหาวิทยาลัยสารคาม",
    "มหาวิทยาลัยขอนแก่น", "อาจารย์", "ปรึกษา", "พ่อค้า", "แพ้อาหาร", "พ่อครัว", "พ่อ",
    "คุณตา", "แม่กำปอง", "แม่", "แม่ฮ่องสอน", "แม่ค้า", "ปลูก", "ลูกจ้าง", "ลูก",
    "มดลูก", "ปู่", "หย่า", "ย้าย", "ตัวอย่าง", "อย่างไร", "ย่า", "พี่สาว", "พี่", "น้อง",
    "ผู้ชาย", "ผู้หญิง", "เด็ก", "สอน", "ผู้ใหญ่", "ทำงาน", "ทำ", "จ่าย", "ทำไม", "นี่", "เดี๋ยวนี้", "เมื่อกี้นี้", "ไม่ดี", "พบกัน",
    "นั่น", "เขา", "ลด", "โหลด", "ยาก", "อยาก", "ไม่อยาก", "ง่าย", "ราคาแพง",
    "เที่ยงคืน", "เที่ยงวัน", "น้ำ", "โค้ก", "น้ำชา", "น้ำเต้าหู้", "โซดา",
    "น้ำแข็ง", "รุ้งกินน้ำ", "ร้อน", "ใจร้อน", "หนาว", "เสื้อกันหนาว",
    "อากาศ", "เครื่องปรับอากาศ", "รถโดยสารปรับอากาศ", "ครั้งเดียว",
    "ดอกไม้", "กะหล่ำดอก", "ดอกแค", "สวย", "หมู่บ้าน", "ทะเบียนบ้าน", "บ้าน",
    "โทรศัพท์", "ห้องครัว", "เนื้ิอวัว", "เนื้อหมู", "น้ำตกเนื้อ", "เกาเหลาเนื้อวัว",
    "รถยนต์", "ใบขับขี่รถยนต์", "รถยนต์ไฟฟ้า", "คุย", "ผลไม้", "ต้นไม้",
    "ไม่", "ไม่เคย", "ไม่รู้", "ไม่กิน", "ไม่มี", "ฝนตก", "หิมะ", "ออกกำลังกาย",
    "กำลังใจ", "ตกลง", "ตก", "แตก", "ตกใจ", "น้ำตก", "พลาสติก", "ทอง",
    "ตั๋ว", "ซิ่", "ซิ่ง", "เลื่อน", "ฟุ่มเฟือย", "เฉพาะ", "กด", "แชร์",
    "ธุระ", "นั่ง", "นอน", "อ่าน", "ใคร", "ว่ายน้ำ", "จำเป็น", "จำ", "จดจำ",
    "จำนำ", "ลดลง", "เพิ่มขึ้น", "ได้ยิน", "มอง", "มองดู", "สมอง", "เห็น",
    "เห็นด้วย", "รู้", "ไม่รู็", "รู้จัก", "เสร็จ", "กะทันหัน", "เผ็ด",
    "แกงเผ็ด", "ดัง", "กลางคืน", "ค่อย", "ออก", "ลาออก", "แยก", "ลุง",
    "ป้า", "ป้าย", "สูง", "รัก", "น่ารัก", "โกรธ", "กระดาษ", "เขียน",
    "อันตราย", "แผ่นดิน", "ถาม", "คำถาม", "ดีใจ", "เชียงใหม่", "กรุงเทพ",
    "ถนน", "สุขุมวิท", "ครอบครัว", "สบายดี", "ภาษาอังกฤษ", "งด",
    "บัตรเครดิต", "ต้องการ", "คู่", "หน้าต่าง", "ว่าง", "พัก", "พักผ่อน",
    "เต็ม", "โรงแรม", "รถไฟ", "รถไฟฟ้า", "บุหรี่", "เครื่องบิน", "รู้สึก",
    "หมี", "ห้องน้ำ", "อยู่", "ฉัน", "คุณ (1)", "เขา (1)", "ถนนคนเดินวันศุกร์",
    "ถนนคนเดินพิษณุโลก", "ถนนคนเดินพะเยา", "หนังสือเดินทาง",
    "ถนนคนเดินประตูท่าแพ", "วัดพระนั่งเดิน", "ทางเดินเท้า",
    "พระที่นั่งอนันตสมาคม", "วัดพระยืน", "พระที่นั่งวิมานเมฆ", "หนอน",
    "เลบานอน", "แน่นอน", "พูดมาก", "ถ้ำหลวงขุนน้ำนางนอน", "พูดอย่างลำบากใจ",
    "พูดรายงานการประชุม", "พูดไม่ได้เลย", "พูดไม่ชัด", "เจ้าชู้",
    "พูดตรงๆ", "พูดอ้อมค้อมวกไปวนมา", "สลับกัน", "หูฟังมีสาย",
    "หูฟังไร้สาย", "กระดูก", "อุปการะเลี้ยงดู", "ดูถูก", "ดูคาติ Ducati",
    "กล้องดูดาว", "ตกขาว", "ฤดู", "บูธ", "รายงาน", "กิ๊ก (1)", "ข้อมูล",
    "กระทรวงพลังงาน", "คิดลบ", "เราเตอร์", "วิธี", "ชีวิต", "น่ารังเกียจ",
    "กระทรวงการพัฒนาสังคมและความมั่นคงของมนุษย์", "แพะ", "อ่าง",
    "ตามสั่ง", "ปริญญาเอก", "ปริญญาตรี", "ปริญญาโท", "สามย่านมิตรทาวน์",
    "ตอนนี้", "กมลา แฮร์ริส", "ดอนัลด์ ทรัมป์", "ทิศใต้", "ทิศตะวันออก",
    "ทิศตะวันตก", "ทิศเหนือ", "ประเภท", "ใบหน้า", "ขนาด", "ภาคกลาง",
    "สินค้า", "ย่อ", "ไอร์แลนด์", "ค้อน", "สุขภาพ", "เอ็มเค (MK)",
    "ชุมชน", "อาหาร", "พิซซ่า (Pizza)", "แมคโดนัลด์ (MCDONALDS)", "เคเอฟซี",
    "เมเจอร์ ซีนีเพล็กซ์ (Major Cineplex)", "รายเดือน", "กฏ", "เงินประกัน",
    "บ้านม้าเฟอร์นิเจอร์", "เดอะซันนิวเซ็นเตอร์", "แจ่มฟ้าช้อปปิ้งมอลล์",
    "อนุสาวรีย์พระนางจามเทวี", "กู่ช้างกู่ม้า", "อ่างเก็บน้ำแม่ธิ",
    "วัดพระบาทผาหนาม", "วัดพุทธบาทตากผ้า", "วัดสันป่ายางหลวง",
    "สะพานทาชมภู", "แก่งก้อ", "น้ำตกก้อหลวง", "วัดมหาวัน", "วัดจามเทวี",
    "วัดพระธาตุหริภุญชัยวรมหาวิหาร", "อุโมงค์รถไฟขุนตาล",
    "อุทยานแห่งชาติดอยขุนตาล", "ฮะจิบัง ราเมน", "วัดดอยติ",
    "อินทนิล คอฟฟี่ (Inthanin Coffee)", "สตาร์บัค (Starbucks)",
    "นายโชคชัย วิเชียรชัยยะ", "ผู้อาวุโส", "อีฟ ปานเจริญ (ปาล์มมี่)",
    "กรรชัย กำเนิดพลอย (หนุ่ม)", "ไพบูลย์ แสงเดือน", "เกาะสมุย",
    "เดชอิศม์ ขาวทอง", "ดร. เฉลิมชัย ศรีอ่อน", "ไฟแนนซ์", "กัน จอมพลัง",
    "ทนายเดชา", "ภูมิธรรม เวชยชัย", "ปลาฉลาม", "อุทยานแห่งชาติน้ำตกแจ้ซ้อน",
    "บ้านป่าเมี้ยง", "วัดหลวงพ่อเกษมลำปาง", "กาดทุ่งเกวียน",
    "สถานีรถม้า", "วัดศรีชุม", "วัดศรีรองเมือง", "วัดพระธาตุจอมปิง",
    "พิพิธภัฑ์เซรามิกธนบดี", "วัดพระธาตุลำปางหลวง", "วัดเจดีย์ซาวหลัง",
    "วัดพระแก้วดอนเต้าสุชาดาราม",    "พริษฐ์ ชิวารักษ์", "อุซเบกิสถาน (ประเทศ)", "เฮติ (ประเทศ)", "ณัฏฐา มหัทธนา (พรรคก้าวไกล)",
    "น้ำตกเต่าดำ", "ริมน้ำปิง", "บ่อน้ำพุร้อนพระร่วง", "บ่อน้ำสีฟ้า", "โรงนาคาแฟกำแพงเพชร",
    "บ้านริมธารปูกะแหยม", "ประเพณีสารทไทยกล้วยไข่", "อุทยานแห่งชาติคลองลาน",
    "อุทยานแห่งชาติแม่วงก์", "โรงงานทำเฉาก๊วยชากังราว", "ตลาดย้อนยุคนครชุม",
    "วัดพระบรมธาตุนครชุม", "ศาลพระอิศวร", "ศาลเจ้าพ่อเสือ", "วัดเสด็จ(กำแพงเพชร)",
    "วัดคูยาง", "วัดเทพโมฬี", "หลวงพ่อเพชร วัดบาง", "ศาลหลักเมืองกำแพงเพชร",
    "อุทยานประวัติศาสตร์สตร์กำแพงเพชร", "บ้านไร่รั้วไทรงาม", "ทุ่งทานตะวัน (พิษณุโลก)",
    "วัดเสนาสน์", "บึงตะเคร็ง", "บ้านมุง(พิษณุโลก)", "ภูลมโล(พิษณุโลก)",
    "อุทยานแห่งชาติน้ำตกชาติตระการ", "วัดทับยายเชียง", "วัดบัวหลวง(พิษณุโลก)",
    "วัดราชศิริหิรัญยาราม", "ล่องแก่งลำน้ำเข็ก(พิษณุโลก)", "ก๋วยเตี๋ยวห้อยขา(พิษณุโลก)",
    "ถนนคนเดิน(พิษณุโลก)", "ศาลสมเด็จพระนเรศวรมหาราช", "วัดจุฬามณี",
    "สวนพฤกษศาสตร์บ้านร่มเกล้า", "สวนบัวอมรรัตน์", "วัดพระศรีรัตนมหาธาตุวรมหาวิหาร",
    "สมบูรณ์แบบ", "ขาดทุน", "โอมาน(ประเทศ)", "คีร์กีซสถาน(ประเทศ)", "ทัวร์ลง",
    "ไมโครซอฟท์ พาวเวอร์พอยต์(Microsoft PowerPoint)", "ไมโครซอฟท์ เอกซ์เซล(Microsoft Excel)",
    "ไมโครซอฟท์ เวิร์ด(Microsoft Word)", "โฆษณา", "หิมะ", "อาหรับเอมิเรตต์(ประเทศ)",
    "ลักเซมเบิร์ก(ประเทศ) (ท่าที่2)", "ลักเซมเบิร์ก(ประเทศ) (ท่าที่1)", "บ่อสิบสอง",
    "ถนนคนเดินพะเยา", "ทุ่งบัวแดง กว๊านพะเยา", "วัดศรีชุม พระเจ้าทันใจ",
    "วัดผาธรรมนิมิต", "เจดีย์พระธาตุดอยหนอก", "ดอยหลวง ดอยหนอก", "บ้านสิงห์ธรรม",
    "วัดพระนั่งดิน", "วัดนันตาราม", "วัดติโลกอาราม", "วัดศรีโคมคำ พระเจ้าตนหลวง",
    "วัดพระธาตุจอมทอง", "กาดเช้าริมกว๊านพะเยา", "วัดนาลโยทิพยาราม", "อุทยานแห่งชาติภูซาง",
    "วนอุทยานภูลังกา", "อนุเสาวรีย์พ่อขุนงำเมือง", "กว๊านพะเยา", "เครื่องปั่นดิน",
    "อุทยานประวัติศาสตร์สุโขทัย", "อุทยานประวัติศาสตร์ ศรีสัชนาลัย",
    "ถั่วทอดลอนศิลป อ.ศรีสำโรง", "วัดมหาธาตุ เมืองเก่า", "วัดทุ่งเสลี่ยมหลวงพ่อศิลา",
    "บ้านนาตันจั่น ศรีสัชนาลัย (ข้าวเปิ๊บ ยายเครื่อง)", "สวนสัตด์สนามบินสุโขทัย",
    "น้ำตกสายรุ้ง", "วัดช้างล้อม", "วัดพิพัฒน์มาดล", "ดอยเขามุ้ง",
    "ถ้ำเจ้ารามถ้ำพระราม", "ตลาดริมยม", "อุทยานแห่งชาติรามคำแหง", "พระแม่ย่า",
    "เทหลวงสุโขทัย", "เกรงใจ", "คลองถม", "พาหุรัด", "ยินดีด้วย", "ดี",
    "ซ้ำ (ท่าที่2)", "ซ้ำ", "ศพ", "วัดโบสถ์ (อำเภอ)", "วังทอง (อำเภอ)",
    "พรหมพิราม (อำเภอ)", "บางระกำ (อำเภอ)", "บางกระทุ่ม (อำเภอ)",
    "เนินมะปราง (อำเภอ)", "นครไทย (อำเภอ)", "ชาติตระการ (อำเภอ)",
    "เมืองพิษณุโลก (อำเภอ)", "เดิน", "ตัดสิน (ท่าที่2)", "เปลี่ยน", "สังคม",
    "ประกัน", "เขิน", "ยุ่ง", "ประชด", "ตายแล้ว (ท่าที่2)", "ตายแล้ว", "เสียหาย",
    "ห้างฉัตร (อำเภอ)", "เสริมงาม (อำเภอ)", "สบปราบ (อำเภอ)", "วังเหนือ (อำเภอ)",
    "เมืองปาน (อำเภอ)", "แม่เมาะ (อำเภอ)", "แม่พริก (อำเภอ)", "แม่ทะ (อำเภอ)",
    "เถิน (อำเภอ)", "แจ้ห่ม (อำเภอ)", "งาว (อำเภอ)", "เกาะคา (อำเภอ)",
    "เมืองลำปาง (อำเภอ)", "กังวล", "ศูนย์ราชการแจ้งวัฒนะ", "ข่าว", "ผอม",
    "อ้วน", "เพิ่มพูน ชิดชอบ", "งก", "อวดดี", "อวด", "ไข่ดาว (ท่าที่2)", "ไข่ดาว",
    "ไข่เจียว (ท่าที่2)", "ไข่เจียว", "ไข่ (ท่าที่2)", "กาตาร์-(ประเทศ)",
    "กรีซ-(ประเทศ)", "โรงพยาบาลส่งเสริมสุขภาพตำบล", "สถานีอนามัย",
    "เยเมน-(ประเทศ)", "กรมอนามัย", "ผ้าป่า", "นักศึกษา", "นักเรียน", "คู่",
    "กทปส.", "กล้วยทอด", "ช้า", "นาน(ท่าที่2)", "ช้า(ท่าที่2)", "ฮามาส", "สีส้ม",
    "ปาเลสไตน์ (ประเทศ)", "พิเชษฐ์ เชื้อเมืองพาน", "ปดิพัทธ์ สันติภาดา (หมออ๋อง)",
    "สยามพารากอน", "นกขมิ้นน้อยปีกสีเรียบ (Great Iora)", "นกขมิ้นน้อยธรรมดา (Common Iora)",
    "นกขมิ้นน้อยสีเขียว (Green Iora)", "กลุ่มนกขมิ้นน้อย (Iora)",
    "นกกางเขนบ้าน (Oriental Magpie Robin)", "นกยางกรอก (pond herons)",
    "นกกะรางหัวขวาน (Eurasian Hoopoe)", "กลุ่มนกเขา (doves and pigeons)",
    "นกอีแพรดแถบอกดำ (Malaysian Pied Fantail)", "นกกิ้งโครงคอดำ (Black-collared Starling)",
    "นกเอี้ยงด่าง (Siamese Pied Starling)", "นกสีชมพูสวน (Scarlet-backed Flowerpecker)",
    "กลุ่มนกกินปลี (sunbirds)", "นกกระจาบทอง (Asian Golden Weaver)",
    "นกกระติ๊ดขี้หมู (Scaly-breasted Munia)", "นกกระจอกใหญ่ (House Sparrow)",
    "นกกระจอกบ้าน (Eurasian Tree Sparrow)", "กลุ่มนกกระจอกและนกกระติ๊ด",
}

def get_lemma(word):
    lemmas = {
        "มาช้า": "มาสาย",
        "ขับ": "ขับรถ",
        "ทาน": "กิน",
        "ไม่ทาน": "ไม่กิน",
        "ผม ": "ผม (เส้นผม)",
        "การสาธิต": "สาธิต",
        "ความปลอดภัย": "ปลอดภัย",
        "ท่องเที่ยว": "เที่ยว",
        # สามารถเพิ่ม lemma ได้ตามต้องการ
    }
    return lemmas.get(word, word)

def reorder_to_tsl(words):
    # ลบคำที่ไม่จำเป็นออก
    simplified_sentence = [word for word in words if word not in ['คือ', 'เป็น', 'จะ', 'ก็', 'ที่', 'นั้น', 'นี้', ]]
    # คำที่เกี่ยวข้องกับเวลา
    time_words = ['วันนี้', 'พรุ่งนี้', 'เมื่อวาน', 'ตอนเช้า', 'ตอนเย็น', 'หนึ่งสัปดาห์หน้า']
    time_elements = [word for word in simplified_sentence if word in time_words]
    non_time_elements = [word for word in simplified_sentence if word not in time_words]
    # นำคำที่เกี่ยวข้องกับเวลาไปไว้ก่อน
    reordered_sentence = time_elements + non_time_elements
    return reordered_sentence

def process_sentence(sentence):
    # กำหนดคำสำหรับ tokenizer
    custom_words = set(thai_words())
    custom_words.discard("อี")
    custom_words.discard("อีกที")
    custom_words.discard("เตียงคู่")
    custom_words.discard("บอกทาง")
    custom_words.discard("ความช่วยเหลือ")
    custom_words.discard("หาอาหาร")
    custom_words.discard("คนญี่ปุ่น")
    custom_words.discard("ราคาแพง")
    custom_words.discard("อาหารจีน")
    custom_words.discard("เวลาว่าง")
    custom_words.discard("กินข้าว")
    custom_words.discard("อ่านหนังสือ")
    custom_words.discard("เที่ยงตรง")
    custom_words.discard("ทำอาหาร")
    custom_words.discard("แต่เช้า")
    custom_words.discard("เดินเล่น")
    custom_words.discard("ฤดูหนาว")
    custom_words.discard("คุณพ่อ")
    custom_words.discard("ทานข้าว")
    custom_words.discard("มองเห็น")
    custom_words.discard("ตัดผม")
    custom_words.discard("คนไทย")
    custom_words.discard("ที่อยู่")
    custom_words.discard("หรือยัง")
    custom_words.discard("มีครอบครัว")
    custom_words.discard("เขียนหนังสือ")
    custom_words.discard("ยืดตัว")
    custom_words.discard("ไม้ดอก")
    custom_words.discard("ตั๋วไปกลับ")
    custom_words.discard("หรือไม่")
    custom_words.discard("เข็มขัดนิรภัย")
    custom_words.discard("รัดเข็มขัด")
    custom_words.discard("เที่ยวบิน")
    custom_words.discard("ใช้เวลานาน")
    custom_words.discard("ใช้เวลา")
    custom_words.discard("เป็นเวลา")
    custom_words.discard("ดีมาก")
    custom_words.add("เมื่อวานนี้")
    custom_words.add("หนึ่งสัปดาห์หน้า")
    custom_words.add("หนึ่งสัปดาห์ที่แล้ว")
    custom_words.add("ประเทศไทย")
    custom_words.add("กี่โมง")
    custom_words.add("มาช้า")
    custom_words.add("ถนนคนเดิน")
    custom_words.add("วันปีใหม่")
    custom_words.add("วันเสาร์")
    custom_words.add("ฝนตกหนัก")
    custom_words.add("ไม่มี")
    custom_words.add("ร้องเพลงคาราโอเกะ")
    custom_words.add("ไม่ทาน")
    custom_words.add("เสร็จแล้ว")
    custom_words.add("ไม่ดี")
    custom_words.add("โกนหนวด")
    custom_words.add("สีขาว")
    custom_words.add("สีดำ")
    custom_words.add("เสื้อยืด")
    custom_words.add("เกาะสมุย")
    custom_words.add("เอาใส่ใจ")
    custom_words.add("วันอังคาร")
    custom_words.add("วันศุกร์")
    custom_words.add("วันศุกร์")
    custom_words.add("เหลือเท่าไร")
    custom_words.add("เหลือ")
    custom_words.add("เช็คอิน")
    custom_words.add("ได้ไหม")
    custom_words.add("ลิซ่า")
    custom_words.add("สวนลุมพินี")
    custom_words.add("อีก")
    custom_words.add("อีกรอบ")
    custom_words.add("ไม่ดี")
    custom_words.add("ไกลมาก")
    custom_words.add("รถไฟความเร็วสูง")
    stopwords = set(thai_stopwords())

    stopwords.add("กี่")
    stopwords.add(" ")
    stopwords.add("ไหม")
    stopwords.add("ทำการ")
    stopwords.discard("ขึ้น")
    stopwords.discard("อยู่")
    stopwords.discard("ตรง")
    stopwords.discard("มา")
    stopwords.discard("หรือยัง")
    stopwords.discard("ยัง")
    stopwords.discard("ใหญ่")
    stopwords.discard("ตัว")
    stopwords.discard("หรือไม่")
    stopwords.discard("สั้น")
    stopwords.discard("ช่วย")
    stopwords.discard("ใช้")
    stopwords.discard("ประมาณ")
    stopwords.discard("ถึง")
    stopwords.discard("เหลือ")
    stopwords.discard("ต้อง")
    stopwords.discard("ให้")
    stopwords.discard("ถูก")
    stopwords.discard("บอก")
    stopwords.discard("ทาง")
    stopwords.discard("อีก")
    stopwords.discard("รอบ")
    stopwords.discard("รับ")

    custom_tokenizer = Tokenizer(custom_words)
    tokens = custom_tokenizer.word_tokenize(sentence)

    # กรอง stopwords (ยกเว้น important_words)
    filtered_tokens = [token for token in tokens if token not in stopwords or token in important_words]
    # ทำ lemmatization
    lemmatized_tokens = [get_lemma(token) for token in filtered_tokens]
    # จัดเรียงคำใหม่
    reordered_sentence = reorder_to_tsl(lemmatized_tokens)

    return reordered_sentence

    # Process all sentences in the list
travel_sentences_train = [process_sentence(sentence) for sentence in sentences]

 # Output the results
for i, sentence in enumerate(travel_sentences_train):
    print(f"Original: {sentences[i]}")
    print(f"Processed: {sentence}\n")
# Out:
# Original: ฉันต้องการจองสองที่นั่งถึงกรุงเทพ
# Processed: ['ฉัน', 'ต้องการ', 'จอง', 'สอง', 'ที่นั่ง', 'ถึง', 'กรุงเทพ']
#
# Original: คุณต้องการตั๋วเที่ยวเดียวหรือไปกลับ
# Processed: ['คุณ', 'ต้องการ', 'ตั๋ว', 'เที่ยว', 'หรือ', 'ไป', 'กลับ']
#
# Original: ตั๋วไปกลับราคาเท่าไร
# Processed: ['ตั๋ว', 'ไป', 'กลับ', 'ราคา', 'เท่าไร']
#
# Original: คุณต้องการจ่ายเงินสดหรือบัตรเครดิต
# Processed: ['คุณ', 'ต้องการ', 'จ่าย', 'เงินสด', 'หรือ', 'บัตรเครดิต']
#
# Original: ฉันขอดูตั๋วและหนังสือเดินทางของคุณได้ไหม
# Processed: ['ฉัน', 'ดู', 'ตั๋ว', 'หนังสือเดินทาง', 'คุณ', 'ได้ไหม']
#
# Original: วันนี้มีใครไปกับคุณไหม
# Processed: ['วันนี้', 'มี', 'ใคร', 'ไป', 'คุณ']
#
# Original: ฉันเอาสัมภาระมาสองชิ้น
# Processed: ['ฉัน', 'เอา', 'สัมภาระ', 'มา', 'สอง', 'ชิ้น']
#
# Original: คุณอยากจะนั่งใกล้หน้าต่างหรือไม่
# Processed: ['คุณ', 'อยาก', 'นั่ง', 'ใกล้', 'หน้าต่าง', 'หรือ', 'ไม่']
#
# Original: เครื่องบินไปที่เกาะสมุยตั๋วหมดแล้ว
# Processed: ['เครื่องบิน', 'ไป', 'เกาะสมุย', 'ตั๋ว', 'หมด', 'แล้ว']
#
# Original: คุณต้องการตั๋วเวลาบ่ายสองหรือสี่โมง
# Processed: ['คุณ', 'ต้องการ', 'ตั๋ว', 'เวลา', 'บ่าย', 'สอง', 'หรือ', 'สี่', 'โมง']
#
# Original: หมายเลขที่นั่งของคุณคืออะไร
# Processed: ['หมายเลข', 'ที่นั่ง', 'คุณ', 'อะไร']
#
# Original: โปรดเอาใส่ใจกับการสาธิตความปลอดภัยบนเครื่องบินสั้นๆ นี้
# Processed: ['โปรด', 'เอาใส่ใจ', 'สาธิต', 'ปลอดภัย', 'บน', 'เครื่องบิน', 'สั้น']
#
# Original: ช่วยปิดโทรศัพท์มือถือและอุปกรณ์อิเล็กทรอนิกส์อื่นๆ
# Processed: ['ช่วย', 'ปิด', 'โทรศัพท์มือถือ', 'อุปกรณ์', 'อิเล็กทรอนิกส์']
#
# Original: กรุณารัดเข็มขัดนิรภัย
# Processed: ['กรุณา', 'รัด', 'เข็มขัด', 'นิรภัย']
#
# Original: เที่ยวบินใช้เวลานานเท่าไร
# Processed: ['เที่ยว', 'บิน', 'ใช้', 'เวลา', 'นาน', 'เท่าไร']
#
# Original: คุณต้องการอาหารหรือเครื่องดื่มอะไรไหม
# Processed: ['คุณ', 'ต้องการ', 'อาหาร', 'หรือ', 'เครื่องดื่ม', 'อะไร']
#
# Original: คุณต้องการดื่มชาหรือกาแฟ
# Processed: ['คุณ', 'ต้องการ', 'ดื่ม', 'ชา', 'หรือ', 'กาแฟ']
#
# Original: ฉันอยากดื่มโค้กโดยไม่ใส่น้ำแข็ง
# Processed: ['ฉัน', 'อยาก', 'ดื่ม', 'โค้ก', 'ไม่', 'ใส่', 'น้ำแข็ง']
#
# Original: เครื่องบินจะลงจอดในอีกประมาณสิบห้านาที
# Processed: ['เครื่องบิน', 'ลง', 'จอด', 'อีก', 'ประมาณ', 'สิบห้า', 'นาที']
#
# Original: เวลาที่ท่าอากาศยานสนามบินดอนเมืองตอนนี้คือสิบนาฬิกาห้านาที
# Processed: ['เวลา', 'ท่าอากาศยาน', 'สนามบิน', 'ดอนเมือง', 'ตอนนี้', 'สิบ', 'นาฬิกา', 'ห้า', 'นาที']
#
# Original: คุณมีสัญชาติอะไร
# Processed: ['คุณ', 'มี', 'สัญชาติ', 'อะไร']
#
# Original: ฉันเป็นคนไทย
# Processed: ['ฉัน', 'คน', 'ไทย']
#
# Original: ฉันขอดูหนังสือเดินทางของคุณได้ไหม
# Processed: ['ฉัน', 'ดู', 'หนังสือเดินทาง', 'คุณ', 'ได้ไหม']
#
# Original: นี่คือหนังสือเดินทางของฉัน
# Processed: ['นี่', 'หนังสือเดินทาง', 'ฉัน']
#
# Original: คุณมาทำงานหรือเที่ยว
# Processed: ['คุณ', 'มา', 'ทำงาน', 'หรือ', 'เที่ยว']
#
# Original: ทำไมคุณอยากไปประเทศสหรัฐอเมริกา
# Processed: ['ทำไม', 'คุณ', 'อยาก', 'ไป', 'ประเทศ', 'สหรัฐอเมริกา']
#
# Original: มีเที่ยวบินไปเกาหลีใต้ เพราะฉันอยากไปเที่ยวกับครอบครัว
# Processed: ['มี', 'เที่ยว', 'บิน', 'ไป', 'เกาหลีใต้', 'ฉัน', 'อยาก', 'ไปเที่ยว', 'ครอบครัว']
#
# Original: ฉันเดินทางไปทำงาน
# Processed: ['ฉัน', 'เดินทาง', 'ไป', 'ทำงาน']
#
# Original: ฉันไปเยี่ยมครอบครัว
# Processed: ['ฉัน', 'ไป', 'เยี่ยม', 'ครอบครัว']
#
# Original: ฉันจะไปอยู่บ้านเพื่อนที่ชลบุรีเวลาหนึ่งเดือน
# Processed: ['ฉัน', 'ไป', 'อยู่', 'บ้าน', 'เพื่อน', 'ชลบุรี', 'เวลา', 'หนึ่ง', 'เดือน']
#
# Original: ฉันสามารถจองโรงแรมได้หรือไม่
# Processed: ['ฉัน', 'สามารถ', 'จอง', 'โรงแรม', 'ได้', 'หรือ', 'ไม่']
#
# Original: สวัสดี ขอถามหน่อยว่าโรงแรมของคุณราคาเท่าไหร่
# Processed: ['สวัสดี', 'ถาม', 'โรงแรม', 'คุณ', 'ราคา']
#
# Original: ฉันต้องการเพียงหนึ่งห้องเท่านั้น
# Processed: ['ฉัน', 'ต้องการ', 'หนึ่ง', 'ห้อง']
#
# Original: ฉันจะอยู่เป็นเวลาหนึ่งสัปดาห์
# Processed: ['ฉัน', 'อยู่', 'เวลา', 'หนึ่ง', 'สัปดาห์']
#
# Original: ฉันต้องการห้องตั้งแต่วันอังคารถึงวันศุกร์
# Processed: ['ฉัน', 'ต้องการ', 'ห้อง', 'วันอังคาร', 'ถึง', 'วันศุกร์']
#
# Original: มีห้องว่างที่เป็นเตียงคู่เหลือเท่าไร
# Processed: ['มี', 'ห้อง', 'ว่าง', 'เตียง', 'คู่', 'เหลือเท่าไร']
#
# Original: ฉันจะอยู่ที่กรุงเทพอีกนาน
# Processed: ['ฉัน', 'อยู่', 'กรุงเทพ', 'อีก', 'นาน']
#
# Original: ฉันต้องการอยู่พักแค่สองคน
# Processed: ['ฉัน', 'ต้องการ', 'อยู่', 'พัก', 'สอง', 'คน']
#
# Original: โรงแรมเหลือห้องสุดท้าย ต้องการจองไว้มั้ย
# Processed: ['โรงแรม', 'เหลือ', 'ห้อง', 'สุดท้าย', 'ต้องการ', 'จอง']
#
# Original: ฉันต้องเดินไปที่ไหนเพื่อเข้าห้องน้ำ
# Processed: ['ฉัน', 'ต้อง', 'เดิน', 'ไป', 'ที่ไหน', 'เข้า', 'ห้องน้ำ']
#
# Original: ฉันได้ทำการจองไว้แล้วตอนนี้ต้องการเช็คอิน
# Processed: ['ฉัน', 'ได้', 'จอง', 'แล้ว', 'ตอนนี้', 'ต้องการ', 'เช็คอิน']
#
# Original: ฉันขอดูบัตรประชาชนของคุณได้ไหม
# Processed: ['ฉัน', 'ดู', 'บัตรประชาชน', 'คุณ', 'ได้ไหม']
#
# Original: นี่คือกุญแจห้องของคุณ
# Processed: ['นี่', 'กุญแจ', 'ห้อง', 'คุณ']
#
# Original: ฉันลืมบัตรเครดิต ขอเป็นจ่ายเงินสดแทน
# Processed: ['ฉัน', 'ลืม', 'บัตรเครดิต', 'จ่าย', 'เงินสด', 'แทน']
#
# Original: ฉันขอดูแผนที่ได้ไหม
# Processed: ['ฉัน', 'ดู', 'แผนที่', 'ได้ไหม']
#
# Original: ฉันสามารถชำระเงินด้วยบัตรเครดิตได้หรือไม่
# Processed: ['ฉัน', 'สามารถ', 'ชำระเงิน', 'บัตรเครดิต', 'ได้', 'หรือ', 'ไม่']
#
# Original: คุณมีพนักงานดูแลกระเป๋าหรือไม่
# Processed: ['คุณ', 'มี', 'พนักงาน', 'ดูแล', 'กระเป๋า', 'หรือ', 'ไม่']
#
# Original: ช่วยเรียกรถแท็กซี่ให้ฉันหน่อยได้ไหม
# Processed: ['ช่วย', 'เรียก', 'รถแท็กซี่', 'ให้', 'ฉัน', 'ได้ไหม']
#
# Original: เสื้อนี่ราคาเท่าไร
# Processed: ['เสื้อ', 'นี่', 'ราคา', 'เท่าไร']
#
# Original: คุณมีเสื้อราคาถูกลงอีกไหม
# Processed: ['คุณ', 'มี', 'เสื้อ', 'ราคา', 'ถูก', 'ลง', 'อีก']
#
# Original: คุณมีสินค้านี้หรือไม่
# Processed: ['คุณ', 'มี', 'สินค้า', 'หรือ', 'ไม่']
#
# Original: คุณรู้หรือไม่ว่ามีที่อื่นขายหรือไม่?
# Processed: ['คุณ', 'รู้', 'หรือ', 'ไม่', 'มี', 'ที่อื่น', 'ขาย', 'หรือ', 'ไม่', '?']
#
# Original: คุณพูดภาษาอังกฤษได้ไหม
# Processed: ['คุณ', 'พูด', 'ภาษาอังกฤษ', 'ได้ไหม']
#
# Original: ฉันชื่อเล่นว่าลิซ่า
# Processed: ['ฉัน', 'ชื่อเล่น', 'ลิซ่า']
#
# Original: ฉันดีใจที่ได้พบคุณ
# Processed: ['ฉัน', 'ดีใจ', 'ได้', 'พบ', 'คุณ']
#
# Original: คุณมาจากที่ไหน
# Processed: ['คุณ', 'มาจาก', 'ที่ไหน']
#
# Original: คุณจะอยู่ภูเก็ตนานเท่าไร
# Processed: ['คุณ', 'อยู่', 'ภูเก็ต', 'นาน', 'เท่าไร']
#
# Original: ช่วยบอกทางไปน้ำตกหน่อยได้ไหม
# Processed: ['ช่วย', 'บอก', 'ทาง', 'ไป', 'น้ำตก', 'ได้ไหม']
#
# Original: ห้องน้ำอยู่ที่ไหน
# Processed: ['ห้องน้ำ', 'อยู่', 'ที่ไหน']
#
# Original: คุณช่วยพาฉันไปสวนลุมพินีได้ไหม
# Processed: ['คุณ', 'ช่วย', 'ฉัน', 'ไป', 'สวนลุมพินี', 'ได้ไหม']
#
# Original: ฉันจะหารถเมล์ไปเซ็นทรัลได้ที่ไหน
# Processed: ['ฉัน', 'หา', 'รถเมล์', 'ไป', 'เซ็นทรัล', 'ได้', 'ที่ไหน']
#
# Original: ฉันต้องการความช่วยเหลือจากคุณ
# Processed: ['ฉัน', 'ต้องการ', 'ช่วยเหลือ', 'คุณ']
#
# Original: ขนมนี่ราคาเท่าไร
# Processed: ['ขนม', 'นี่', 'ราคา', 'เท่าไร']
#
# Original: ขอโทษ คุณช่วยพูดซ้ำอีกทีได้ไหม
# Processed: ['ขอโทษ', 'คุณ', 'ช่วย', 'พูด', 'ซ้ำ', 'อีก', 'ได้ไหม']
#
# Original: ฉันจะเอาสิ่งของเหล่านี้กลับบ้าน
# Processed: ['ฉัน', 'เอา', 'สิ่งของ', 'กลับบ้าน']
#
# Original: ฉันจะหาอาหารอร่อยได้ที่ไหน
# Processed: ['ฉัน', 'หา', 'อาหาร', 'อร่อย', 'ได้', 'ที่ไหน']
#
# Original: เคยไปที่ถนนเยาวราชหรือยัง
# Processed: ['เคย', 'ไป', 'ถนน', 'เยาวราช', 'หรือ', 'ยัง']
#
# Original: คุณช่วยเขียนลงกระดาษให้ฉันได้ไหม
# Processed: ['คุณ', 'ช่วย', 'เขียน', 'ลง', 'กระดาษ', 'ให้', 'ฉัน', 'ได้ไหม']
#
# Original: คุณพูดช้าลงหน่อยได้ไหม
# Processed: ['คุณ', 'พูด', 'ช้า', 'ลง', 'ได้ไหม']
#
# Original: คุณช่วยบอกทางไปสถานีรถไฟให้ฉันหน่อยได้ไหม
# Processed: ['คุณ', 'ช่วย', 'บอก', 'ทาง', 'ไป', 'สถานีรถไฟ', 'ให้', 'ฉัน', 'ได้ไหม']
#
# Original: คุณรับบัตรเครดิตหรือไม่
# Processed: ['คุณ', 'รับ', 'บัตรเครดิต', 'หรือ', 'ไม่']
#
# Original: คุณช่วยบอกทางไปเซเว่นบนแผนที่ให้ฉันหน่อยได้ไหม
# Processed: ['คุณ', 'ช่วย', 'บอก', 'ทาง', 'ไป', 'เซเว่น', 'บน', 'แผนที่', 'ให้', 'ฉัน', 'ได้ไหม']
#
# Original: ฉันหลงทาง
# Processed: ['ฉัน', 'หลงทาง']
#
# Original: ฉันไม่เข้าใจ
# Processed: ['ฉัน', 'ไม่', 'เข้าใจ']
#
# Original: ภาษาอังกฤษของฉันไม่ดีมาก
# Processed: ['ภาษาอังกฤษ', 'ฉัน', 'ไม่ดี', 'มาก']
#
# Original: โรงแรมอยู่ไกลมาก ขึ้นรถไฟความเร็วสูงไปดีกว่านะ
# Processed: ['โรงแรม', 'อยู่', 'ไกลมาก', 'ขึ้น', 'รถไฟความเร็วสูง', 'ไป', 'ดีกว่า']
#
# Original: คุณจะไปที่สนามบินกี่โมง
# Processed: ['คุณ', 'ไป', 'สนามบิน', 'กี่โมง']
#
# Original: เสร็จแล้วจะไปเที่ยวที่ไหนกันอีกดี
# Processed: ['เสร็จแล้ว', 'ไปเที่ยว', 'ที่ไหน', 'อีก', 'ดี']
#
# Original: เครื่องบินจะออกเมื่อไร
# Processed: ['เครื่องบิน', 'ออก', 'เมื่อไร']
#
# Original: ตรงไปข้างหน้าแล้วเลี้ยวซ้าย
# Processed: ['ตรง', 'ไป', 'ข้างหน้า', 'แล้ว', 'เลี้ยวซ้าย']

# %% [markdown]
# ###ประโยคชีวิตประจำวัน 140 คำ แบบไม่ลง Excel ได้ 92.14%

# %%
predicted_tokens = processed_sentences_train
ground_truth_tokens = [
    ['นี่', 'หนังสือ'],
    ['นั่น', 'สมุด'],
    ['นี่', 'อะไร'],
    ['นี่', 'นาฬิกา', 'หรือ', 'ปากกา'],
    ['คุณ', 'เข้าใจ'],
    ['ฉัน', 'ขอโทษ'],
    ['ขอบคุณ', 'พี่ชาย'],
    ['โทรศัพท์', 'อยู่', 'ที่ไหน'],
    ['คุณ', 'คน', 'ที่ไหน'],
    ['ขาย', 'ราคา', 'เท่าไร'],
    ['โทรศัพท์', 'อยู่', 'บน', 'โต๊ะ'],
    ['เขา', 'คน', 'ญี่ปุ่น', 'หรือ', 'คน', 'เกาหลีใต้'],
    ['ภาษาไทย', 'ยาก'],
    ['ภาษาไทย', 'ง่าย'],
    ['ราคา', 'แพง'],
    ['หนังสือ', 'อยู่', 'บน', 'เก้าอี้'],
    ['คุณ', 'ชอบ', 'อาหาร', 'อะไร'],
    ['คุณ', 'ชอบ', 'อาหาร', 'จีน'],
    ['คุณ', 'ชอบ', 'อาหาร', 'ไทย', 'หรือ', 'อาหาร', 'จีน'],
    ['คุณ', 'อ่าน', 'ภาษาไทย'],
    ['คุณ', 'เขียน', 'ภาษาไทย'],
    ['คุณ', 'ไป', 'ที่ไหน'],
    ['เขา', 'ชอบ', 'ดื่ม', 'อะไร'],
    ['เขา', 'ทำงาน', 'ที่ไหน'],
    ['ขอโทษ', 'พูด', 'ช้า', 'ลง'],
    ['พูด', 'อีกที'],
    ['เขา', 'มี', 'เวลา', 'ว่าง', 'ทุกวัน', 'เสาร์'],
    ['เมื่อวานนี้', 'ไป', 'ทำงาน'],
    ['หนึ่งสัปดาห์หน้า', 'เรียน', 'ภาษาไทย'],
    ['หนึ่งสัปดาห์ที่แล้ว', 'กลับบ้าน', 'ช้า', 'ทุกวัน'],
    ['อีก', 'สาม', 'ปี', 'กลับ', 'ประเทศไทย'],
    ['ตอนเที่ยง', 'กิน', 'ข้าวมันไก่', 'แล้ว'],
    ['ผม', 'พบ', 'แฟน', 'สวนสัตว์'],
    ['ตอนนี้', 'เวลา', 'กี่โมง'],
    ['คุณ', 'กิน', 'ข้าว', 'เช้า', 'กี่โมง'],
    ['เขา', 'มาสาย'],
    ['ผม', 'เรียน', 'ภาษาไทย', 'เริ่ม', 'เวลา', 'บ่าย'],
    ['ผม', 'อ่าน', 'หนังสือ', 'อยู่', 'ตอนนี้'],
    ['เขา', 'ไป', 'สนามบิน', 'เวลา', 'เที่ยง', 'ตรง'],
    ['ผม', 'ทำ', 'อาหาร', 'ไทย', 'ตอนเที่ยง'],
    ['สามารถ', 'ไป', 'เข้า', 'ห้องน้ำ', 'ได้', 'ห้า', 'นาที'],
    ['ผม', 'ทำงาน', 'ห้า', 'ชั่วโมง'],
    ['อีก', 'สิบ', 'นาที', 'กลับบ้าน'],
    ['พรุ่งนี้', 'ดิฉัน', 'ทำงาน', 'เวลา', 'เช้า'],
    ['คุณ', 'ไป', 'ธนาคาร', 'กี่โมง'],
    ['วันนี้', 'วันหยุด', 'ทำ', 'อะไร', 'ดี'],
    ['พรุ่งนี้', 'วันอาทิตย์'],
    ['', 'แล้ว', 'เงินเดือน', 'ออก'],
    ['วันปีใหม่', 'ไปเที่ยว', 'ที่ไหน'],
    ['คุณ', 'ไป', 'ประเทศไทย', 'เดือน', 'อะไร'],
    ['วันหยุด', 'คุณ', 'ทำ', 'อะไร'],
    ['เมื่อวานนี้', 'คุณ', 'ทำ', 'อะไร'],
    ['ผม', 'อยู่', 'ประเทศไทย', 'นาน', 'หก', 'ปี', 'แล้ว'],
    ['หนึ่งสัปดาห์หน้า', 'ทำ', 'อะไร'],
    ['เมื่อวานซืน', 'คุย', 'โทรศัพท์', 'แฟน', 'สอง', 'ชั่วโมง'],
    ['เขา', 'ไป', 'ทำงาน', 'เช้า'],
    ['วันเสาร์', 'ฉัน', 'ชอบ', 'ไป', 'เดิน', 'เล่น'],
    ['ผม', 'กลับ', 'ประเทศ', 'อังกฤษ', 'เดือน', 'ธันวาคม'],
    ['คุณ', 'ไป', 'ออกกำลังกาย', 'กี่โมง'],
    ['คุณ', 'กิน', 'ข้าว', 'หรือ', 'ยัง'],
    ['คุณ', 'อยาก', 'ทำ', 'อะไร'],
    ['ฉัน', 'เคย', 'ไป', 'ประเทศ', 'เม็กซิโก'],
    ['อากาศ', 'ร้อน', 'เมื่อไร', 'เข้า', 'ฤดู', 'หนาว'],
    ['คุณ', 'พ่อ', 'ไป', 'กิน', 'ข้าว', 'ร้าน', 'อาหาร'],
    ['ปกติ', 'คุณ', 'ไป', 'ทำงาน'],
    ['ไป', 'ที่ไหน', 'มา'],
    ['ผม', 'อยาก', 'ไป', 'หา', 'คุณ'],
    ['ฝนตกหนัก', 'มาก'],
    ['ผม', 'ขับรถ', 'รถยนต์', 'ไป', 'ทำงาน'],
    ['ผม', 'ชอบ', 'คุย', 'คน', 'ไทย'],
    ['ประเทศไทย', 'ไม่มี', 'หิมะ', 'ตก'],
    ['ภูเขา', 'เดี๋ยวนี้', 'ไม่มี', 'ต้นไม้'],
    ['บ้าน', 'ไม่มี', 'คน', 'อยู่'],
    ['วันนี้', 'มี', 'ไป', 'ทำ', 'ธุระ'],
    ['ผม', 'กิน', 'ข้าว', 'แล้ว'],
    ['ผม', 'ยัง', 'ไม่กิน', 'ข้าว'],
    ['ฉัน', 'นั่ง', 'ร้องเพลงคาราโอเกะ'],
    ['เขา', 'ยืน', 'คุย', 'คุณ'],
    ['ผม', 'ชอบ', 'นั่ง', 'อ่าน', 'หนังสือ', 'บ้าน'],
    ['พรุ่งนี้', 'อยาก', 'ไปเที่ยว', 'แฟน'],
    ['เขา', 'ยัง', 'ไม่', 'อยาก', 'เรียน', 'ภาษาไทย', 'ตอนนี้'],
    ['วันนี้', 'ไม่', 'อยาก', 'ทำ', 'อะไร'],
    ['นี่', 'ใคร'],
    ['ฉัน', 'ไป', 'ว่ายน้ำ', 'ออกกำลังกาย'],
    ['จำ', 'ผม'],
    ['ได้ยิน', 'ฉัน'],
    ['มอง', 'เห็น', 'เขา'],
    ['รู้จัก', 'เขา'],
    ['ทำงาน', 'เสร็จแล้ว'],
    ['เมื่อวานนี้', 'นอนหลับ', 'ไม่ดี'],
    ['ง่วงนอน', 'ต้องการ', 'ดื่ม', 'กาแฟ'],
    ['เขา', 'ฟัง', 'ภาษาไทย', 'ไม่'],
    ['ผม', 'อ่าน', 'หนังสือ', 'ภาษาไทย', 'ยัง', 'ไม่'],
    ['กิน', 'เผ็ด', 'ไม่'],
    ['ไป', 'ประเทศไทย', 'ไม่'],
    ['ผม', 'คิดถึง', 'คุณ', 'มาก'],
    ['เขา', 'มองดู', 'ทะเล'],
    ['ผม', 'พูด', 'ภาษาไทย', 'นิดหน่อย'],
    ['เขา', 'อ่าน', 'ภาษาอังกฤษ', 'ไม่', 'ผิด'],
    ['อาหาร', 'ไทย', 'อร่อย', 'มาก'],
    ['คุณ', 'ไป', 'ประเทศไทย', 'เดือน', 'อะไร'],
    ['เขา', 'ชื่อเล่น', 'อะไร'],
    ['พรุ่งนี้', 'ไป', 'ตัด', 'ผม', '(เส้นผม)'],
    ['ผม', 'โกนหนวด', 'ทุกวัน', 'เวลา', 'เช้า'],
    ['คน', 'ไทย', 'ชอบ', 'อาบน้ำ'],
    ['ไป', 'ซื้อ', 'สบู่', 'ยาสีฟัน'],
    ['เขา', 'ชอบ', 'ซื้อ', 'เสื้อแขนยาว'],
    ['ครอบครัว', 'คุณ', 'มี', 'คน'],
    ['คุณ', 'ทำงาน', 'อะไร'],
    ['คุณ', 'แต่งงาน', 'หรือ', 'ยัง'],
    ['คุณ', 'มี', 'ลูก', 'หรือ', 'ยัง'],
    ['คุณ', 'อายุ', 'ปี'],
    ['บ้าน', 'คุณ', 'มี', 'แมว'],
    ['ใคร', 'ครู', 'ภาษาไทย'],
    ['ทำไม', 'คุณ', 'เรียน', 'ภาษาไทย'],
    ['ทำไม', 'คุณ', 'ไม่', 'มา', 'วัด', 'หนึ่งสัปดาห์ที่แล้ว'],
    ['ถ้า', 'คุณ', 'รวย', 'คุณ', 'อยาก', 'ทำ', 'อะไร'],
    ['ถ้า', 'ฝนตก', 'ทำ', 'อะไร', 'ดี'],
    ['วันนี้', 'อยาก', 'ไป', 'หา', 'หมอ', 'ฟัน'],
    ['ผม', 'มี', 'ลุง', 'อยู่', 'อังกฤษ'],
    ['เขา', 'มี', 'ครอบครัว', 'อยู่', 'ไทย'],
    ['ผม', 'อยาก', 'แต่งงาน', 'คุณ'],
    ['ผม', 'รัก', 'คุณ', 'มาก'],
    ['เขา', 'สูง', 'มาก'],
    ['คุณ', 'เรียน', 'ภาษาไทย', 'ชั่วโมง'],
    ['ผม', 'ชอบ', 'สีขาว', 'มาก', 'สีดำ'],
    ['เครื่องบิน', 'ลำ', 'ใหญ่', 'มาก'],
    ['เขา', 'รัก', 'เธอ', 'มาก'],
    ['เขา', 'เกลียด', 'คุณ', 'คุณ', 'ชอบ', 'โกหก'],
    ['เสื้อยืด', 'ตัว', 'ไม่', 'แพง'],
    ['ใคร', 'เขียน', 'หนังสือ', 'สวย'],
    ['คุณ', 'ชอบ', 'ไปเที่ยว', 'ที่ไหน'],
    ['วันนี้', 'กิน', 'กล้วยหอม'],
    ['เมื่อวานนี้', 'คุณ', 'อ่าน', 'หนังสือ', 'อะไร'],
    ['ผม', 'มี', 'ทีวี', 'สาม', 'เครื่อง', 'คอมพิวเตอร์', 'หนึ่ง', 'เครื่อง'],
    ['นั่ง', 'เครื่องบิน', 'มา', 'ลง', 'กรุงเทพฯ'],
    ['ผม', 'ซื้อ', 'บ้าน', 'ใหม่'],
    ['เนื้อ', 'ชิ้น', 'อร่อย', 'มาก'],
    ['ดอกไม้', 'ดอก', 'สวย', 'มาก'],
    ['มี', 'อาหาร', 'หก', 'จาน', 'อยู่', 'บน', 'โต๊ะ']
]
    # ฟังก์ชันคำนวณความแม่นยำสำหรับแต่ละประโยค
def calculate_sentence_accuracy(predicted, ground_truth):
    # ตรวจสอบว่าแต่ละประโยคตรงกันหรือไม่
    correct_sentences = sum([pred == gt for pred, gt in zip(predicted, ground_truth)])

    # คำนวณเปอร์เซ็นต์ความแม่นยำ
    accuracy = correct_sentences / len(ground_truth) * 100
    return accuracy

# คำนวณความแม่นยำสำหรับแต่ละประโยค
accuracy = calculate_sentence_accuracy(predicted_tokens, ground_truth_tokens)

# แสดงผล
print(f"Sentence-level Accuracy: {accuracy:.2f}%")
# Out:
# Sentence-level Accuracy: 92.14%

# %% [markdown]
# ###ประโยคชีวิตประจำวัน 140 คำ แบบลง Excel ได้ 89.29%

# %%
import pandas as pd
import numpy as np

# Path to the ground truth file
ground_truth_tokens_path = '/content/drive/MyDrive/Thesis/Project/ประโยคจากหนังสือ.xlsx'

# Load the data from the Excel sheet (sheet_name=2 refers to the 3rd sheet)
df = pd.read_excel(ground_truth_tokens_path, sheet_name=1)

# Columns representing tokenized words
selected_columns = ['word_1', 'word_2', 'word_3', 'word_4', 'word_5', 'word_6', 'word_7']

# Extract the relevant columns
df_selected = df[selected_columns]

# Convert the DataFrame to a list of lists (ground truth tokens)
ground_truth_tokens = df_selected.values.tolist()

# Predicted tokens (ensure that processed_sentences_train is defined)
predicted_tokens = processed_sentences_train  # Ensure this is a list of lists as well

# ฟังก์ชันทำความสะอาดประโยคโดยการกำจัดค่า nan ออก
def clean_tokens(tokens):
    return [token for token in tokens if token is not np.nan]

# ทำความสะอาดทั้ง predicted และ ground truth
cleaned_predicted_tokens = [clean_tokens(pred) for pred in predicted_tokens]
cleaned_ground_truth_tokens = [clean_tokens(gt) for gt in ground_truth_tokens]

# ฟังก์ชันคำนวณความแม่นยำสำหรับแต่ละประโยค
def calculate_sentence_accuracy(predicted, ground_truth):
    correct_sentences = sum([pred == gt for pred, gt in zip(predicted, ground_truth)])
    accuracy = correct_sentences / len(ground_truth) * 100
    return accuracy

# คำนวณความแม่นยำหลังทำความสะอาดข้อมูล
accuracy = calculate_sentence_accuracy(cleaned_predicted_tokens, cleaned_ground_truth_tokens)

# แสดงผล
print(f"Sentence-level Accuracy: {accuracy:.2f}%")

for i in range(10):
    print(f"Predicted: {cleaned_predicted_tokens[i]}")
    print(f"Ground Truth: {cleaned_ground_truth_tokens[i]}")
    print("---")
# Out:
# Sentence-level Accuracy: 89.29%
# Predicted: ['นี่', 'หนังสือ']
# Ground Truth: ['นี่', 'หนังสือ']
# ---
# Predicted: ['นั่น', 'สมุด']
# Ground Truth: ['นั่น', 'สมุด']
# ---
# Predicted: ['นี่', 'อะไร']
# Ground Truth: ['นี่่', 'อะไร']
# ---
# Predicted: ['นี่', 'นาฬิกา', 'หรือ', 'ปากกา']
# Ground Truth: ['นี่', 'นาฬิกา', 'หรือ', 'ปากกา']
# ---
# Predicted: ['คุณ', 'เข้าใจ']
# Ground Truth: ['คุณ', 'เข้าใจ']
# ---
# Predicted: ['ฉัน', 'ขอโทษ']
# Ground Truth: ['ฉัน', 'ขอโทษ']
# ---
# Predicted: ['ขอบคุณ', 'พี่ชาย']
# Ground Truth: ['ขอบคุณ', 'พี่ชาย']
# ---
# Predicted: ['โทรศัพท์', 'อยู่', 'ที่ไหน']
# Ground Truth: ['โทรศัพท์', 'อยู่', 'ที่ไหน']
# ---
# Predicted: ['คุณ', 'คน', 'ที่ไหน']
# Ground Truth: ['คุณ', 'คน', 'ที่ี่ไหน']
# ---
# Predicted: ['ขาย', 'ราคา', 'เท่าไร']
# Ground Truth: ['ขาย', 'ราคา', 'เท่าไร']
# ---

# %%
# Path to the ground truth file
ground_truth_tokens_path = '/content/drive/MyDrive/Thesis/Project/ประโยคจากหนังสือ.xlsx'

# Load the data from the Excel sheet (sheet_name=1 refers to the 2nd sheet)
df = pd.read_excel(ground_truth_tokens_path, sheet_name=1)

# Columns representing tokenized words
selected_columns = ['word_1', 'word_2', 'word_3', 'word_4', 'word_5', 'word_6', 'word_7']

# Extract the relevant columns
df_selected = df[selected_columns]

# Convert the DataFrame to a list of lists (ground truth tokens)
ground_truth_tokens = df_selected.values.tolist()

# Predicted tokens (ensure that processed_sentences_train is defined)
predicted_tokens = processed_sentences_train  # Ensure this is a list of lists as well

# ฟังก์ชันทำความสะอาดประโยคโดยการกำจัดค่า nan ออก
def clean_tokens(tokens):
    return [token for token in tokens if token is not np.nan]

# ทำความสะอาดทั้ง predicted และ ground truth
cleaned_predicted_tokens = [clean_tokens(pred) for pred in predicted_tokens]
cleaned_ground_truth_tokens = [clean_tokens(gt) for gt in ground_truth_tokens]

# ฟังก์ชันคำนวณ Precision สำหรับแต่ละประโยค
def calculate_precision(predicted, ground_truth):
    TP = 0  # True Positives
    FP = 0  # False Positives

    # คำนวณ TP และ FP
    for token in predicted:
        if token in ground_truth:
            TP += 1  # True Positive (token exists in both predicted and ground truth)
        else:
            FP += 1  # False Positive (token exists only in predicted)

    # คำนวณ Precision
    if TP + FP == 0:  # to avoid division by zero
        precision = 0
    else:
        precision = TP / (TP + FP)

    return precision

# คำนวณ Precision หลังทำความสะอาดข้อมูล
precision = [calculate_precision(pred, gt) for pred, gt in zip(cleaned_predicted_tokens, cleaned_ground_truth_tokens)]

# คำนวณ Precision โดยเฉลี่ยสำหรับทั้งหมด
average_precision = np.mean(precision)

# แสดงผล
print(f"Average Precision: {average_precision:.2f}")

# ถ้าคุณต้องการดู Precision สำหรับแต่ละประโยค
for i in range(10):  # Show first 10 sentences' precision
    sentence_precision = calculate_precision(cleaned_predicted_tokens[i], cleaned_ground_truth_tokens[i])
    print(f"Sentence {i+1} Precision: {sentence_precision:.2f}")
    print(f"Predicted: {cleaned_predicted_tokens[i]}")
    print(f"Ground Truth: {cleaned_ground_truth_tokens[i]}")
    print("---")
# Out:
# Average Precision: 0.98
# Sentence 1 Precision: 1.00
# Predicted: ['นี่', 'หนังสือ']
# Ground Truth: ['นี่', 'หนังสือ']
# ---
# Sentence 2 Precision: 1.00
# Predicted: ['นั่น', 'สมุด']
# Ground Truth: ['นั่น', 'สมุด']
# ---
# Sentence 3 Precision: 0.50
# Predicted: ['นี่', 'อะไร']
# Ground Truth: ['นี่่', 'อะไร']
# ---
# Sentence 4 Precision: 1.00
# Predicted: ['นี่', 'นาฬิกา', 'หรือ', 'ปากกา']
# Ground Truth: ['นี่', 'นาฬิกา', 'หรือ', 'ปากกา']
# ---
# Sentence 5 Precision: 1.00
# Predicted: ['คุณ', 'เข้าใจ']
# Ground Truth: ['คุณ', 'เข้าใจ']
# ---
# Sentence 6 Precision: 1.00
# Predicted: ['ฉัน', 'ขอโทษ']
# Ground Truth: ['ฉัน', 'ขอโทษ']
# ---
# Sentence 7 Precision: 1.00
# Predicted: ['ขอบคุณ', 'พี่ชาย']
# Ground Truth: ['ขอบคุณ', 'พี่ชาย']
# ---
# Sentence 8 Precision: 1.00
# Predicted: ['โทรศัพท์', 'อยู่', 'ที่ไหน']
# Ground Truth: ['โทรศัพท์', 'อยู่', 'ที่ไหน']
# ---
# Sentence 9 Precision: 0.67
# Predicted: ['คุณ', 'คน', 'ที่ไหน']
# Ground Truth: ['คุณ', 'คน', 'ที่ี่ไหน']
# ---
# Sentence 10 Precision: 1.00
# Predicted: ['ขาย', 'ราคา', 'เท่าไร']
# Ground Truth: ['ขาย', 'ราคา', 'เท่าไร']
# ---

# %%
import pandas as pd
import numpy as np

# Path to the ground truth file
ground_truth_tokens_path = '/content/drive/MyDrive/Thesis/Project/ประโยคจากหนังสือ.xlsx'

# Load the data from the Excel sheet (sheet_name=1 refers to the 2nd sheet)
df = pd.read_excel(ground_truth_tokens_path, sheet_name=1)

# Columns representing tokenized words
selected_columns = ['word_1', 'word_2', 'word_3', 'word_4', 'word_5', 'word_6', 'word_7']

# Extract the relevant columns
df_selected = df[selected_columns]

# Convert the DataFrame to a list of lists (ground truth tokens)
ground_truth_tokens = df_selected.values.tolist()

# Predicted tokens (ensure that processed_sentences_train is defined)
predicted_tokens = processed_sentences_train  # Ensure this is a list of lists as well

# ฟังก์ชันทำความสะอาดประโยคโดยการกำจัดค่า nan ออก
def clean_tokens(tokens):
    return [token for token in tokens if token is not np.nan]

# ทำความสะอาดทั้ง predicted และ ground truth
cleaned_predicted_tokens = [clean_tokens(pred) for pred in predicted_tokens]
cleaned_ground_truth_tokens = [clean_tokens(gt) for gt in ground_truth_tokens]

# ฟังก์ชันคำนวณ Recall สำหรับแต่ละประโยค
def calculate_recall(predicted, ground_truth):
    TP = 0  # True Positives
    FN = 0  # False Negatives

    # คำนวณ TP และ FN
    for token in ground_truth:
        if token in predicted:
            TP += 1  # True Positive (token exists in both predicted and ground truth)
        else:
            FN += 1  # False Negative (token exists only in ground truth)

    # คำนวณ Recall (Sensitivity)
    if TP + FN == 0:  # to avoid division by zero
        recall = 0
    else:
        recall = TP / (TP + FN)

    return recall

# คำนวณ Recall หลังทำความสะอาดข้อมูล
recall = [calculate_recall(pred, gt) for pred, gt in zip(cleaned_predicted_tokens, cleaned_ground_truth_tokens)]

# คำนวณ Recall โดยเฉลี่ยสำหรับทั้งหมด
average_recall = np.mean(recall)

# แสดงผล
print(f"Average Recall: {average_recall:.2f}")

# ถ้าคุณต้องการดู Recall สำหรับแต่ละประโยค
for i in range(10):  # Show first 10 sentences' recall
    sentence_recall = calculate_recall(cleaned_predicted_tokens[i], cleaned_ground_truth_tokens[i])
    print(f"Sentence {i+1} Recall: {sentence_recall:.2f}")
    print(f"Predicted: {cleaned_predicted_tokens[i]}")
    print(f"Ground Truth: {cleaned_ground_truth_tokens[i]}")
    print("---")
# Out:
# Average Recall: 0.97
# Sentence 1 Recall: 1.00
# Predicted: ['นี่', 'หนังสือ']
# Ground Truth: ['นี่', 'หนังสือ']
# ---
# Sentence 2 Recall: 1.00
# Predicted: ['นั่น', 'สมุด']
# Ground Truth: ['นั่น', 'สมุด']
# ---
# Sentence 3 Recall: 0.50
# Predicted: ['นี่', 'อะไร']
# Ground Truth: ['นี่่', 'อะไร']
# ---
# Sentence 4 Recall: 1.00
# Predicted: ['นี่', 'นาฬิกา', 'หรือ', 'ปากกา']
# Ground Truth: ['นี่', 'นาฬิกา', 'หรือ', 'ปากกา']
# ---
# Sentence 5 Recall: 1.00
# Predicted: ['คุณ', 'เข้าใจ']
# Ground Truth: ['คุณ', 'เข้าใจ']
# ---
# Sentence 6 Recall: 1.00
# Predicted: ['ฉัน', 'ขอโทษ']
# Ground Truth: ['ฉัน', 'ขอโทษ']
# ---
# Sentence 7 Recall: 1.00
# Predicted: ['ขอบคุณ', 'พี่ชาย']
# Ground Truth: ['ขอบคุณ', 'พี่ชาย']
# ---
# Sentence 8 Recall: 1.00
# Predicted: ['โทรศัพท์', 'อยู่', 'ที่ไหน']
# Ground Truth: ['โทรศัพท์', 'อยู่', 'ที่ไหน']
# ---
# Sentence 9 Recall: 0.67
# Predicted: ['คุณ', 'คน', 'ที่ไหน']
# Ground Truth: ['คุณ', 'คน', 'ที่ี่ไหน']
# ---
# Sentence 10 Recall: 1.00
# Predicted: ['ขาย', 'ราคา', 'เท่าไร']
# Ground Truth: ['ขาย', 'ราคา', 'เท่าไร']
# ---

# %%
import pandas as pd
import numpy as np

# Path to the ground truth file
ground_truth_tokens_path = '/content/drive/MyDrive/Thesis/Project/ประโยคจากหนังสือ.xlsx'

# Load the data from the Excel sheet (sheet_name=1 refers to the 2nd sheet)
df = pd.read_excel(ground_truth_tokens_path, sheet_name=1)

# Columns representing tokenized words
selected_columns = ['word_1', 'word_2', 'word_3', 'word_4', 'word_5', 'word_6', 'word_7']

# Extract the relevant columns
df_selected = df[selected_columns]

# Convert the DataFrame to a list of lists (ground truth tokens)
ground_truth_tokens = df_selected.values.tolist()

# Predicted tokens (ensure that processed_sentences_train is defined)
predicted_tokens = processed_sentences_train  # Ensure this is a list of lists as well

# ฟังก์ชันทำความสะอาดประโยคโดยการกำจัดค่า nan ออก
def clean_tokens(tokens):
    return [token for token in tokens if token is not np.nan]

# ทำความสะอาดทั้ง predicted และ ground truth
cleaned_predicted_tokens = [clean_tokens(pred) for pred in predicted_tokens]
cleaned_ground_truth_tokens = [clean_tokens(gt) for gt in ground_truth_tokens]

# ฟังก์ชันคำนวณ Precision สำหรับแต่ละประโยค
def calculate_precision(predicted, ground_truth):
    TP = 0  # True Positives
    FP = 0  # False Positives

    # คำนวณ TP และ FP
    for token in predicted:
        if token in ground_truth:
            TP += 1  # True Positive (token exists in both predicted and ground truth)
        else:
            FP += 1  # False Positive (token exists only in predicted)

    # คำนวณ Precision
    if TP + FP == 0:  # to avoid division by zero
        precision = 0
    else:
        precision = TP / (TP + FP)

    return precision

# ฟังก์ชันคำนวณ Recall (Sensitivity) สำหรับแต่ละประโยค
def calculate_recall(predicted, ground_truth):
    TP = 0  # True Positives
    FN = 0  # False Negatives

    # คำนวณ TP และ FN
    for token in ground_truth:
        if token in predicted:
            TP += 1  # True Positive (token exists in both predicted and ground truth)
        else:
            FN += 1  # False Negative (token exists only in ground truth)

    # คำนวณ Recall
    if TP + FN == 0:  # to avoid division by zero
        recall = 0
    else:
        recall = TP / (TP + FN)

    return recall

# ฟังก์ชันคำนวณ F1 Score สำหรับแต่ละประโยค
def calculate_f1_score(predicted, ground_truth):
    precision = calculate_precision(predicted, ground_truth)
    recall = calculate_recall(predicted, ground_truth)

    if precision + recall == 0:  # to avoid division by zero
        f1_score = 0
    else:
        f1_score = 2 * ((precision * recall) / (precision + recall))

    return f1_score

# คำนวณ F1 Score สำหรับแต่ละประโยค
f1_scores = [calculate_f1_score(pred, gt) for pred, gt in zip(cleaned_predicted_tokens, cleaned_ground_truth_tokens)]

# คำนวณ F1 Score โดยเฉลี่ยสำหรับทั้งหมด
average_f1_score = np.mean(f1_scores)

# แสดงผล
print(f"Average F1 Score: {average_f1_score:.2f}")

# ถ้าคุณต้องการดู F1 Score สำหรับแต่ละประโยค
for i in range(10):  # Show first 10 sentences' F1 Score
    sentence_f1_score = calculate_f1_score(cleaned_predicted_tokens[i], cleaned_ground_truth_tokens[i])
    print(f"Sentence {i+1} F1 Score: {sentence_f1_score:.2f}")
    print(f"Predicted: {cleaned_predicted_tokens[i]}")
    print(f"Ground Truth: {cleaned_ground_truth_tokens[i]}")
    print("---")
# Out:
# Average F1 Score: 0.97
# Sentence 1 F1 Score: 1.00
# Predicted: ['นี่', 'หนังสือ']
# Ground Truth: ['นี่', 'หนังสือ']
# ---
# Sentence 2 F1 Score: 1.00
# Predicted: ['นั่น', 'สมุด']
# Ground Truth: ['นั่น', 'สมุด']
# ---
# Sentence 3 F1 Score: 0.50
# Predicted: ['นี่', 'อะไร']
# Ground Truth: ['นี่่', 'อะไร']
# ---
# Sentence 4 F1 Score: 1.00
# Predicted: ['นี่', 'นาฬิกา', 'หรือ', 'ปากกา']
# Ground Truth: ['นี่', 'นาฬิกา', 'หรือ', 'ปากกา']
# ---
# Sentence 5 F1 Score: 1.00
# Predicted: ['คุณ', 'เข้าใจ']
# Ground Truth: ['คุณ', 'เข้าใจ']
# ---
# Sentence 6 F1 Score: 1.00
# Predicted: ['ฉัน', 'ขอโทษ']
# Ground Truth: ['ฉัน', 'ขอโทษ']
# ---
# Sentence 7 F1 Score: 1.00
# Predicted: ['ขอบคุณ', 'พี่ชาย']
# Ground Truth: ['ขอบคุณ', 'พี่ชาย']
# ---
# Sentence 8 F1 Score: 1.00
# Predicted: ['โทรศัพท์', 'อยู่', 'ที่ไหน']
# Ground Truth: ['โทรศัพท์', 'อยู่', 'ที่ไหน']
# ---
# Sentence 9 F1 Score: 0.67
# Predicted: ['คุณ', 'คน', 'ที่ไหน']
# Ground Truth: ['คุณ', 'คน', 'ที่ี่ไหน']
# ---
# Sentence 10 F1 Score: 1.00
# Predicted: ['ขาย', 'ราคา', 'เท่าไร']
# Ground Truth: ['ขาย', 'ราคา', 'เท่าไร']
# ---

# %% [markdown]
# ### ประโยคท่องเที่ยว 80 ประโยค เทรน ลง Excel ได้ 82.50%

# %%
import pandas as pd
import numpy as np

# Path to the ground truth file
ground_truth_tokens_path = '/content/drive/MyDrive/Thesis/Project/ประโยคจากหนังสือ.xlsx'

# Load the data from the Excel sheet (sheet_name=2 refers to the 3rd sheet)
df = pd.read_excel(ground_truth_tokens_path, sheet_name=4)

# Columns representing tokenized words
selected_columns = ['word_1', 'word_2', 'word_3', 'word_4', 'word_5', 'word_6', 'word_7', 'word_8', 'word_9', 'word_10', 'word_11']

# Extract the relevant columns
df_selected = df[selected_columns]

# Convert the DataFrame to a list of lists (ground truth tokens)
ground_truth_tokens = df_selected.values.tolist()

# Predicted tokens (ensure that processed_sentences_train is defined)
predicted_tokens = travel_sentences_train  # Ensure this is a list of lists as well

# ฟังก์ชันทำความสะอาดประโยคโดยการกำจัดค่า nan ออก
def clean_tokens(tokens):
    return [token for token in tokens if token is not np.nan]

# ทำความสะอาดทั้ง predicted และ ground truth
cleaned_predicted_tokens = [clean_tokens(pred) for pred in predicted_tokens]
cleaned_ground_truth_tokens = [clean_tokens(gt) for gt in ground_truth_tokens]

# ฟังก์ชันคำนวณความแม่นยำสำหรับแต่ละประโยค
def calculate_sentence_accuracy(predicted, ground_truth):
    correct_sentences = sum([pred == gt for pred, gt in zip(predicted, ground_truth)])
    accuracy = correct_sentences / len(ground_truth) * 100
    return accuracy

# คำนวณความแม่นยำหลังทำความสะอาดข้อมูล
accuracy = calculate_sentence_accuracy(cleaned_predicted_tokens, cleaned_ground_truth_tokens)

# แสดงผล
print(f"Sentence-level Accuracy: {accuracy:.2f}%")

for i in range(80):
    print(f"Predicted: {cleaned_predicted_tokens[i]}")
    print(f"Ground Truth: {cleaned_ground_truth_tokens[i]}")
    print("---")
# Out:
# Sentence-level Accuracy: 82.50%
# Predicted: ['ฉัน', 'ต้องการ', 'จอง', 'สอง', 'ที่นั่ง', 'ถึง', 'กรุงเทพ']
# Ground Truth: ['คุณ', 'ช่วย', 'บอก', 'ทาง', 'ไป', 'สถานีรถไฟ', 'ให้', 'ฉัน', 'ได้ไหม']
# ---
# Predicted: ['คุณ', 'รับ', 'บัตรเครดิต', 'หรือ', 'ไม่']
# Ground Truth: ['คุณ', 'รับ', 'บัตรเครดิต', 'หรือ', 'ไม่']
# ---
# Predicted: ['คุณ', 'ช่วย', 'บอก', 'ทาง', 'ไป', 'เซเว่น', 'บน', 'แผนที่', 'ให้', 'ฉัน', 'ได้ไหม']
# Ground Truth: ['คุณ', 'ช่วย', 'บอก', 'ทาง', 'ไป', 'เซเว่น', 'บน', 'แผนที่', 'ให้', 'ฉัน', 'ได้ไหม']
# ---
# Predicted: ['ฉัน', 'หลงทาง']
# Ground Truth: ['ฉัน', 'หลงทาง']
# ---
# Predicted: ['ฉัน', 'ไม่', 'เข้าใจ']
# Ground Truth: ['ฉัน', 'ไม่', 'เข้าใจ']
# ---
# Predicted: ['ภาษาอังกฤษ', 'ฉัน', 'ไม่ดี', 'มาก']
# Ground Truth: ['ภาษาอังกฤษ', 'ฉัน', 'ไม่ดี', 'มาก']
# ---
# Predicted: ['โรงแรม', 'อยู่', 'ไกลมาก', 'ขึ้น', 'รถไฟความเร็วสูง', 'ไป', 'ดีกว่า']
# Ground Truth: ['โรงแรม', 'อยู่', 'ไกลมาก', 'ขึ้น', 'รถไฟความเร็วสูง', 'ไป', 'ดีกว่า']
# ---
# Predicted: ['คุณ', 'ไป', 'สนามบิน', 'กี่โมง']
# Ground Truth: ['คุณ', 'ไป', 'สนามบิน', 'เวลา', 'กี่โมง']
# ---
# Predicted: ['เสร็จแล้ว', 'ไปเที่ยว', 'ที่ไหน', 'อีก', 'ดี']
# Ground Truth: ['เสร็จแล้ว', 'ไป', 'เที่ยว', 'ที่ไหน', 'อีก', 'ดี']
# ---
# Predicted: ['เครื่องบิน', 'ออก', 'เมื่อไร']
# Ground Truth: ['เครื่องบิน', 'ออก', 'เมื่อไร']
# ---
# Predicted: ['ตรง', 'ไป', 'ข้างหน้า', 'แล้ว', 'เลี้ยวซ้าย']
# Ground Truth: ['ตรง', 'ไป', 'ข้างหน้า', 'แล้ว', 'เลี้ยวซ้าย']
# ---

# %%
import pandas as pd
import numpy as np

# Path to the ground truth file
ground_truth_tokens_path = '/content/drive/MyDrive/Thesis/Project/ประโยคจากหนังสือ.xlsx'

# Load the data from the Excel sheet (sheet_name=4 refers to the 5th sheet)
df = pd.read_excel(ground_truth_tokens_path, sheet_name=4)

# Columns representing tokenized words
selected_columns = ['word_1', 'word_2', 'word_3', 'word_4', 'word_5', 'word_6', 'word_7', 'word_8', 'word_9', 'word_10', 'word_11']

# Extract the relevant columns
df_selected = df[selected_columns]

# Convert the DataFrame to a list of lists (ground truth tokens)
ground_truth_tokens = df_selected.values.tolist()

# Predicted tokens (ensure that travel_sentences_train is defined)
predicted_tokens = travel_sentences_train  # Ensure this is a list of lists as well

# ฟังก์ชันทำความสะอาดประโยคโดยการกำจัดค่า nan ออก
def clean_tokens(tokens):
    return [token for token in tokens if token is not np.nan]

# ทำความสะอาดทั้ง predicted และ ground truth
cleaned_predicted_tokens = [clean_tokens(pred) for pred in predicted_tokens]
cleaned_ground_truth_tokens = [clean_tokens(gt) for gt in ground_truth_tokens]

# ฟังก์ชันคำนวณ Precision สำหรับแต่ละประโยค
def calculate_precision(predicted, ground_truth):
    TP = 0  # True Positives
    FP = 0  # False Positives

    # คำนวณ TP และ FP
    for token in predicted:
        if token in ground_truth:
            TP += 1  # True Positive (token exists in both predicted and ground truth)
        else:
            FP += 1  # False Positive (token exists only in predicted)

    # คำนวณ Precision
    if TP + FP == 0:  # to avoid division by zero
        precision = 0
    else:
        precision = TP / (TP + FP)

    return precision

# ฟังก์ชันคำนวณ Recall (Sensitivity) สำหรับแต่ละประโยค
def calculate_recall(predicted, ground_truth):
    TP = 0  # True Positives
    FN = 0  # False Negatives

    # คำนวณ TP และ FN
    for token in ground_truth:
        if token in predicted:
            TP += 1  # True Positive (token exists in both predicted and ground truth)
        else:
            FN += 1  # False Negative (token exists only in ground truth)

    # คำนวณ Recall
    if TP + FN == 0:  # to avoid division by zero
        recall = 0
    else:
        recall = TP / (TP + FN)

    return recall

# ฟังก์ชันคำนวณ F1 Score สำหรับแต่ละประโยค
def calculate_f1_score(predicted, ground_truth):
    precision = calculate_precision(predicted, ground_truth)
    recall = calculate_recall(predicted, ground_truth)

    if precision + recall == 0:  # to avoid division by zero
        f1_score = 0
    else:
        f1_score = 2 * ((precision * recall) / (precision + recall))

    return f1_score

# คำนวณ Precision, Recall และ F1 Score สำหรับแต่ละประโยค
precisions = [calculate_precision(pred, gt) for pred, gt in zip(cleaned_predicted_tokens, cleaned_ground_truth_tokens)]
recalls = [calculate_recall(pred, gt) for pred, gt in zip(cleaned_predicted_tokens, cleaned_ground_truth_tokens)]
f1_scores = [calculate_f1_score(pred, gt) for pred, gt in zip(cleaned_predicted_tokens, cleaned_ground_truth_tokens)]

# คำนวณค่าเฉลี่ยของ Precision, Recall และ F1 Score
average_precision = np.mean(precisions)
average_recall = np.mean(recalls)
average_f1_score = np.mean(f1_scores)

# แสดงผลลัพธ์
print(f"Average Precision: {average_precision:.2f}")
print(f"Average Recall (Sensitivity): {average_recall:.2f}")
print(f"Average F1 Score: {average_f1_score:.2f}")

# ถ้าคุณต้องการดู Precision, Recall, F1 Score สำหรับแต่ละประโยค
for i in range(10):  # Show first 10 sentences' Precision, Recall, and F1 Score
    print(f"Sentence {i+1}:")
    print(f"Predicted: {cleaned_predicted_tokens[i]}")
    print(f"Ground Truth: {cleaned_ground_truth_tokens[i]}")
    print(f"Precision: {precisions[i]:.2f}")
    print(f"Recall: {recalls[i]:.2f}")
    print(f"F1 Score: {f1_scores[i]:.2f}")
    print("---")
# Out:
# Average Precision: 0.99
# Average Recall (Sensitivity): 0.98
# Average F1 Score: 0.98
# Sentence 1:
# Predicted: ['ฉัน', 'ต้องการ', 'จอง', 'สอง', 'ที่นั่ง', 'ถึง', 'กรุงเทพ']
# Ground Truth: ['ฉัน', 'ต้องการ', 'จอง', 'สอง', 'ที่นั่ง', 'กรุงเทพ']
# Precision: 0.86
# Recall: 1.00
# F1 Score: 0.92
# ---
# Sentence 2:
# Predicted: ['คุณ', 'ต้องการ', 'ตั๋ว', 'เที่ยว', 'หรือ', 'ไป', 'กลับ']
# Ground Truth: ['คุณ', 'ต้องการ', 'ตั๋ว', 'เที่ยว', 'หรือ', 'ไป', 'กลับ']
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00
# ---
# Sentence 3:
# Predicted: ['ตั๋ว', 'ไป', 'กลับ', 'ราคา', 'เท่าไร']
# Ground Truth: ['ตั๋ว', 'ไป', 'กลับ', 'ราคา', 'เท่าไร']
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00
# ---
# Sentence 4:
# Predicted: ['คุณ', 'ต้องการ', 'จ่าย', 'เงินสด', 'หรือ', 'บัตรเครดิต']
# Ground Truth: ['คุณ', 'ต้องการ', 'จ่าย', 'เงินสด', 'หรือ', 'บัตรเครดิต']
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00
# ---
# Sentence 5:
# Predicted: ['ฉัน', 'ดู', 'ตั๋ว', 'หนังสือเดินทาง', 'คุณ', 'ได้ไหม']
# Ground Truth: ['ฉัน', 'ดู', 'ตั๋ว', 'หนังสือเดินทาง', 'คุณ', 'ได้ไหม']
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00
# ---
# Sentence 6:
# Predicted: ['วันนี้', 'มี', 'ใคร', 'ไป', 'คุณ']
# Ground Truth: ['วันนี้', 'มี', 'ใคร', 'ไป', 'คุณ']
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00
# ---
# Sentence 7:
# Predicted: ['ฉัน', 'เอา', 'สัมภาระ', 'มา', 'สอง', 'ชิ้น']
# Ground Truth: ['ฉัน', 'เอา', 'สัมภาระ', 'มา', 'สอง', 'ชิ้น']
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00
# ---
# Sentence 8:
# Predicted: ['คุณ', 'อยาก', 'นั่ง', 'ใกล้', 'หน้าต่าง', 'หรือ', 'ไม่']
# Ground Truth: ['คุณ', 'อยาก', 'นั่ง', 'ใกล้', 'หน้าต่าง', 'หรือ', 'ไม่']
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00
# ---
# Sentence 9:
# Predicted: ['เครื่องบิน', 'ไป', 'เกาะสมุย', 'ตั๋ว', 'หมด', 'แล้ว']
# Ground Truth: ['เครื่องบิน', 'ไป', 'เกาะสมุย', 'ตั๋ว', 'หมด', 'แล้ว']
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00
# ---
# Sentence 10:
# Predicted: ['คุณ', 'ต้องการ', 'ตั๋ว', 'เวลา', 'บ่าย', 'สอง', 'หรือ', 'สี่', 'โมง']
# Ground Truth: ['คุณ', 'ต้องการ', 'ตั๋ว', 'เวลา', 'บ่าย', 'สอง', 'หรือ', 'สี่', 'โมง']
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00
# ---

# %%
# ฟังก์ชันคำนวณ Precision สำหรับแต่ละประโยค
def calculate_precision(predicted, ground_truth):
    TP = 0  # True Positives
    FP = 0  # False Positives

    # คำนวณ TP และ FP
    for pred_token, gt_token in zip(predicted, ground_truth):
        if pred_token == gt_token:
            TP += 1  # True Positive
        else:
            FP += 1  # False Positive

    # คำนวณ Precision
    if TP + FP == 0:  # to avoid division by zero
        precision = 0
    else:
        precision = TP / (TP + FP)

    return precision

# คำนวณ Precision หลังทำความสะอาดข้อมูล
precision = [calculate_precision(pred, gt) for pred, gt in zip(cleaned_predicted_tokens, cleaned_ground_truth_tokens)]

# คำนวณ Precision โดยเฉลี่ยสำหรับทั้งหมด
average_precision = np.mean(precision)

# แสดงผล
print(f"Average Precision: {average_precision:.2f}")

# ถ้าคุณต้องการดู Precision สำหรับแต่ละประโยค
for i in range(80):
    sentence_precision = calculate_precision(cleaned_predicted_tokens[i], cleaned_ground_truth_tokens[i])
    print(f"Sentence {i+1} Precision: {sentence_precision:.2f}")
    print(f"Predicted: {cleaned_predicted_tokens[i]}")
    print(f"Ground Truth: {cleaned_ground_truth_tokens[i]}")
    print("---")
# Out:
# Average Precision: 0.96
# Sentence 1 Precision: 1.00
# Predicted: ['นี่', 'หนังสือ']
# Ground Truth: ['นี่', 'หนังสือ']
# ---
# Sentence 2 Precision: 1.00
# Predicted: ['นั่น', 'สมุด']
# Ground Truth: ['นั่น', 'สมุด']
# ---
# Sentence 3 Precision: 0.50
# Predicted: ['นี่', 'อะไร']
# Ground Truth: ['นี่่', 'อะไร']
# ---
# Sentence 4 Precision: 1.00
# Predicted: ['นี่', 'นาฬิกา', 'หรือ', 'ปากกา']
# Ground Truth: ['นี่', 'นาฬิกา', 'หรือ', 'ปากกา']
# ---
# Sentence 5 Precision: 1.00
# Predicted: ['คุณ', 'เข้าใจ']
# Ground Truth: ['คุณ', 'เข้าใจ']
# ---
# Sentence 6 Precision: 1.00
# Predicted: ['ฉัน', 'ขอโทษ']
# Ground Truth: ['ฉัน', 'ขอโทษ']
# ---
# Sentence 7 Precision: 1.00
# Predicted: ['ขอบคุณ', 'พี่ชาย']
# Ground Truth: ['ขอบคุณ', 'พี่ชาย']
# ---
# Sentence 8 Precision: 1.00
# Predicted: ['โทรศัพท์', 'อยู่', 'ที่ไหน']
# Ground Truth: ['โทรศัพท์', 'อยู่', 'ที่ไหน']
# ---
# Sentence 9 Precision: 0.67
# Predicted: ['คุณ', 'คน', 'ที่ไหน']
# Ground Truth: ['คุณ', 'คน', 'ที่ี่ไหน']
# ---
# Sentence 10 Precision: 1.00
# Predicted: ['ขาย', 'ราคา', 'เท่าไร']
# Ground Truth: ['ขาย', 'ราคา', 'เท่าไร']
# ---
# Sentence 11 Precision: 1.00
# Predicted: ['โทรศัพท์', 'อยู่', 'บน', 'โต๊ะ']
# Ground Truth: ['โทรศัพท์', 'อยู่', 'บน', 'โต๊ะ']
# ---
# Sentence 12 Precision: 1.00
# Predicted: ['เขา', 'คน', 'ญี่ปุ่น', 'หรือ', 'คน', 'เกาหลีใต้']
# Ground Truth: ['เขา', 'คน', 'ญี่ปุ่น', 'หรือ', 'คน', 'เกาหลีใต้']
# ---
# Sentence 13 Precision: 1.00
# Predicted: ['ภาษาไทย', 'ยาก']
# Ground Truth: ['ภาษาไทย', 'ยาก']
# ---
# Sentence 14 Precision: 1.00
# Predicted: ['ภาษาไทย', 'ง่าย']
# Ground Truth: ['ภาษาไทย', 'ง่าย']
# ---
# Sentence 15 Precision: 1.00
# Predicted: ['ราคา', 'แพง']
# Ground Truth: ['ราคา', 'แพง']
# ---
# Sentence 16 Precision: 1.00
# Predicted: ['หนังสือ', 'อยู่', 'บน', 'เก้าอี้']
# Ground Truth: ['หนังสือ', 'อยู่', 'บน', 'เก้าอี้']
# ---
# Sentence 17 Precision: 1.00
# Predicted: ['คุณ', 'ชอบ', 'อาหาร', 'อะไร']
# Ground Truth: ['คุณ', 'ชอบ', 'อาหาร', 'อะไร']
# ---
# Sentence 18 Precision: 1.00
# Predicted: ['คุณ', 'ชอบ', 'อาหาร', 'จีน']
# Ground Truth: ['คุณ', 'ชอบ', 'อาหาร', 'จีน']
# ---
# Sentence 19 Precision: 1.00
# Predicted: ['คุณ', 'ชอบ', 'อาหาร', 'ไทย', 'หรือ', 'อาหาร', 'จีน']
# Ground Truth: ['คุณ', 'ชอบ', 'อาหาร', 'ไทย', 'หรือ', 'อาหาร', 'จีน']
# ---
# Sentence 20 Precision: 1.00
# Predicted: ['คุณ', 'อ่าน', 'ภาษาไทย']
# Ground Truth: ['คุณ', 'อ่าน', 'ภาษาไทย']
# ---
# Sentence 21 Precision: 1.00
# Predicted: ['คุณ', 'เขียน', 'ภาษาไทย']
# Ground Truth: ['คุณ', 'เขียน', 'ภาษาไทย']
# ---
# Sentence 22 Precision: 1.00
# Predicted: ['คุณ', 'ไป', 'ที่ไหน']
# Ground Truth: ['คุณ', 'ไป', 'ที่ไหน']
# ---
# Sentence 23 Precision: 1.00
# Predicted: ['เขา', 'ชอบ', 'ดื่ม', 'อะไร']
# Ground Truth: ['เขา', 'ชอบ', 'ดื่ม', 'อะไร']
# ---
# Sentence 24 Precision: 1.00
# Predicted: ['เขา', 'ทำงาน', 'ที่ไหน']
# Ground Truth: ['เขา', 'ทำงาน', 'ที่ไหน']
# ---
# Sentence 25 Precision: 1.00
# Predicted: ['ขอโทษ', 'พูด', 'ช้า', 'ลง']
# Ground Truth: ['ขอโทษ', 'พูด', 'ช้า', 'ลง']
# ---
# Sentence 26 Precision: 1.00
# Predicted: ['พูด', 'อีกที']
# Ground Truth: ['พูด', 'อีกที']
# ---
# Sentence 27 Precision: 0.80
# Predicted: ['เขา', 'มี', 'เวลา', 'ว่าง', 'วันเสาร์']
# Ground Truth: ['เขา', 'มี', 'เวลา', 'ว่าง', 'ทุกวัน', 'เสาร์']
# ---
# Sentence 28 Precision: 1.00
# Predicted: ['เมื่อวานนี้', 'ไป', 'ทำงาน']
# Ground Truth: ['เมื่อวานนี้', 'ไป', 'ทำงาน']
# ---
# Sentence 29 Precision: 1.00
# Predicted: ['หนึ่งสัปดาห์หน้า', 'เรียน', 'ภาษาไทย']
# Ground Truth: ['หนึ่งสัปดาห์หน้า', 'เรียน', 'ภาษาไทย']
# ---
# Sentence 30 Precision: 1.00
# Predicted: ['หนึ่งสัปดาห์ที่แล้ว', 'กลับบ้าน', 'ช้า', 'ทุกวัน']
# Ground Truth: ['หนึ่งสัปดาห์ที่แล้ว', 'กลับบ้าน', 'ช้า', 'ทุกวัน']
# ---
# Sentence 31 Precision: 1.00
# Predicted: ['อีก', 'สาม', 'ปี', 'กลับ', 'ประเทศไทย']
# Ground Truth: ['อีก', 'สาม', 'ปี', 'กลับ', 'ประเทศไทย']
# ---
# Sentence 32 Precision: 1.00
# Predicted: ['ตอนเที่ยง', 'กิน', 'ข้าวมันไก่', 'แล้ว']
# Ground Truth: ['ตอนเที่ยง', 'กิน', 'ข้าวมันไก่', 'แล้ว']
# ---
# Sentence 33 Precision: 1.00
# Predicted: ['ผม', 'พบ', 'แฟน', 'สวนสัตว์']
# Ground Truth: ['ผม', 'พบ', 'แฟน', 'สวนสัตว์']
# ---
# Sentence 34 Precision: 1.00
# Predicted: ['ตอนนี้', 'เวลา', 'กี่โมง']
# Ground Truth: ['ตอนนี้', 'เวลา', 'กี่โมง']
# ---
# Sentence 35 Precision: 1.00
# Predicted: ['คุณ', 'กิน', 'ข้าว', 'เช้า', 'กี่โมง']
# Ground Truth: ['คุณ', 'กิน', 'ข้าว', 'เช้า', 'กี่โมง']
# ---
# Sentence 36 Precision: 1.00
# Predicted: ['เขา', 'มาสาย']
# Ground Truth: ['เขา', 'มาสาย']
# ---
# Sentence 37 Precision: 0.83
# Predicted: ['ผม', 'เรียน', 'ภาษาไทย', 'เริ่ม', 'เวลา', 'บ่ายโมง']
# Ground Truth: ['ผม', 'เรียน', 'ภาษาไทย', 'เริ่ม', 'เวลา', 'บ่าย']
# ---
# Sentence 38 Precision: 1.00
# Predicted: ['ผม', 'อ่าน', 'หนังสือ', 'อยู่', 'ตอนนี้']
# Ground Truth: ['ผม', 'อ่าน', 'หนังสือ', 'อยู่', 'ตอนนี้']
# ---
# Sentence 39 Precision: 1.00
# Predicted: ['เขา', 'ไป', 'สนามบิน', 'เวลา', 'เที่ยง', 'ตรง']
# Ground Truth: ['เขา', 'ไป', 'สนามบิน', 'เวลา', 'เที่ยง', 'ตรง']
# ---
# Sentence 40 Precision: 1.00
# Predicted: ['ผม', 'ทำ', 'อาหาร', 'ไทย', 'ตอนเที่ยง']
# Ground Truth: ['ผม', 'ทำ', 'อาหาร', 'ไทย', 'ตอนเที่ยง']
# ---
# Sentence 41 Precision: 0.67
# Predicted: ['สามารถ', 'ไป', 'เข้า', 'ห้องน้ำ', 'ห้า', 'นาที']
# Ground Truth: ['สามารถ', 'ไป', 'เข้า', 'ห้องน้ำ', 'ได้', 'ห้า', 'นาที']
# ---
# Sentence 42 Precision: 1.00
# Predicted: ['ผม', 'ทำงาน', 'ห้า', 'ชั่วโมง']
# Ground Truth: ['ผม', 'ทำงาน', 'ห้า', 'ชั่วโมง']
# ---
# Sentence 43 Precision: 1.00
# Predicted: ['อีก', 'สิบ', 'นาที', 'กลับบ้าน']
# Ground Truth: ['อีก', 'สิบ', 'นาที', 'กลับบ้าน']
# ---
# Sentence 44 Precision: 1.00
# Predicted: ['พรุ่งนี้', 'ดิฉัน', 'ทำงาน', 'เวลา', 'เช้า']
# Ground Truth: ['พรุ่งนี้', 'ดิฉัน', 'ทำงาน', 'เวลา', 'เช้า']
# ---
# Sentence 45 Precision: 1.00
# Predicted: ['คุณ', 'ไป', 'ธนาคาร', 'กี่โมง']
# Ground Truth: ['คุณ', 'ไป', 'ธนาคาร', 'กี่โมง']
# ---
# Sentence 46 Precision: 0.80
# Predicted: ['วันนี้', 'วันหยุด', 'ทำ', 'อะไร', 'ดี']
# Ground Truth: ['วันนี้', 'วันหยุด ', 'ทำ', 'อะไร', 'ดี']
# ---
# Sentence 47 Precision: 1.00
# Predicted: ['พรุ่งนี้', 'วันอาทิตย์']
# Ground Truth: ['พรุ่งนี้', 'วันอาทิตย์']
# ---
# Sentence 48 Precision: 0.00
# Predicted: ['สิ้นเดือน', 'แล้ว', 'เงินเดือน', 'ออก']
# Ground Truth: ['แล้ว', 'เงินเดือน', 'ออก']
# ---
# Sentence 49 Precision: 1.00
# Predicted: ['วันปีใหม่', 'ไปเที่ยว', 'ที่ไหน']
# Ground Truth: ['วันปีใหม่', 'ไปเที่ยว', 'ที่ไหน']
# ---
# Sentence 50 Precision: 1.00
# Predicted: ['คุณ', 'ไป', 'ประเทศไทย', 'เดือน', 'อะไร']
# Ground Truth: ['คุณ', 'ไป', 'ประเทศไทย', 'เดือน', 'อะไร']
# ---
# Sentence 51 Precision: 1.00
# Predicted: ['วันหยุด', 'คุณ', 'ทำ', 'อะไร']
# Ground Truth: ['วันหยุด', 'คุณ', 'ทำ', 'อะไร']
# ---
# Sentence 52 Precision: 1.00
# Predicted: ['เมื่อวานนี้', 'คุณ', 'ทำ', 'อะไร']
# Ground Truth: ['เมื่อวานนี้', 'คุณ', 'ทำ', 'อะไร']
# ---
# Sentence 53 Precision: 1.00
# Predicted: ['ผม', 'อยู่', 'ประเทศไทย', 'นาน', 'หก', 'ปี', 'แล้ว']
# Ground Truth: ['ผม', 'อยู่', 'ประเทศไทย', 'นาน', 'หก', 'ปี', 'แล้ว']
# ---
# Sentence 54 Precision: 1.00
# Predicted: ['หนึ่งสัปดาห์หน้า', 'ทำ', 'อะไร']
# Ground Truth: ['หนึ่งสัปดาห์หน้า', 'ทำ', 'อะไร']
# ---
# Sentence 55 Precision: 1.00
# Predicted: ['เมื่อวานซืน', 'คุย', 'โทรศัพท์', 'แฟน', 'สอง', 'ชั่วโมง']
# Ground Truth: ['เมื่อวานซืน', 'คุย', 'โทรศัพท์', 'แฟน', 'สอง', 'ชั่วโมง']
# ---
# Predicted: ['ผม', 'ชอบ', 'คุย', 'คน', 'ไทย']
# Ground Truth: ['ผม', 'ชอบ', 'คุย', 'คน', 'ไทย']
# ---
# Sentence 71 Precision: 1.00
# Predicted: ['ประเทศไทย', 'ไม่มี', 'หิมะ', 'ตก']
# Ground Truth: ['ประเทศไทย', 'ไม่มี', 'หิมะ', 'ตก']
# ---
# Sentence 72 Precision: 1.00
# Predicted: ['ภูเขา', 'เดี๋ยวนี้', 'ไม่มี', 'ต้นไม้']
# Ground Truth: ['ภูเขา', 'เดี๋ยวนี้', 'ไม่มี', 'ต้นไม้']
# ---
# Sentence 73 Precision: 1.00
# Predicted: ['บ้าน', 'ไม่มี', 'คน', 'อยู่']
# Ground Truth: ['บ้าน', 'ไม่มี', 'คน', 'อยู่']
# ---
# Sentence 74 Precision: 1.00
# Predicted: ['วันนี้', 'มี', 'ไป', 'ทำ', 'ธุระ']
# Ground Truth: ['วันนี้', 'มี', 'ไป', 'ทำ', 'ธุระ']
# ---
# Sentence 75 Precision: 1.00
# Predicted: ['ผม', 'กิน', 'ข้าว', 'แล้ว']
# Ground Truth: ['ผม', 'กิน', 'ข้าว', 'แล้ว']
# ---
# Sentence 76 Precision: 1.00
# Predicted: ['ผม', 'ยัง', 'ไม่กิน', 'ข้าว']
# Ground Truth: ['ผม', 'ยัง', 'ไม่กิน', 'ข้าว']
# ---
# Sentence 77 Precision: 1.00
# Predicted: ['ฉัน', 'นั่ง', 'ร้องเพลงคาราโอเกะ']
# Ground Truth: ['ฉัน', 'นั่ง', 'ร้องเพลงคาราโอเกะ']
# ---
# Sentence 78 Precision: 1.00
# Predicted: ['เขา', 'ยืน', 'คุย', 'คุณ']
# Ground Truth: ['เขา', 'ยืน', 'คุย', 'คุณ']
# ---
# Sentence 79 Precision: 1.00
# Predicted: ['ผม', 'ชอบ', 'นั่ง', 'อ่าน', 'หนังสือ', 'บ้าน']
# Ground Truth: ['ผม', 'ชอบ', 'นั่ง', 'อ่าน', 'หนังสือ', 'บ้าน']
# ---
# Sentence 80 Precision: 1.00
# Predicted: ['พรุ่งนี้', 'อยาก', 'ไปเที่ยว', 'แฟน']
# Ground Truth: ['พรุ่งนี้', 'อยาก', 'ไปเที่ยว', 'แฟน']
# ---

# %% [markdown]
# ### NLP ทดสอบประโยคที่ตัดโดยไม่ได้เทรน ชีวิตประจำวัน

# %%
from pythainlp.tokenize import Tokenizer, word_tokenize
from pythainlp.corpus.common import thai_stopwords, thai_words

sentences = [
     "นี่หนังสือใช่ไหม", "นั่นสมุดใช่ไหม", "นี่อะไร", "นี่นาฬิกาหรือปากกา", "คุณเข้าใจไหม",
     "ฉันขอโทษ", "ขอบคุณนะพี่ชาย", "โทรศัพท์อยู่ที่ไหน", "คุณเป็นคนที่ไหน", "ขายราคาเท่าไร",
     "โทรศัพท์อยู่บนโต๊ะใช่ไหม", "เขาเป็นคนญี่ปุ่นหรือคนเกาหลีใต้", "ภาษาไทยยากไหม", "ภาษาไทยง่าย",
     "ราคาแพง", "หนังสืออยู่บนเก้าอี้", "คุณชอบอาหารอะไร", "คุณชอบอาหารจีนไหม", "คุณชอบอาหารไทยหรืออาหารจีน",
    "คุณอ่านภาษาไทยได้ไหม", "คุณเขียนภาษาไทยได้ไหม", "คุณจะไปที่ไหน", "เขาชอบดื่มอะไร", "เขาทำงานที่ไหน",
    "ขอโทษ พูดช้าลงหน่อยได้ไหม", "พูดอีกทีได้ไหม", "เขามีเวลาว่างทุกวันเสาร์", "เมื่อวานนี้ไปทำงาน",
    "หนึ่งสัปดาห์หน้าจะเรียนภาษาไทย", "หนึ่งสัปดาห์ที่แล้วกลับบ้านช้าทุกวัน", "อีกสามปีจะกลับประเทศไทย",
    "ตอนเที่ยงกินข้าวมันไก่แล้ว", "ผมพบกับแฟนที่สวนสัตว์", "ตอนนี้เวลากี่โมง", "คุณกินข้าวเช้ากี่โมง",
    "เขามาช้า", "ผมเรียนภาษาไทยเริ่มจากเวลาบ่ายโมง", "ผมอ่านหนังสืออยู่ตอนนี้", "เขาจะไปสนามบินเวลาเที่ยงตรง",
    "ผมจะทำอาหารไทยตอนเที่ยง", "สามารถไปเข้าห้องน้ำได้ห้านาที", "ผมทำงานห้าชั่วโมง", "อีกสิบนาทีจะกลับบ้าน",
    "พรุ่งนี้ดิฉันทำงานเวลาเช้า", "คุณจะไปธนาคารกี่โมง", "วันนี้วันหยุด ทำอะไรดี", "พรุ่งนี้วันอาทิตย์",
    "สิ้นเดือนแล้วเงินเดือนออก", "วันปีใหม่ไปเที่ยวที่ไหน", "คุณจะไปประเทศไทยเดือนอะไร", "วันหยุดนี้คุณจะทำอะไร",
    "เมื่อวานนี้คุณทำอะไร", "ผมอยู่ประเทศไทยนานหกปีแล้ว", "หนึ่งสัปดาห์หน้าจะทำอะไร",
    "เมื่อวานซืนคุยโทรศัพท์กับแฟนสองชั่วโมง", "เขาไปทำงานแต่เช้า", "วันเสาร์ฉันชอบไปเดินเล่น",
    "ผมกลับประเทศอังกฤษเดือนธันวาคม", "คุณไปออกกำลังกายกี่โมง", "คุณกินข้าวหรือยัง", "คุณอยากทำอะไร",
    "ฉันเคยไปประเทศเม็กซิโก", "อากาศร้อน เมื่อไรจะเข้าฤดูหนาว", "คุณพ่อไปกินข้าวที่ร้านอาหาร", "ปกติคุณไปทำงานยังไง",
    "ไปที่ไหนมา", "ผมอยากไปหาคุณ", "ฝนตกหนักมาก", "ผมขับรถยนต์ไปทำงาน", "ผมชอบคุยกับคนไทย",
    "ประเทศไทยไม่มีหิมะตก", "ภูเขาเดี๋ยวนี้ไม่มีต้นไม้", "ที่บ้านไม่มีคนอยู่", "วันนี้มีไปทำธุระ", "ผมทานข้าวแล้ว",
    "ผมยังไม่ทานข้าว", "ฉันนั่งร้องเพลงคาราโอเกะ", "เขายืนคุยกับคุณ", "ผมชอบนั่งอ่านหนังสือที่บ้าน",
    "พรุ่งนี้อยากไปเที่ยวกับแฟน", "เขายังไม่อยากเรียนภาษาไทยตอนนี้", "วันนี้ไม่อยากทำอะไร", "นี่ใคร",
    "ฉันไปว่ายน้ำออกกำลังกาย", "จำผมได้ไหม", "ได้ยินฉันไหม", "มองเห็นเขาไหม", "รู้จักเขาไหม", "ทำงานเสร็จแล้ว",
    "เมื่อวานนี้นอนหลับไม่ดี", "ง่วงนอนต้องการดื่มกาแฟ", "เขาฟังภาษาไทยไม่ได้", "ผมอ่านหนังสือภาษาไทยยังไม่ได้",
    "กินเผ็ดไม่ได้", "ไปประเทศไทยไม่ได้", "ผมคิดถึงคุณมาก", "เขามองดูทะเล", "ผมพูดภาษาไทยได้นิดหน่อย",
    "เขาอ่านภาษาอังกฤษไม่ผิดเลย", "อาหารไทยอร่อยมาก", "คุณจะไปประเทศไทยเดือนอะไร", "เขาชื่อเล่นอะไร",
    "พรุ่งนี้จะไปตัดผม", "ผมโกนหนวดทุกวันเวลาเช้า", "คนไทยชอบอาบน้ำ", "จะไปซื้อสบู่กับยาสีฟัน",
    "เขาชอบซื้อเสื้อแขนยาว", "ครอบครัวคุณมีกี่คน", "คุณทำงานอะไร", "คุณแต่งงานหรือยัง", "คุณมีลูกหรือยัง",
    "คุณอายุกี่ปี", "บ้านคุณมีแมวไหม", "ใครเป็นครูภาษาไทย", "ทำไมคุณเรียนภาษาไทย", "ทำไมคุณไม่มาวัดหนึ่งสัปดาห์ที่แล้ว",
    "ถ้าคุณรวย คุณอยากจะทำอะไร", "ถ้าฝนตกควรทำอะไรดี", "วันนี้อยากไปหาหมอฟัน", "ผมมีลุงที่อยู่อังกฤษ",
    "เขามีครอบครัวอยู่ที่ไทย", "ผมอยากแต่งงานกับคุณ", "ผมรักคุณมาก", "เขาสูงมาก", "คุณเรียนภาษาไทยกี่ชั่วโมง",
    "ผมชอบสีขาวมากกว่าสีดำ", "เครื่องบินลำนี้ใหญ่มาก", "เขารักเธอมาก", "เขาเกลียดคุณเพราะคุณชอบโกหก",
    "เสื้อยืดตัวนี้ไม่แพง", "ใครเขียนหนังสือสวย", "คุณชอบไปเที่ยวที่ไหน", "วันนี้กินกล้วยหอม",
    "เมื่อวานนี้คุณอ่านหนังสืออะไร", "ผมมีทีวีสามเครื่อง คอมพิวเตอร์หนึ่งเครื่อง",
    "นั่งเครื่องบินมาลงกรุงเทพฯ", "ผมซื้อบ้านใหม่", "เนื้อชิ้นนี้อร่อยมาก", "ดอกไม้ดอกนี้สวยมาก",
    "มีอาหารหกจานอยู่บนโต๊ะ"
]
# Set of words that should not be filtered out (คำศัพท์ที่ไม่ควรตัดออก)
important_words = {

}

# Custom function for lemmatization
def get_lemma(word):
    lemmas = {

        # Add more lemmas as needed
    }
    return lemmas.get(word, word)

# Reordering for TSL (focus on time elements first)
def reorder_to_tsl(words):
    simplified_sentence = [word for word in words if word not in []]

    # Define common time-related words
    time_words = []
    time_elements = [word for word in simplified_sentence if word in time_words]
    non_time_elements = [word for word in simplified_sentence if word not in time_words]

    # Reorder by placing time elements first
    reordered_sentence = time_elements + non_time_elements
    return reordered_sentence  # Return as a list

# Create a custom tokenizer by defining words to be used
# Remove words that should not be in the dictionary
custom_tokenizer = Tokenizer(custom_words)

# Stopwords
stopwords = set(thai_stopwords())

# Process each sentence through tokenization, stopword removal, lemmatization, and reordering
def process_sentence(sentence):
    # Tokenization using custom tokenizer
    tokens = custom_tokenizer.word_tokenize(sentence)

    # Stopword filtering, but keeping important words
    filtered_tokens = [token for token in tokens if token not in stopwords or token in important_words]

    # Lemmatization
    lemmatized_tokens = [get_lemma(token) for token in filtered_tokens]

    # Sentence reordering for TSL
    reordered_sentence = reorder_to_tsl(lemmatized_tokens)

    return reordered_sentence

# Process all sentences in the list
processed_sentences_train_notcostom = [process_sentence(sentence) for sentence in sentences]

# %% [markdown]
# ### NLP ทดสอบประโยคที่ตัดโดยไม่ได้เทรน ท่องเที่ยว

# %%
from pythainlp.tokenize import Tokenizer, word_tokenize
from pythainlp.corpus.common import thai_stopwords, thai_words

sentences = [
    "ฉันต้องการจองสองที่นั่งถึงกรุงเทพ",
    "คุณต้องการตั๋วเที่ยวเดียวหรือไปกลับ",
    "ตั๋วไปกลับราคาเท่าไร",
    "คุณต้องการจ่ายเงินสดหรือบัตรเครดิต",
    "ฉันขอดูตั๋วและหนังสือเดินทางของคุณได้ไหม",
    "วันนี้มีใครไปกับคุณไหม",
    "ฉันเอาสัมภาระมาสองชิ้น",
    "คุณอยากจะนั่งใกล้หน้าต่างหรือไม่",
    "เครื่องบินไปที่เกาะสมุยตั๋วหมดแล้ว",
    "คุณต้องการตั๋วเวลาบ่ายสองหรือสี่โมง",
    "หมายเลขที่นั่งของคุณคืออะไร",
    "โปรดเอาใส่ใจกับการสาธิตความปลอดภัยบนเครื่องบินสั้นๆ นี้",
    "ช่วยปิดโทรศัพท์มือถือและอุปกรณ์อิเล็กทรอนิกส์อื่นๆ",
    "กรุณารัดเข็มขัดนิรภัย",
    "เที่ยวบินใช้เวลานานเท่าไร",
    "คุณต้องการอาหารหรือเครื่องดื่มอะไรไหม",
    "คุณต้องการดื่มชาหรือกาแฟ",
    "ฉันอยากดื่มโค้กโดยไม่ใส่น้ำแข็ง",
    "เครื่องบินจะลงจอดในอีกประมาณสิบห้านาที",
    "เวลาที่ท่าอากาศยานสนามบินดอนเมืองตอนนี้คือสิบนาฬิกาห้านาที",
    "คุณมีสัญชาติอะไร",
    "ฉันเป็นคนไทย",
    "ฉันขอดูหนังสือเดินทางของคุณได้ไหม",
    "นี่คือหนังสือเดินทางของฉัน",
    "คุณมาทำงานหรือเที่ยว",
    "ทำไมคุณอยากไปประเทศสหรัฐอเมริกา",
    "มีเที่ยวบินไปเกาหลีใต้ เพราะฉันอยากไปเที่ยวกับครอบครัว",
    "ฉันเดินทางไปทำงาน",
    "ฉันไปเยี่ยมครอบครัว",
    "ฉันจะไปอยู่บ้านเพื่อนที่ชลบุรีเวลาหนึ่งเดือน",
    "ฉันสามารถจองโรงแรมได้หรือไม่",
    "สวัสดี ขอถามหน่อยว่าโรงแรมของคุณราคาเท่าไหร่",
    "ฉันต้องการเพียงหนึ่งห้องเท่านั้น",
    "ฉันจะอยู่เป็นเวลาหนึ่งสัปดาห์",
    "ฉันต้องการห้องตั้งแต่วันอังคารถึงวันศุกร์",
    "มีห้องว่างที่เป็นเตียงคู่เหลือเท่าไร",
    "ฉันจะอยู่ที่กรุงเทพอีกนาน",
    "ฉันต้องการอยู่พักแค่สองคน",
    "โรงแรมเหลือห้องสุดท้าย ต้องการจองไว้มั้ย",
    "ฉันต้องเดินไปที่ไหนเพื่อเข้าห้องน้ำ",
    "ฉันได้ทำการจองไว้แล้วตอนนี้ต้องการเช็คอิน",
    "ฉันขอดูบัตรประชาชนของคุณได้ไหม",
    "นี่คือกุญแจห้องของคุณ",
    "ฉันลืมบัตรเครดิต ขอเป็นจ่ายเงินสดแทน",
    "ฉันขอดูแผนที่ได้ไหม",
    "ฉันสามารถชำระเงินด้วยบัตรเครดิตได้หรือไม่",
    "คุณมีพนักงานดูแลกระเป๋าหรือไม่",
    "ช่วยเรียกรถแท็กซี่ให้ฉันหน่อยได้ไหม",
    "เสื้อนี่ราคาเท่าไร",
    "คุณมีเสื้อราคาถูกลงอีกไหม",
    "คุณมีสินค้านี้หรือไม่",
    "คุณรู้หรือไม่ว่ามีที่อื่นขายหรือไม่?",
    "คุณพูดภาษาอังกฤษได้ไหม",
    "ฉันชื่อเล่นว่าลิซ่า",
    "ฉันดีใจที่ได้พบคุณ",
    "คุณมาจากที่ไหน",
    "คุณจะอยู่ภูเก็ตนานเท่าไร",
    "ช่วยบอกทางไปน้ำตกหน่อยได้ไหม",
    "ห้องน้ำอยู่ที่ไหน",
    "คุณช่วยพาฉันไปสวนลุมพินีได้ไหม",
    "ฉันจะหารถเมล์ไปเซ็นทรัลได้ที่ไหน",
    "ฉันต้องการความช่วยเหลือจากคุณ",
    "ขนมนี่ราคาเท่าไร",
    "ขอโทษ คุณช่วยพูดซ้ำอีกทีได้ไหม",
    "ฉันจะเอาสิ่งของเหล่านี้กลับบ้าน",
    "ฉันจะหาอาหารอร่อยได้ที่ไหน",
    "เคยไปที่ถนนเยาวราชหรือยัง",
    "คุณช่วยเขียนลงกระดาษให้ฉันได้ไหม",
    "คุณพูดช้าลงหน่อยได้ไหม",
    "คุณช่วยบอกทางไปสถานีรถไฟให้ฉันหน่อยได้ไหม",
    "คุณรับบัตรเครดิตหรือไม่",
    "คุณช่วยบอกทางไปเซเว่นบนแผนที่ให้ฉันหน่อยได้ไหม",
    "ฉันหลงทาง",
    "ฉันไม่เข้าใจ",
    "ภาษาอังกฤษของฉันไม่ดีมาก",
    "โรงแรมอยู่ไกลมาก ขึ้นรถไฟความเร็วสูงไปดีกว่านะ",
    "คุณจะไปที่สนามบินกี่โมง",
    "เสร็จแล้วจะไปเที่ยวที่ไหนกันอีกดี",
    "เครื่องบินจะออกเมื่อไร",
    "ตรงไปข้างหน้าแล้วเลี้ยวซ้าย"
]
# Set of words that should not be filtered out (คำศัพท์ที่ไม่ควรตัดออก)
important_words = {

}

# Custom function for lemmatization
def get_lemma(word):
    lemmas = {

        # Add more lemmas as needed
    }
    return lemmas.get(word, word)

# Reordering for TSL (focus on time elements first)
def reorder_to_tsl(words):
    simplified_sentence = [word for word in words if word not in []]

    # Define common time-related words
    time_words = []
    time_elements = [word for word in simplified_sentence if word in time_words]
    non_time_elements = [word for word in simplified_sentence if word not in time_words]

    # Reorder by placing time elements first
    reordered_sentence = time_elements + non_time_elements
    return reordered_sentence  # Return as a list

# Create a custom tokenizer by defining words to be used
# Remove words that should not be in the dictionary
custom_tokenizer = Tokenizer(custom_words)

# Stopwords
stopwords = set(thai_stopwords())

# Process each sentence through tokenization, stopword removal, lemmatization, and reordering
def process_sentence(sentence):
    # Tokenization using custom tokenizer
    tokens = custom_tokenizer.word_tokenize(sentence)

    # Stopword filtering, but keeping important words
    filtered_tokens = [token for token in tokens if token not in stopwords or token in important_words]

    # Lemmatization
    lemmatized_tokens = [get_lemma(token) for token in filtered_tokens]

    # Sentence reordering for TSL
    reordered_sentence = reorder_to_tsl(lemmatized_tokens)

    return reordered_sentence

# Process all sentences in the list
travel_sentences_train_notcostom = [process_sentence(sentence) for sentence in sentences]

# %% [markdown]
# ###ประโยคชีวิตประจำวัน 140 ประโยค ที่ไม่มีการเทรน ได้ 11.43%

# %%
from sklearn.metrics import accuracy_score

# ตัวอย่างคำที่ตัดออกจากข้อความ
predicted_tokens = processed_sentences_train_notcostom
# คำที่ถูกต้องจากเฉลย
ground_truth_tokens = [
    ['นี่', 'หนังสือ'],
    ['นั่น', 'สมุด'],
    ['นี่', 'อะไร'],
    ['นี่', 'นาฬิกา', 'หรือ', 'ปากกา'],
    ['คุณ', 'เข้าใจ'],
    ['ฉัน', 'ขอโทษ'],
    ['ขอบคุณ', 'พี่ชาย'],
    ['โทรศัพท์', 'อยู่', 'ที่ไหน'],
    ['คุณ', 'คน', 'ที่ไหน'],
    ['ขาย', 'ราคา', 'เท่าไร'],
    ['โทรศัพท์', 'อยู่', 'บน', 'โต๊ะ'],
    ['เขา', 'คน', 'ญี่ปุ่น', 'หรือ', 'คน', 'เกาหลีใต้'],
    ['ภาษาไทย', 'ยาก'],
    ['ภาษาไทย', 'ง่าย'],
    ['ราคา', 'แพง'],
    ['หนังสือ', 'อยู่', 'บน', 'เก้าอี้'],
    ['คุณ', 'ชอบ', 'อาหาร', 'อะไร'],
    ['คุณ', 'ชอบ', 'อาหาร', 'จีน'],
    ['คุณ', 'ชอบ', 'อาหาร', 'ไทย', 'หรือ', 'อาหาร', 'จีน'],
    ['คุณ', 'อ่าน', 'ภาษาไทย'],
    ['คุณ', 'เขียน', 'ภาษาไทย'],
    ['คุณ', 'ไป', 'ที่ไหน'],
    ['เขา', 'ชอบ', 'ดื่ม', 'อะไร'],
    ['เขา', 'ทำงาน', 'ที่ไหน'],
    ['ขอโทษ', 'พูด', 'ช้า', 'ลง'],
    ['พูด', 'อีกที'],
    ['เขา', 'มี', 'เวลา', 'ว่าง', 'ทุกวัน', 'เสาร์'],
    ['เมื่อวานนี้', 'ไป', 'ทำงาน'],
    ['ผม', 'อยาก', 'ไป', 'หา', 'คุณ'],
    ['ฝนตกหนัก', 'มาก'],
    ['ผม', 'ขับรถ', 'รถยนต์', 'ไป', 'ทำงาน'],
    ['ผม', 'ชอบ', 'คุย', 'คน', 'ไทย'],
    ['ประเทศไทย', 'ไม่มี', 'หิมะ', 'ตก'],
    ['ภูเขา', 'เดี๋ยวนี้', 'ไม่มี', 'ต้นไม้'],
    ['บ้าน', 'ไม่มี', 'คน', 'อยู่'],
    ['วันนี้', 'มี', 'ไป', 'ทำ', 'ธุระ'],
    ['ผม', 'กิน', 'ข้าว', 'แล้ว'],
    ['ผม', 'ยัง', 'ไม่กิน', 'ข้าว'],
    ['ฉัน', 'นั่ง', 'ร้องเพลงคาราโอเกะ'],
    ['เขา', 'ยืน', 'คุย', 'คุณ'],
    ['ผม', 'ชอบ', 'นั่ง', 'อ่าน', 'หนังสือ', 'บ้าน'],
    ['พรุ่งนี้', 'อยาก', 'ไปเที่ยว', 'แฟน'],
    ['เขา', 'ยัง', 'ไม่', 'อยาก', 'เรียน', 'ภาษาไทย', 'ตอนนี้'],
    ['วันนี้', 'ไม่', 'อยาก', 'ทำ', 'อะไร'],
    ['นี่', 'ใคร'],
    ['ฉัน', 'ไป', 'ว่ายน้ำ', 'ออกกำลังกาย'],
    ['จำ', 'ผม'],
    ['ได้ยิน', 'ฉัน'],
    ['มอง', 'เห็น', 'เขา'],
    ['รู้จัก', 'เขา'],
    ['ทำงาน', 'เสร็จแล้ว'],
    ['เมื่อวานนี้', 'นอนหลับ', 'ไม่ดี'],
    ['ง่วงนอน', 'ต้องการ', 'ดื่ม', 'กาแฟ'],
    ['เขา', 'ฟัง', 'ภาษาไทย', 'ไม่'],
    ['ผม', 'อ่าน', 'หนังสือ', 'ภาษาไทย', 'ยัง', 'ไม่'],
    ['กิน', 'เผ็ด', 'ไม่'],
    ['ไป', 'ประเทศไทย', 'ไม่'],
    ['ผม', 'คิดถึง', 'คุณ', 'มาก'],
    ['เขา', 'มองดู', 'ทะเล'],
    ['ผม', 'พูด', 'ภาษาไทย', 'นิดหน่อย'],
    ['เขา', 'อ่าน', 'ภาษาอังกฤษ', 'ไม่', 'ผิด'],
    ['อาหาร', 'ไทย', 'อร่อย', 'มาก'],
    ['คุณ', 'ไป', 'ประเทศไทย', 'เดือน', 'อะไร'],
    ['เขา', 'ชื่อเล่น', 'อะไร'],
    ['พรุ่งนี้', 'ไป', 'ตัด', 'ผม', '(เส้นผม)'],
    ['ผม', 'โกนหนวด', 'ทุกวัน', 'เวลา', 'เช้า'],
    ['คน', 'ไทย', 'ชอบ', 'อาบน้ำ'],
    ['ไป', 'ซื้อ', 'สบู่', 'ยาสีฟัน'],
    ['เขา', 'ชอบ', 'ซื้อ', 'เสื้อแขนยาว'],
    ['ครอบครัว', 'คุณ', 'มี', 'คน'],
    ['คุณ', 'ทำงาน', 'อะไร'],
    ['คุณ', 'แต่งงาน', 'หรือ', 'ยัง'],
    ['คุณ', 'มี', 'ลูก', 'หรือ', 'ยัง'],
    ['คุณ', 'อายุ', 'ปี'],
    ['บ้าน', 'คุณ', 'มี', 'แมว'],
    ['ใคร', 'ครู', 'ภาษาไทย'],
    ['ทำไม', 'คุณ', 'เรียน', 'ภาษาไทย'],
    ['ทำไม', 'คุณ', 'ไม่', 'มา', 'วัด', 'หนึ่งสัปดาห์ที่แล้ว'],
    ['ถ้า', 'คุณ', 'รวย', 'คุณ', 'อยาก', 'ทำ', 'อะไร'],
    ['ถ้า', 'ฝนตก', 'ทำ', 'อะไร', 'ดี'],
    ['วันนี้', 'อยาก', 'ไป', 'หา', 'หมอ', 'ฟัน'],
    ['ผม', 'มี', 'ลุง', 'อยู่', 'อังกฤษ'],
    ['เขา', 'มี', 'ครอบครัว', 'อยู่', 'ไทย'],
    ['ผม', 'อยาก', 'แต่งงาน', 'คุณ'],
    ['ผม', 'รัก', 'คุณ', 'มาก'],
    ['เขา', 'สูง', 'มาก'],
    ['คุณ', 'เรียน', 'ภาษาไทย', 'ชั่วโมง'],
    ['ผม', 'ชอบ', 'สีขาว', 'มาก', 'สีดำ'],
    ['เครื่องบิน', 'ลำ', 'ใหญ่', 'มาก'],
    ['เขา', 'รัก', 'เธอ', 'มาก'],
    ['เขา', 'เกลียด', 'คุณ', 'คุณ', 'ชอบ', 'โกหก'],
    ['เสื้อยืด', 'ตัว', 'ไม่', 'แพง'],
    ['ใคร', 'เขียน', 'หนังสือ', 'สวย'],
    ['คุณ', 'ชอบ', 'ไปเที่ยว', 'ที่ไหน'],
    ['วันนี้', 'กิน', 'กล้วยหอม'],
    ['เมื่อวานนี้', 'คุณ', 'อ่าน', 'หนังสือ', 'อะไร'],
    ['ผม', 'มี', 'ทีวี', 'สาม', 'เครื่อง', 'คอมพิวเตอร์', 'หนึ่ง', 'เครื่อง'],
    ['นั่ง', 'เครื่องบิน', 'มา', 'ลง', 'กรุงเทพฯ'],
    ['ผม', 'ซื้อ', 'บ้าน', 'ใหม่'],
    ['เนื้อ', 'ชิ้น', 'อร่อย', 'มาก'],
    ['ดอกไม้', 'ดอก', 'สวย', 'มาก'],
    ['มี', 'อาหาร', 'หก', 'จาน', 'อยู่', 'บน', 'โต๊ะ']
]

# ฟังก์ชันคำนวณความแม่นยำสำหรับแต่ละประโยค
def calculate_sentence_accuracy(predicted, ground_truth):
    # ตรวจสอบว่าแต่ละประโยคตรงกันหรือไม่
    correct_sentences = sum([pred == gt for pred, gt in zip(predicted, ground_truth)])

    # คำนวณเปอร์เซ็นต์ความแม่นยำ
    accuracy = correct_sentences / len(ground_truth) * 100
    return accuracy

# คำนวณความแม่นยำสำหรับแต่ละประโยค
accuracy = calculate_sentence_accuracy(predicted_tokens, ground_truth_tokens)

# แสดงผล
print(f"Sentence-level Accuracy: {accuracy:.2f}%")
# Out:
# Sentence-level Accuracy: 11.43%

# %% [markdown]
# ###ประโยคท่องเที่ยว 80 ประโยค ที่ไม่มีการเทรน ได้ 0%

# %%
import pandas as pd
import numpy as np

# Path to the ground truth file
ground_truth_tokens_path = '/content/drive/MyDrive/Thesis/Project/ประโยคจากหนังสือ.xlsx'

# Load the data from the Excel sheet (sheet_name=2 refers to the 3rd sheet)
df = pd.read_excel(ground_truth_tokens_path, sheet_name=4)

# Columns representing tokenized words
selected_columns = ['word_1', 'word_2', 'word_3', 'word_4', 'word_5', 'word_6', 'word_7', 'word_8', 'word_9', 'word_10', 'word_11']

# Extract the relevant columns
df_selected = df[selected_columns]

# Convert the DataFrame to a list of lists (ground truth tokens)
ground_truth_tokens = df_selected.values.tolist()

# Predicted tokens (ensure that processed_sentences_train is defined)
predicted_tokens = travel_sentences_train_notcostom  # Ensure this is a list of lists as well

# ฟังก์ชันทำความสะอาดประโยคโดยการกำจัดค่า nan ออก
def clean_tokens(tokens):
    return [token for token in tokens if token is not np.nan]

# ทำความสะอาดทั้ง predicted และ ground truth
cleaned_predicted_tokens = [clean_tokens(pred) for pred in predicted_tokens]
cleaned_ground_truth_tokens = [clean_tokens(gt) for gt in ground_truth_tokens]

# ฟังก์ชันคำนวณความแม่นยำสำหรับแต่ละประโยค
def calculate_sentence_accuracy(predicted, ground_truth):
    correct_sentences = sum([pred == gt for pred, gt in zip(predicted, ground_truth)])
    accuracy = correct_sentences / len(ground_truth) * 100
    return accuracy

# คำนวณความแม่นยำหลังทำความสะอาดข้อมูล
accuracy = calculate_sentence_accuracy(cleaned_predicted_tokens, cleaned_ground_truth_tokens)

# แสดงผล
print(f"Sentence-level Accuracy: {accuracy:.2f}%")

for i in range(80):
    print(f"Predicted: {cleaned_predicted_tokens[i]}")
    print(f"Ground Truth: {cleaned_ground_truth_tokens[i]}")
    print("---")
# Out:
# Sentence-level Accuracy: 0.00%
# Predicted: ['ต้องการ', 'จอง', 'สอง', 'ที่นั่ง', 'กรุงเทพ']
# Ground Truth: ['ฉัน', 'ต้องการ', 'จอง', 'สอง', 'ที่นั่ง', 'กรุงเทพ']
# ---
# Predicted: ['ต้องการ', 'ตั๋ว', 'เที่ยว']
# Ground Truth: ['คุณ', 'ต้องการ', 'ตั๋ว', 'เที่ยว', 'หรือ', 'ไป', 'กลับ']
# ---
# Predicted: ['ตั๋วไปกลับ', 'ราคา']
# Ground Truth: ['ตั๋ว', 'ไป', 'กลับ', 'ราคา', 'เท่าไร']
# ---
# Predicted: ['ต้องการ', 'จ่าย', 'เงินสด', 'บัตรเครดิต']
# Ground Truth: ['คุณ', 'ต้องการ', 'จ่าย', 'เงินสด', 'หรือ', 'บัตรเครดิต']
# ---
# Predicted: ['ดู', 'ตั๋ว', 'หนังสือเดินทาง', 'ไหม']
# Ground Truth: ['ฉัน', 'ดู', 'ตั๋ว', 'หนังสือเดินทาง', 'คุณ', 'ได้ไหม']
# ---
# Predicted: ['ไหม']
# Ground Truth: ['วันนี้', 'มี', 'ใคร', 'ไป', 'คุณ']
# ---
# Predicted: ['สัมภาระ', 'สอง', 'ชิ้น']
# Ground Truth: ['ฉัน', 'เอา', 'สัมภาระ', 'มา', 'สอง', 'ชิ้น']
# ---
# Predicted: ['นั่ง', 'หน้าต่าง']
# Ground Truth: ['คุณ', 'อยาก', 'นั่ง', 'ใกล้', 'หน้าต่าง', 'หรือ', 'ไม่']
# ---
# Predicted: ['เครื่องบิน', 'เกาะ', 'สมุย', 'ตั๋ว']
# Ground Truth: ['เครื่องบิน', 'ไป', 'เกาะสมุย', 'ตั๋ว', 'หมด', 'แล้ว']
# ---
# Predicted: ['ต้องการ', 'ตั๋ว', 'เวลา', 'บ่าย', 'สอง', 'สี่', 'โมง']
# Ground Truth: ['คุณ', 'ต้องการ', 'ตั๋ว', 'เวลา', 'บ่าย', 'สอง', 'หรือ', 'สี่', 'โมง']
# ---
# Predicted: ['หมายเลข', 'ที่นั่ง']
# Ground Truth: ['หมายเลข', 'ที่นั่ง', 'คุณ', 'อะไร']
# ---
# Predicted: ['โปรด', 'ใส่ใจ', 'การสาธิต', 'ความปลอดภัย', 'เครื่องบิน', ' ']
# Ground Truth: ['โปรด', 'เอาใส่ใจ', 'สาธิต', 'ปลอดภัย', 'บน', 'เครื่องบิน', 'สั้น']
# ---
# Predicted: ['โทรศัพท์มือถือ', 'อุปกรณ์', 'อิเล็กทรอนิกส์']
# Ground Truth: ['ช่วย', 'ปิด', 'โทรศัพท์มือถือ', 'อุปกรณ์', 'อิเล็กทรอนิกส์']
# ---
# Predicted: ['กรุณา', 'รัด', 'เข็มขัดนิรภัย']
# Ground Truth: ['กรุณา', 'รัด', 'เข็มขัด', 'นิรภัย']
# ---
# Predicted: ['เที่ยวบิน', 'ใช้เวลานาน']
# Ground Truth: ['เที่ยว', 'บิน', 'ใช้', 'เวลา', 'นาน', 'เท่าไร']
# ---
# Predicted: ['ต้องการ', 'อาหาร', 'เครื่องดื่ม', 'ไหม']
# Ground Truth: ['คุณ', 'ต้องการ', 'อาหาร', 'หรือ', 'เครื่องดื่ม', 'อะไร']
# ---
# Predicted: ['ต้องการ', 'ดื่ม', 'ชา', 'กาแฟ']
# Ground Truth: ['คุณ', 'ต้องการ', 'ดื่ม', 'ชา', 'หรือ', 'กาแฟ']
# ---
# Predicted: ['ดื่ม', 'โค้ก', 'ใส่', 'น้ำแข็ง']
# Ground Truth: ['ฉัน', 'อยาก', 'ดื่ม', 'โค้ก', 'ไม่', 'น้ำแข็ง']
# ---
# Predicted: ['เครื่องบิน', 'จอด', 'สิบห้า', 'นาที']
# Ground Truth: ['เครื่องบิน', 'ลง', 'จอด', 'อีก', 'ประมาณ', 'สิบห้า', 'นาที']
# ---
# Predicted: ['เวลา', 'ท่าอากาศยาน', 'สนามบิน', 'ดอนเมือง', 'ตอนนี้', 'สิบ', 'นาฬิกา', 'ห้า', 'นาที']
# Ground Truth: ['เวลา', 'ท่าอากาศยาน', 'สนามบิน', 'ดอนเมือง', 'ตอนนี้', 'คือ', 'สิบ', 'นาฬิกา', 'ห้า', 'นาที']
# ---
# Predicted: ['สัญชาติ']
# Ground Truth: ['คุณ', 'มี', 'สัญชาติ', 'อะไร']
# ---
# Predicted: ['คน', 'ไทย']
# Ground Truth: ['ฉัน', 'คน', 'ไทย']
# Ground Truth: ['โรงแรม', 'เหลือ', 'ห้อง', 'สุดท้าย', 'ต้องการ', 'จอง']
# ---
# Predicted: ['เดิน', 'ห้องน้ำ']
# Ground Truth: ['ฉัน', 'ต้อง', 'เดิน', 'ไป', 'ที่ไหน', 'เข้า', 'ห้องน้ำ']
# ---
# Predicted: ['ทำการ', 'จอง', 'ตอนนี้', 'ต้องการ', 'เช็ค', 'อิน']
# Ground Truth: ['ฉัน', 'ได้', 'จอง', 'แล้ว', 'ตอนนี้', 'ต้องการ', 'เช็คอิน']
# ---
# Predicted: ['ดู', 'บัตรประชาชน', 'ไหม']
# Ground Truth: ['ฉัน', 'ดู', 'บัตรประชาชน', 'คุณ', 'ได้ไหม']
# ---
# Predicted: ['กุญแจ', 'ห้อง']
# Ground Truth: ['นี่', 'กุญแจ', 'ห้อง', 'คุณ']
# ---
# Predicted: ['ลืม', 'บัตรเครดิต', ' ', 'จ่าย', 'เงินสด', 'แทน']
# Ground Truth: ['ฉัน', 'ลืม', 'บัตรเครดิต', 'จ่าย', 'เงินสด', 'แทน']
# ---
# Predicted: ['ดู', 'แผนที่', 'ไหม']
# Ground Truth: ['ฉัน', 'ขอ', 'ดู', 'แผนที่', 'ได้ไหม']
# ---
# Predicted: ['ชำระเงิน', 'บัตรเครดิต']
# Ground Truth: ['ฉัน', 'สามารถ', 'ชำระเงิน', 'บัตรเครดิต', 'ได้', 'หรือ', 'ไม่']
# ---
# Predicted: ['พนักงาน', 'ดูแล', 'กระเป๋า']
# Ground Truth: ['คุณ', 'มี', 'พนักงาน', 'ดูแล', 'กระเป๋า', 'หรือ', 'ไม่']
# ---
# Predicted: ['รถแท็กซี่', 'ไหม']
# Ground Truth: ['ช่วย', 'เรียก', 'รถแท็กซี่', 'ให้', 'ฉัน', 'ได้ไหม']
# ---
# Predicted: ['เสื้อ', 'ราคา']
# Ground Truth: ['เสื้อ', 'นี่', 'ราคา', 'เท่าไร']
# ---
# Predicted: ['เสื้อ', 'ราคา', 'ไหม']
# Ground Truth: ['คุณ', 'มี', 'เสื้อ', 'ราคา', 'ถูก', 'ลง', 'อีก']
# ---
# Predicted: ['สินค้า']
# Ground Truth: ['คุณ', 'มี', 'สินค้า', 'นี้', 'หรือ', 'ไม่']
# ---
# Predicted: ['รู้', 'ที่อื่น', 'ขาย', '?']
# Ground Truth: ['คุณ', 'รู้', 'หรือ', 'ไม่', 'มี', 'ที่อื่น', 'ขาย']
# ---
# Predicted: ['ภาษาอังกฤษ', 'ไหม']
# Ground Truth: ['คุณ', 'พูด', 'ภาษาอังกฤษ', 'ได้ไหม']
# ---
# Predicted: ['ชื่อเล่น', 'ลิ', 'ซ่า']
# Ground Truth: ['ฉัน', 'ชื่อเล่น', 'ลิซ่า']
# ---
# Predicted: ['ดีใจ']
# Ground Truth: ['ฉัน', 'ดีใจ', 'ได้', 'พบ', 'คุณ']
# ---
# Predicted: ['มาจาก']
# Ground Truth: ['คุณ', 'มาจาก', 'ที่ไหน']
# ---
# Predicted: ['ภูเก็ต']
# ---
# Predicted: ['โรงแรม', ' ', 'รถไฟ', 'ความเร็ว', 'ดีกว่า']
# Ground Truth: ['โรงแรม', 'อยู่', 'ไกลมาก', 'ขึ้น', 'รถไฟความเร็วสูง', 'ไป', 'ดีกว่า']
# ---
# Predicted: ['สนามบิน', 'กี่โมง']
# Ground Truth: ['คุณ', 'ไป', 'สนามบิน', 'เวลา', 'กี่โมง']
# ---
# Predicted: ['ไปเที่ยว', 'ดี']
# Ground Truth: ['เสร็จแล้ว', 'ไป', 'เที่ยว', 'ที่ไหน', 'อีก', 'ดี']
# ---
# Predicted: ['เครื่องบิน']
# Ground Truth: ['เครื่องบิน', 'ออก', 'เมื่อไร']
# ---
# Predicted: ['ข้างหน้า', 'เลี้ยวซ้าย']
# Ground Truth: ['ตรง', 'ไป', 'ข้างหน้า', 'แล้ว', 'เลี้ยวซ้าย']
# ---

# %% [markdown]
# ### เล่มที่ 2 ไม่ใช้

# %%
from pythainlp.tokenize import word_tokenize
from pythainlp.corpus.common import thai_stopwords

sentences = [
    "สวัสดีครับ", "สบายดีหรือ", "ขอบคุณครับ", "ขอบพระคุณครับ", "ขอบใจครับ", "เชิญครับ",
    "ดีใจที่ได้พบคุณ", "ลาก่อนนะ", "พบกันใหม่นะ", "พบกันใหม่วันจันทร์", "ราตรีสวัสดิ์",
    "นายพงษ์พบมิสเตอร์จอห์นตอนเช้า", "สวัสดีครับคุณจอห์น", "แล้วคุณล่ะ", "ผมสบายดีครับ",
    "นางสาวแดงพบมิสเตอร์เจมส์ในตอนบ่าย", "มิสเตอร์ดำพบนางสาวมาเรียในตอนกลางคืน",
    "นายพงษ์แนะนำให้มิสเตอร์จอห์นรู้จักกับนางสาวแดง", "ผมขอแนะนำให้คุณรู้จักคุณแดง",
    "ผมดีใจที่ได้รู้จัก", "คุณรู้จักคุณแดงหรือเปล่า", "ขอถามหน่อยว่าคุณเป็นใคร",
    "นี่คือนามบัตรของผม", "ผมดีใจที่ได้รู้จักคุณ", "คุณมาจากไหน", "คุณเป็นคนที่ไหน",
    "ผมเป็นคนเชียงใหม่", "คุณอยู่ที่ไหน", "ผมอยู่ในกรุงเทพ", "ผมอยู่ถนนสุขุมวิท",
    "ฉันอยู่บ้านเลขที่ 17/231 สุขุมวิท ซอย 6", "ลูกชายคุณสบายดีหรือ", "ครอบครัวคุณสบายดีหรือ",
    "คุณพ่อคุณสบายดีหรือ", "คุณพูดภาษาอังกฤษได้ไหม", "เปล่าผมพูดภาษาอังกฤษไม่ได้",
    "ผมพูดภาษาอังกฤษได้นิดหน่อย", "ผมไม่เข้าใจ", "ผมไม่รู้", "ผมพููดภาษาคุณไม่ได้",
    "กรุณาพูดช้าๆ", "พูดอีกทีสิ", "คุณพูดได้กี่ภาษา", "คุณเข้าใจไหม", "คุณเข้าใจที่ผมพูดไหม",
    "ภาษาไทยยากไหม", "ภาษาไทยง่ายมากใช่ไหม", "ผมพูดภาษาไทย, อังกฤษ,เยอรมันและสวีเดน",
    "กี่โมงแล้ว", "คุณชื่ออะไร", "พบกันใหม่วันจันทร์", "พบกันใหม่นะ", "ขอโทษครับ",
    "ช่วยฉันหน่อยได้ไหม", "บอกฉันหน่อยได้ไหม", "ที่นี่มีไหม", "ที่นี่มีน้ำดื่มไหม",
    "คุณมีบุหรี่ไหม", "ราคาเท่าไหร่", "ฉันไปนะ", "ไชโย", "คุณรับเครดิตการ์ดไหม",
    "ห้องน้ำอยู่ที่ไหน", "เที่ยวบินไปเชียงใหม่ออกเมื่อไหร่", "เป็นเที่ยวบินตรงใช่ไหม",
    "ฉันต้องเปลี่ยนเครื่องบินไหม", "ฉันต้องเช็คอินเมื่อไหร่", "ฉันต้องการตั๋วเดี่ยวหนึ่งใบไปเชียงใหม่",
    "ฉันต้องการตั๋วไปกลับไปเชียงใหม่", "ฉันต้องการที่นั่งไม่สูบบุหรี่", "ฉันต้องการที่นั่งใกล้หน้าต่าง",
    "เที่ยวบินนี้จะเลื่อนเวลาออกไปกี่ชั่วโมง", "เที่ยวบินนี้จะช้ากี่ชั่วโมง",
    "เที่ยวบินไปเชียงใหม่อยู่ประตูไหน", "เราจะถึงเชียงใหม่กี่โมง", "ฉันรู้สึกไม่สบายมาก",
    "คุณมีห้องว่างไหม", "ฉันได้จองไว้แล้ว", "ฉันต้องการห้องเดี่ยว", "ฉันต้องการห้องคู่",
    "ฉันต้องการห้องที่มีห้องน้ำในตัว", "ฉันต้องการห้องที่มีระเบียง", "ฉันต้องการห้องเพียงคืนเดียว",
    "คืนละเท่าไหร่", "ฉันยังไม่รู้ฉันจะพักกี่คืน", "คำตอบที่คุณจะได้รับ", "ฉันเสียใจ",
    "ห้องเต็มแล้ว", "ไม่มีห้องเดี่ยวเหลืออยู่แล้ว", "ไม่มีห้องคู่เหลืออยู่แล้ว",
    "คุณจะชำระเงินอย่างไร", "กรุณาเขียนรายละเอียดในแบบฟอร์มนี้", "กรุณาเซ็นต์ชื่อ",
    "กรุณาชำระเงินล่วงหน้า", "อาหารเช้ากี่โมง", "อาหารเย็นกี่โมง",
    "กรุณานำกระเป๋าเดินทางไปที่ห้องฉันด้วย", "ฉันทานอาหารเช้าในห้องได้ไหม", "ฉันจะกลับวันพรุ่งนี้",
    "เก็บตังค์ด้วยครับ", "ฉันชำระเงินด้วยบัตรเครดิต", "ฉันชำำระเงินสด",
    "กรุณาเรียกแท็กซี่ให้ฉันหน่อยได้ไหม", "กรุณาแนะนำโรงแรมแห่งอื่นให้ฉันได้ไหม",
    "รถไฟออกเมื่อไหร่", "รถไฟมาถึงสถานีเมื่อไหร่", "รถไฟมาถึงสถานี 2 ทุ่ม", "เชิญนั่งครับ",
    "คุณเรียกสิ่งนี้เป็นภาษาไทยว่ายังไง", "นั่นหมายความว่าอย่างไร", "พบกันใหม่", "ผมหิว",
    "ผมกระหายน้ำ", "ผมหลงทาง", "เร็วหน่อย", "คุณต้องการอะไร", "อะไรนะ", "เป็นอะไรไป",
    "เกิดอะไรขึ้น", "รอเดี๋ยว", "รอสักครู่นะครับ", "คุณจะไปไหน", "ช่วยตัวเองนะ",
    "เชิญตามสบายนะ", "ทำต่อไป", "ดูที่นั่นซิ", "มันมากเกินไป", "มันแพงเกินไป",
    "คุณใจดีมาก", "ผมไม่ได้คิดเช่นนั้น", "คุณรู้ไหม", "เปล่าผมไม่รู้", "จดไว้สิ",
    "ยาวเท่าไหร่", "ใช่แล้ว", "สายเกินไปแล้ว", "เช้าเกินไปแล้ว", "เร็วที่สุดเท่าที่จะทำได้",
    "ไม่เป็นไร", "ระวังนะ", "ฟังสิ!ฟังนะ!", "ดูนี่สิ", "มีอะไรจะให้ผมช่วยบ้าง", "ผมผิดเอง",
    "มันเป็นความผิดของผม", "ผมไม่ผิด", "มันไม่ใช่ความผิดของผม", "ออกไป", "คุณคิดว่าอย่างไร",
    "ขอเลขโทรศัพท์หน่อยสิ", "ผมเข้าไปข้างในได้ไหม", "คุณเห็นไหม", "ผมขอสูบบุหรี่ได้ไหม",
    "ผมต้องจ่ายเท่าไหร่", "ขออนุญาตถ่ายรูปได้ไหม", "เรียกแท็กซี่ให้ผมหน่อยได้ไหม",
    "พาผมกลับไปที่โรงแรมเดี๋ยวนี้", "วันนี้อัตราแลกเปลี่ยนเป็นเท่าไหร่", "ผมต้องการไปซื้อของ"
]

# Example stopwords (can be expanded)
stopwords = set(thai_stopwords())

def process_sentence(sentence):
    # Tokenization
    tokens = word_tokenize(sentence, engine="newmm")

    # Stopword filtering
    filtered_tokens = [token for token in tokens if token not in stopwords]

    # Lemmatization (dummy implementation)
    lemmatized_tokens = [token for token in filtered_tokens]  # Add lemmatization logic here

    # Sentence reordering (dummy implementation)
    reordered_sentence = " ".join(lemmatized_tokens)  # Add reordering logic here

    return reordered_sentence

# Process all sentences in the list
processed_sentences_test = [process_sentence(sentence) for sentence in sentences]

# Output the results
for i, sentence in enumerate(processed_sentences_test):
    print(f"Original: {sentences[i]}")
    print(f"Processed: {sentence}\n")
# Out:
# Original: สวัสดีครับ
# Processed: สวัสดี
#
# Original: สบายดีหรือ
# Processed: สบายดี
#
# Original: ขอบคุณครับ
# Processed: ขอบคุณ
#
# Original: ขอบพระคุณครับ
# Processed: ขอบพระคุณ
#
# Original: ขอบใจครับ
# Processed: ขอบใจ
#
# Original: เชิญครับ
# Processed: เชิญ
#
# Original: ดีใจที่ได้พบคุณ
# Processed: ดีใจ
#
# Original: ลาก่อนนะ
# Processed: ลาก่อน
#
# Original: พบกันใหม่นะ
# Processed: พบกัน
#
# Original: พบกันใหม่วันจันทร์
# Processed: พบกัน จันทร์
#
# Original: ราตรีสวัสดิ์
# Processed: ราตรีสวัสดิ์
#
# Original: นายพงษ์พบมิสเตอร์จอห์นตอนเช้า
# Processed: พงษ์ มิสเตอร์ จอห์น ตอนเช้า
#
# Original: สวัสดีครับคุณจอห์น
# Processed: สวัสดี จอห์น
#
# Original: แล้วคุณล่ะ
# Processed: ล่ะ
#
# Original: ผมสบายดีครับ
# Processed: ผม สบายดี
#
# Original: นางสาวแดงพบมิสเตอร์เจมส์ในตอนบ่าย
# Processed: แดง มิสเตอร์ เจมส์ ตอนบ่าย
#
# Original: มิสเตอร์ดำพบนางสาวมาเรียในตอนกลางคืน
# Processed: มิสเตอร์ ดำ เรีย ตอนกลางคืน
#
# Original: นายพงษ์แนะนำให้มิสเตอร์จอห์นรู้จักกับนางสาวแดง
# Processed: พงษ์ แนะนำ มิสเตอร์ จอห์น รู้จัก แดง
#
# Original: ผมขอแนะนำให้คุณรู้จักคุณแดง
# Processed: ผม แนะนำ รู้จัก แดง
#
# Original: ผมดีใจที่ได้รู้จัก
# Processed: ผม ดีใจ รู้จัก
#
# Original: คุณรู้จักคุณแดงหรือเปล่า
# Processed: รู้จัก แดง
#
# Original: ขอถามหน่อยว่าคุณเป็นใคร
# Processed: ถาม
#
# Original: นี่คือนามบัตรของผม
# Processed: นามบัตร ผม
#
# Original: ผมดีใจที่ได้รู้จักคุณ
# Processed: ผม ดีใจ รู้จัก
#
# Original: คุณมาจากไหน
# Processed: มาจาก
#
# Original: คุณเป็นคนที่ไหน
# Processed: คน
#
# Original: ผมเป็นคนเชียงใหม่
# Processed: ผม คน เชียงใหม่
#
# Original: คุณอยู่ที่ไหน
# Processed:
#
# Original: ผมอยู่ในกรุงเทพ
# Processed: ผม กรุงเทพ
#
# Original: ผมอยู่ถนนสุขุมวิท
# Processed: ผม ถนน สุขุมวิท
#
# Original: ฉันอยู่บ้านเลขที่ 17/231 สุขุมวิท ซอย 6
# Processed: บ้าน เลขที่   17 /231   สุขุมวิท   ซอย   6
#
# Original: ลูกชายคุณสบายดีหรือ
# Processed: ลูกชาย สบายดี
#
# Original: ครอบครัวคุณสบายดีหรือ
# Processed: ครอบครัว สบายดี
#
# Original: คุณพ่อคุณสบายดีหรือ
# Processed: พ่อคุณ สบายดี
#
# Original: คุณพูดภาษาอังกฤษได้ไหม
# Processed: ภาษาอังกฤษ ไหม
#
# Original: เปล่าผมพูดภาษาอังกฤษไม่ได้
# Processed: เปล่า ผม ภาษาอังกฤษ
#
# Original: ผมพูดภาษาอังกฤษได้นิดหน่อย
# Processed: ผม ภาษาอังกฤษ
#
# Original: ผมไม่เข้าใจ
# Processed: ผม
#
# Original: ผมไม่รู้
# Processed: ผม รู้
#
# Original: ผมพููดภาษาคุณไม่ได้
# Processed: ผม พู ูด ภาษา
#
# Original: กรุณาพูดช้าๆ
# Processed: กรุณา
#
# Original: พูดอีกทีสิ
# Processed: อีกที สิ
#
# Original: คุณพูดได้กี่ภาษา
# Processed: กี่ ภาษา
#
# Original: คุณเข้าใจไหม
# Processed: ไหม
#
# Original: คุณเข้าใจที่ผมพูดไหม
# Processed: ผม ไหม
#
# Original: ภาษาไทยยากไหม
# Processed: ภาษาไทย ไหม
#
# Original: ภาษาไทยง่ายมากใช่ไหม
# Processed: ภาษาไทย
#
# Original: ผมพูดภาษาไทย, อังกฤษ,เยอรมันและสวีเดน
# Processed: ผม ภาษาไทย ,   อังกฤษ , เยอรมัน สวีเดน
#
# Original: กี่โมงแล้ว
# Processed: กี่ โมง
#
# Original: คุณชื่ออะไร
# Processed: ชื่อ
#
# Original: พบกันใหม่วันจันทร์
# Processed: พบกัน จันทร์
#
# Original: พบกันใหม่นะ
# Processed: พบกัน
#
# Original: ขอโทษครับ
# Processed: ขอโทษ
#
# Original: ช่วยฉันหน่อยได้ไหม
# Processed: ไหม
#
# Original: บอกฉันหน่อยได้ไหม
# Processed: ไหม
#
# Original: ที่นี่มีไหม
# Processed: ที่นี่ ไหม
#
# Original: ที่นี่มีน้ำดื่มไหม
# Processed: ที่นี่ น้ำดื่ม ไหม
#
# Original: คุณมีบุหรี่ไหม
# Processed: บุหรี่ ไหม
#
# Original: ราคาเท่าไหร่
# Processed: ราคา
#
# Original: ฉันไปนะ
# Processed:
#
# Original: ไชโย
# Processed: ไชโย
#
# Original: คุณรับเครดิตการ์ดไหม
# Processed: เครดิตการ์ด ไหม
#
# Original: ห้องน้ำอยู่ที่ไหน
# Processed: ห้องน้ำ
#
# Original: เที่ยวบินไปเชียงใหม่ออกเมื่อไหร่
# Processed: เที่ยวบิน เชียงใหม่
#
# Original: เป็นเที่ยวบินตรงใช่ไหม
# Processed: เที่ยวบิน
#
# Original: ฉันต้องเปลี่ยนเครื่องบินไหม
# Processed: เครื่องบิน ไหม
#
# Original: ฉันต้องเช็คอินเมื่อไหร่
# Processed: เช็ค อิน
#
# Original: ฉันต้องการตั๋วเดี่ยวหนึ่งใบไปเชียงใหม่
# Processed: ต้องการ ตั๋ว เดี่ยว ใบ เชียงใหม่
#
# Original: ฉันต้องการตั๋วไปกลับไปเชียงใหม่
# Processed: ต้องการ ตั๋วไปกลับ เชียงใหม่
#
# Original: ฉันต้องการที่นั่งไม่สูบบุหรี่
# Processed: ต้องการ ที่นั่ง สูบบุหรี่
#
# Original: ฉันต้องการที่นั่งใกล้หน้าต่าง
# Processed: ต้องการ ที่นั่ง หน้าต่าง
#
# Original: เที่ยวบินนี้จะเลื่อนเวลาออกไปกี่ชั่วโมง
# Processed: เที่ยวบิน เลื่อนเวลา กี่ ชั่วโมง
#
# Original: เที่ยวบินนี้จะช้ากี่ชั่วโมง
# Processed: เที่ยวบิน กี่ ชั่วโมง
#
# Original: เที่ยวบินไปเชียงใหม่อยู่ประตูไหน
# Processed: เที่ยวบิน เชียงใหม่ ประตู
#
# Original: เราจะถึงเชียงใหม่กี่โมง
# Processed: เชียงใหม่ กี่ โมง
#
# Original: ฉันรู้สึกไม่สบายมาก
# Processed: รู้สึก
#
# Original: คุณมีห้องว่างไหม
# Processed: ห้อง ว่าง ไหม
#
# Original: ฉันได้จองไว้แล้ว
# Processed: จอง
#
# Original: ฉันต้องการห้องเดี่ยว
# Processed: ต้องการ ห้อง เดี่ยว
#
# Original: ฉันต้องการห้องคู่
# Processed: ต้องการ ห้อง คู่
#
# Original: ฉันต้องการห้องที่มีห้องน้ำในตัว
# Processed: ต้องการ ห้อง ห้องน้ำ ตัว
#
# Original: ฉันต้องการห้องที่มีระเบียง
# Processed: ต้องการ ห้อง ระเบียง
#
# Original: ฉันต้องการห้องเพียงคืนเดียว
# Processed: ต้องการ ห้อง คืน
#
# Original: คืนละเท่าไหร่
# Processed: คืน
#
# Original: ฉันยังไม่รู้ฉันจะพักกี่คืน
# Processed: รู้ พัก กี่ คืน
#
# Original: คำตอบที่คุณจะได้รับ
# Processed: คำตอบ
#
# Original: ฉันเสียใจ
# Processed: เสียใจ
#
# Original: ห้องเต็มแล้ว
# Processed: ห้อง เต็ม
#
# Original: ไม่มีห้องเดี่ยวเหลืออยู่แล้ว
# Processed: ห้อง เดี่ยว อยู่แล้ว
#
# Original: ไม่มีห้องคู่เหลืออยู่แล้ว
# Processed: ห้อง คู่ อยู่แล้ว
#
# Original: คุณจะชำระเงินอย่างไร
# Processed: ชำระเงิน
#
# Original: กรุณาเขียนรายละเอียดในแบบฟอร์มนี้
# Processed: กรุณา รายละเอียด แบบฟอร์ม
#
# Original: กรุณาเซ็นต์ชื่อ
# Processed: กรุณา เซ็นต์ ชื่อ
#
# Original: กรุณาชำระเงินล่วงหน้า
# Processed: กรุณา ชำระเงิน ล่วงหน้า
#
# Original: อาหารเช้ากี่โมง
# Processed: อาหารเช้า กี่ โมง
#
# Original: อาหารเย็นกี่โมง
# Processed: อาหารเย็น กี่ โมง
#
# Original: กรุณานำกระเป๋าเดินทางไปที่ห้องฉันด้วย
# Processed: กรุณา กระเป๋าเดินทาง ห้อง
#
# Original: ฉันทานอาหารเช้าในห้องได้ไหม
# Processed: ทาน อาหารเช้า ห้อง ไหม
#
# Original: ฉันจะกลับวันพรุ่งนี้
# Processed: วันพรุ่งนี้
#
# Original: เก็บตังค์ด้วยครับ
# Processed: ตังค์
#
# Original: ฉันชำระเงินด้วยบัตรเครดิต
# Processed: ชำระเงิน บัตรเครดิต
#
# Original: ฉันชำำระเงินสด
# Processed: ชำ ำ ระ เงินสด
#
# Original: กรุณาเรียกแท็กซี่ให้ฉันหน่อยได้ไหม
# Processed: กรุณา แท็กซี่ ไหม
#
# Original: กรุณาแนะนำโรงแรมแห่งอื่นให้ฉันได้ไหม
# Processed: กรุณา แนะนำ โรงแรม ไหม
#
# Original: รถไฟออกเมื่อไหร่
# Processed: รถไฟ
#
# Original: รถไฟมาถึงสถานีเมื่อไหร่
# Processed: รถไฟ มาถึง สถานี
#
# Original: รถไฟมาถึงสถานี 2 ทุ่ม
# Processed: รถไฟ มาถึง สถานี   2   ทุ่ม
#
# Original: เชิญนั่งครับ
# Processed: เชิญ นั่ง
#
# Original: คุณเรียกสิ่งนี้เป็นภาษาไทยว่ายังไง
# Processed: ภาษาไทย
#
# Original: นั่นหมายความว่าอย่างไร
# Processed: หมายความว่า
#
# Original: พบกันใหม่
# Processed: พบกัน
#
# Original: ผมหิว
# Processed: ผม หิว
#
# Original: ผมกระหายน้ำ
# Processed: ผม กระหายน้ำ
#
# Original: ผมหลงทาง
# Processed: ผม หลงทาง
#
# Original: เร็วหน่อย
# Processed:
#
# Original: คุณต้องการอะไร
# Processed: ต้องการ
#
# Original: อะไรนะ
# Processed:
#
# Original: เป็นอะไรไป
# Processed:
#
# Original: เกิดอะไรขึ้น
# Processed:
#
# Original: รอเดี๋ยว
# Processed: รอเดี๋ยว
#
# Original: รอสักครู่นะครับ
# Processed: รอ สักครู่
#
# Original: คุณจะไปไหน
# Processed:
#
# Original: ช่วยตัวเองนะ
# Processed: ช่วยตัวเอง
#
# Original: เชิญตามสบายนะ
# Processed: เชิญ ตามสบาย
#
# Original: ทำต่อไป
# Processed: ทำ ต่อไป
#
# Original: ดูที่นั่นซิ
# Processed: ดู ที่นั่น ซิ
#
# Original: มันมากเกินไป
# Processed: มากเกินไป
#
# Original: มันแพงเกินไป
# Processed: แพง เกินไป
#
# Original: คุณใจดีมาก
# Processed: ใจ ดีมาก
#
# Original: ผมไม่ได้คิดเช่นนั้น
# Processed: ผม ได้คิด
#
# Original: คุณรู้ไหม
# Processed: รู้ ไหม
#
# Original: เปล่าผมไม่รู้
# Processed: เปล่า ผม รู้
#
# Original: จดไว้สิ
# Processed: สิ
#
# Original: ยาวเท่าไหร่
# Processed:
#
# Original: ใช่แล้ว
# Processed:
#
# Original: สายเกินไปแล้ว
# Processed: สาย เกินไป
#
# Original: เช้าเกินไปแล้ว
# Processed: เช้า เกินไป
#
# Original: เร็วที่สุดเท่าที่จะทำได้
# Processed: ที่จะ ทำได้
#
# Original: ไม่เป็นไร
# Processed:
#
# Original: ระวังนะ
# Processed: ระวัง
#
# Original: ฟังสิ!ฟังนะ!
# Processed: ฟัง สิ ! ฟัง !
#
# Original: ดูนี่สิ
# Processed: ดู สิ
#
# Original: มีอะไรจะให้ผมช่วยบ้าง
# Processed: ผม
#
# Original: ผมผิดเอง
# Processed: ผม
#
# Original: มันเป็นความผิดของผม
# Processed: ความผิด ผม
#
# Original: ผมไม่ผิด
# Processed: ผม
#
# Original: มันไม่ใช่ความผิดของผม
# Processed: ความผิด ผม
#
# Original: ออกไป
# Processed:
#
# Original: คุณคิดว่าอย่างไร
# Processed:
#
# Original: ขอเลขโทรศัพท์หน่อยสิ
# Processed: เลข โทรศัพท์ สิ
#
# Original: ผมเข้าไปข้างในได้ไหม
# Processed: ผม เข้าไป ข้างใน ไหม
#
# Original: คุณเห็นไหม
# Processed: ไหม
#
# Original: ผมขอสูบบุหรี่ได้ไหม
# Processed: ผม สูบบุหรี่ ไหม
#
# Original: ผมต้องจ่ายเท่าไหร่
# Processed: ผม จ่าย
#
# Original: ขออนุญาตถ่ายรูปได้ไหม
# Processed: ขออนุญาต ถ่ายรูป ไหม
#
# Original: เรียกแท็กซี่ให้ผมหน่อยได้ไหม
# Processed: แท็กซี่ ผม ไหม
#
# Original: พาผมกลับไปที่โรงแรมเดี๋ยวนี้
# Processed: ผม โรงแรม เดี๋ยวนี้
#
# Original: วันนี้อัตราแลกเปลี่ยนเป็นเท่าไหร่
# Processed: อัตราแลกเปลี่ยน
#
# Original: ผมต้องการไปซื้อของ
# Processed: ผม ต้องการ ซื้อ

# %%
#processed_sentences_test
